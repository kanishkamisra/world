# %%
import csv
import itertools

from collections import defaultdict
from tqdm import tqdm

# %%
concepts = []
features = []
concept_features = defaultdict(list)
categories = {}

with open('../data/xcslb_compressed.csv', 'r') as f:
    reader = csv.DictReader(f)
    
    for line in reader:
        concepts.append(line['concept'])
        features.append(line['feature'])
        categories[line['concept']] = line['category']
        
        concept_features[line['concept']].append(line['feature'])
        
concepts = list(set(concepts))
features = list(set(features))

# %%
feature_space = defaultdict(lambda: defaultdict(list))

for c, f in tqdm(itertools.product(concepts, features), total = len(concepts) * len(features)):
    if f in concept_features[c]:
        feature_space[f]['positive'].append(c)
    else:
        feature_space[f]['negative'].append(c)
# Out:
# 100%|██████████| 1901650/1901650 [00:01<00:00, 952017.89it/s]

# %%
'''
Pseudo-code for inverse-scaling:

standard template,
{premise: the property "<prop>" is {flipped/unflipped}
examples/shots: 4-shot} * n
query

sample 2m properties (constraint, at least k positive concepts): m aligned and m flipped. 
Additionally, sample 1 query property (no constraint)

randomize order
premise
sample k positive and negative concepts from each
'''
# Out:
# '\nPseudo-code for inverse-scaling:\n\nstandard template,\n{premise: the property "<prop>" is {flipped/unflipped}\nexamples/shots: 4-shot} * n\nquery\n\nsample 2m properties (constraint, at least k concepts): m aligned and m flipped. and 1 query (?)\n\nrandomize order\npremise\nsample k concepts from each\n'

# %%
import world

# %%
world = world.World()
world.create()
# Out:
# 521it [00:00, 3059.95it/s]

# %% [markdown]
# ## Property Filtering
#
# * only animals
# * have at least 5 positive and negative members

# %%
animals = world.taxonomy['animal.n.01'].descendants()

# %%
animal_props = []

for c, props in world.concept_features.items():
    if c in animals:
        animal_props.extend(props)
        
animal_props = list(set(animal_props))

# %%
candidates = []
for prop, members in world.feature_space.items():
#     if prop in animal_props:
    c_p = len([c for c in members['positive']])
    c_n = len([c for c in members['negative']])

    if c_p >=5 and c_n >= 5:
        candidates.append((prop, c_p))

# %%
candidates
# Out:
# [('has a trigger', 7),
#  ('is a condiment', 8),
#  ('is a chair', 6),
#  ('can be unhealthy', 22),
#  ('has no lid', 5),
#  ('is fastened at the front', 5),
#  ('can roll', 14),
#  ('cannot fly', 6),
#  ('can provide warmth', 17),
#  ('has a mouthpiece', 9),
#  ('can peck', 36),
#  ('uses electricity', 15),
#  ('has fibrous skin', 9),
#  ('is made of skin', 9),
#  ('can drag its prey', 10),
#  ('has a steering wheel', 14),
#  ('is worn on head', 5),
#  ('is a flower', 15),
#  ('can fit in the pocket', 8),
#  ('is planted', 24),
#  ('can contain chocolate', 5),
#  ('can be found on farms', 17),
#  ('can be moored', 14),
#  ('can billow', 9),
#  ('can kill people', 29),
#  ('is luxurious', 5),
#  ('can contain fruit flavor', 6),
#  ('has a fishy smell', 30),
#  ('is used while eating', 7),
#  ('can be sweet in taste', 49),
#  ('has a long body', 10),
#  ('can be eaten raw', 42),
#  ('is used for touching and feeling', 6),
#  ('is spherical in shape', 18),
#  ('can be used to kill animals', 5),
#  ('is fragile and delicate', 16),
#  ('can have padding', 7),
#  ('has wings', 56),
#  ('has a shell', 21),
#  ('has wires and cables', 15),
#  ('is a songbird', 8),
#  ('is soft when ripe', 25),
#  ('has holes', 12),
#  ('can be warm', 6),
#  ('can be long', 10),
#  ('can be made into juice', 28),
#  ('contains aluminum', 16),
#  ('allows movement', 6),
#  ('can drain water', 7),
#  ('can move', 218),
#  ('is planted on the ground', 81),
#  ('is a small bird', 11),
#  ('has a glossy surface', 39),
#  ('is chewy', 8),
#  ('can hold or contain liquid', 15),
#  ('can be green in color', 34),
#  ('is a tree', 9),
#  ('has a thorax', 122),
#  ('has eyes', 149),
#  ('can be blue in color', 17),
#  ('can cut flesh', 11),
#  ('has a big tail', 7),
#  ('is a bird of prey', 5),
#  ('is a part of the human body', 14),
#  ('is peeled', 61),
#  ('can blow in the wind', 25),
#  ('can be found on lakes', 5),
#  ('can be made of wool', 22),
#  ('has pith', 7),
#  ('is a citrus fruit', 6),
#  ('can be found living in large groups', 13),
#  ('can malfunction', 55),
#  ('basks in the sun', 6),
#  ('fires bullets', 6),
#  ('can be found in the wild', 177),
#  ('hunts in packs', 5),
#  ('is an insect', 24),
#  ('has stamens', 15),
#  ('has feathers', 36),
#  ('has soft meat', 9),
#  ('can be made with raspberries', 5),
#  ('has thick skin', 14),
#  ('has an exoskeleton', 31),
#  ('can make a squeaky noise', 10),
#  ('can climb trees', 27),
#  ('is a crustacean', 6),
#  ('contains fiber', 33),
#  ('can crease', 37),
#  ('can be found at the hardware store', 31),
#  ('can be used as a weapon', 11),
#  ('can travel long distances', 14),
#  ('has shelves', 5),
#  ('can carry objects', 52),
#  ('has sensitive bones', 8),
#  ('can be cold', 10),
#  ('is a type of boat', 13),
#  ('has a handle', 84),
#  ('lives in jungles', 18),
#  ('has feet', 124),
#  ('has big wings', 11),
#  ('can be salty in taste', 9),
#  ('can be found in hot climate', 16),
#  ('can have a wooden frame', 13),
#  ('is a body part', 14),
#  ('eats hay', 13),
#  ('can be red in color', 58),
#  ('can contain decoration', 7),
#  ('is deciduous', 6),
#  ('can be cooked', 77),
#  ('is a vehicle', 43),
#  ('is a plant', 85),
#  ('has a pulp', 39),
#  ('has a slim body', 12),
#  ('is made of elastic', 11),
#  ('can dive underwater', 17),
#  ('has a trunk', 10),
#  ('has a seat', 37),
#  ('bruises over time', 30),
#  ('has a curved beak', 8),
#  ('is a dairy product', 5),
#  ('can swim', 49),
#  ('is violent', 23),
#  ('is used in combat', 25),
#  ('can have green skin', 6),
#  ('is used in playing football', 5),
#  ('is a flowering plant', 15),
#  ('can be pink in color', 36),
#  ('can be tall', 29),
#  ('is eaten by birds', 6),
#  ('has a base', 32),
#  ('has a frame', 47),
#  ('is a type of furniture', 17),
#  ('is worn by humans', 37),
#  ('has a sharp point', 18),
#  ('can be found in supermarkets', 264),
#  ('can be fished', 24),
#  ('can be found at weddings', 7),
#  ('can be made of polyester', 13),
#  ('is zesty', 6),
#  ('is a source of energy', 29),
#  ('has a hard surface', 172),
#  ('can be made of canvas material', 6),
#  ('can be found on tables', 8),
#  ('has a green stalk', 69),
#  ('can fly', 54),
#  ('can require electricity', 19),
#  ('can be viscous', 5),
#  ('eats nuts', 5),
#  ('has a zip', 11),
#  ('can be strong in taste', 8),
#  ('has a metal end', 20),
#  ('can be flexible', 17),
#  ('is a gun', 6),
#  ('is used in cakes', 10),
#  ('can spin', 7),
#  ('has fins', 19),
#  ('is round in shape', 110),
#  ('can glide', 11),
#  ('is used by builders', 6),
#  ('eats meat', 110),
#  ('has temperature controls', 8),
#  ('is worn when cold', 8),
#  ('can provide shade', 10),
#  ('can eat plants', 52),
#  ('has fur', 59),
#  ('is solitary', 5),
#  ('can gallop', 15),
#  ('can have a smoky flavor', 5),
#  ('is found on the face', 6),
#  ('has a neck', 113),
#  ('is a cooking utensil', 6),
#  ('can be covered', 5),
#  ('has windows', 16),
#  ('can be black in color', 94),
#  ('has leathery skin', 22),
#  ('has hooves', 17),
#  ('contains water', 22),
#  ('has wheels', 27),
#  ('can be golden in color', 12),
#  ('has buds', 16),
#  ('can be made with strawberries', 5),
#  ('has metal blades', 24),
#  ('can be fastened', 12),
#  ('can contain eggs', 7),
#  ('is perishable', 59),
#  ('can be found in seas', 43),
#  ('is a popular pet', 6),
#  ('can be cut into slices', 34),
#  ('can be made of wood and metal', 14),
#  ('is found on water', 25),
#  ('is traditional', 8),
#  ('can be inflated', 5),
#  ('can contain bubbles', 5),
#  ('has edible skin', 7),
#  ('is feline', 7),
#  ('has hard and tough skin', 16),
#  ('has green leaves', 37),
#  ('is used by the navy', 7),
#  ('is hard to see', 5),
#  ('can growl', 13),
#  ('can be used to make smoothies', 30),
#  ('has an antenna', 28),
#  ('can be rectangular in shape', 32),
#  ('can be found on plants', 9),
#  ('is worn at home', 8),
#  ('can prance', 6),
#  ('has a cartridge', 6),
#  ('grows on a stalk', 9),
#  ('can lay eggs', 95),
#  ('is played with hands', 28),
#  ('is made using butter', 7),
#  ('can have a large surface area', 5),
#  ('can be squeezed', 14),
#  ('can be posh', 30),
#  ('is a water bird', 10),
#  ('can bite', 68),
#  ('can be white in color', 255),
#  ('can contain hot water', 5),
#  ('is a delicacy', 7),
#  ('can be grey in color', 41),
#  ('is used in desserts', 46),
#  ('has a mirror', 14),
#  ('has a long beak', 7),
#  ('has air conditioning', 9),
#  ('is a part of the primate body', 14),
#  ('can be transparent', 19),
#  ('can wriggle', 7),
#  ('is found in all vertebrates', 14),
#  ('is moveable', 58),
#  ('is used on pizza', 8),
#  ('can transport goods', 22),
#  ('can be sold frozen', 8),
#  ('can pierce or impale', 9),
#  ('can be found in zoos', 91),
#  ('is used to cover the body', 37),
#  ('has sails', 5),
#  ('has antioxidants', 28),
#  ('has a sting', 5),
#  ('is buoyant', 15),
#  ('is rigid', 49),
#  ('is a scavenger', 8),
#  ('can fly fast', 5),
#  ('has a smooth texture', 23),
#  ('eats leaves', 52),
#  ('can be used to make drinks', 41),
#  ('is low in calories', 44),
#  ('has skin', 221),
#  ('can be locked', 13),
#  ('can be added to alcoholic drinks', 5),
#  ('can be worn on the shoulder', 8),
#  ('can be black and white in color', 9),
#  ('is used for recreation', 26),
#  ('is a fruit', 39),
#  ('can be found in bedrooms', 13),
#  ('has doors', 28),
#  ('is common in summer', 15),
#  ('has blood vessels', 12),
#  ('has good eyesight', 6),
#  ('has talons', 6),
#  ('contains fabric parts', 5),
#  ('can be brown in color', 115),
#  ('can contain a ring', 5),
#  ('can be made of leather', 17),
#  ('can be found in water', 49),
#  ('holds liquid', 8),
#  ('is a brass instrument', 5),
#  ('has horns', 6),
#  ('has a collar', 6),
#  ('can be made of silk', 16),
#  ('is electric', 12),
#  ('has propellers', 6),
#  ('can live near the water', 20),
#  ('is aerodynamic', 8),
#  ('is tube shaped', 5),
#  ('can have a lid', 12),
#  ('is an animal', 152),
#  ('can be silver in color', 16),
#  ('lives on the ground', 8),
#  ('can produce milk', 5),
#  ('can be wrapped around the body', 5),
#  ('can be thick', 10),
#  ('can be eaten with bread', 7),
#  ('is used in seas', 8),
#  ('can be used by armed forces', 25),
#  ('has two arm rests', 6),
#  ('can gnaw', 8),
#  ('can support body weight', 22),
#  ('has slimy skin', 22),
#  ('can be oily', 6),
#  ('has pockets', 14),
#  ('comes in different varieties', 18),
#  ('has edges', 21),
#  ('is a snack', 9),
#  ('can be found in the living room', 10),
#  ('has a nose', 99),
#  ('can be made of soft fabric', 14),
#  ('is aquatic', 32),
#  ('resembles a horse', 5),
#  ('can be found on ponds', 9),
#  ('has controls', 11),
#  ('is made of alcohol', 7),
#  ('is a string instrument', 7),
#  ('has a water source', 6),
#  ('can be found underwater', 31),
#  ('can be driven', 17),
#  ('is a reptile', 7),
#  ('contains carbohydrates', 84),
#  ('can be bought and sold at supermarkets', 267),
#  ('can be sold at fairs', 61),
#  ('is a container', 20),
#  ('contains circuit boards', 14),
#  ('is made of flesh', 164),
#  ('can have a wooden handle', 13),
#  ('can be made of plastic', 155),
#  ('has branches', 9),
#  ('has edible seeds', 5),
#  ('is involved in movement', 7),
#  ('can be bitter in taste', 31),
#  ('has valves', 6),
#  ('has a tongue', 99),
#  ('can be made of wood', 113),
#  ('can scrape', 9),
#  ('has lights', 6),
#  ('can have spots on its body', 13),
#  ('has a face', 147),
#  ('comes in pairs', 14),
#  ('can be used to shoot something', 7),
#  ('is worn on formal occasions', 7),
#  ('is used by farmers', 6),
#  ('has pincers', 10),
#  ('can play different notes', 23),
#  ('requires twisting', 6),
#  ('can be used to entertain', 5),
#  ('has protein', 9),
#  ('is a root vegetable', 8),
#  ('can be made of fabric', 50),
#  ('has a hood', 15),
#  ('can scuttle', 16),
#  ('can be used for building and repairing', 9),
#  ('can have a bell', 7),
#  ('is an organ', 14),
#  ('is brittle', 16),
#  ('has technology', 32),
#  ('can be made of lycra', 6),
#  ('can be found in burgers', 12),
#  ('is served in a bowl', 7),
#  ('can be used to chop', 7),
#  ('has bark', 9),
#  ('is a type of food', 97),
#  ('has a strong flavor', 27),
#  ('can cause injuries', 20),
#  ('has a hard shell', 14),
#  ('can be made of metal', 181),
#  ('is grown in warm climate', 15),
#  ('can be scary', 34),
#  ('has keys', 12),
#  ('has big eyes', 18),
#  ('is used by soldiers', 5),
#  ('can be found in the toolshed', 31),
#  ('is indulgent', 5),
#  ('has webbed feet', 11),
#  ('has bones', 155),
#  ('has a furry texture', 11),
#  ('has two eyes', 125),
#  ('has yellow flesh', 5),
#  ('has a streamlined body', 8),
#  ('has multiple parts', 38),
#  ('is shaped like a box', 10),
#  ('can cut', 25),
#  ('is a bird', 36),
#  ('is chopped', 30),
#  ('lives in herds', 11),
#  ('is held in hand', 60),
#  ('has a strong bite', 8),
#  ('is sharp', 31),
#  ('has cushions', 8),
#  ('has four wings', 5),
#  ('is domesticated', 26),
#  ('is blown to play', 9),
#  ('breeds rapidly', 8),
#  ('has large teeth', 16),
#  ('can have a hem', 14),
#  ('can dig', 5),
#  ('is portable', 107),
#  ('can be durable', 5),
#  ('can attract insects', 43),
#  ('can pounce', 11),
#  ('has a tube', 7),
#  ('can be grown', 85),
#  ('consumes planktons', 5),
#  ('has a bushy tail', 6),
#  ('can suck blood', 5),
#  ('is drunk with food', 5),
#  ('can swing', 5),
#  ('is a sea creature', 30),
#  ('has a rim', 15),
#  ('requires skill to use', 77),
#  ('is involved in special occasions', 18),
#  ('has two feet', 40),
#  ('is soft when cooked', 64),
#  ('can be made of ceramic', 15),
#  ('is a rodent', 13),
#  ('was used in medieval warfare', 9),
#  ('can open', 7),
#  ('is used in lab experiments', 5),
#  ('can hurt', 26),
#  ('adds flavor to food', 8),
#  ('is used by chefs', 29),
#  ('is eaten in salad', 20),
#  ('has a long tongue', 7),
#  ('is an invertebrate', 39),
#  ('is a musical instrument', 23),
#  ('is oval shaped', 7),
#  ('has leaves', 67),
#  ('can be found at orchestras', 14),
#  ('is handheld', 103),
#  ('can pollute the environment', 7),
#  ('has a good sense of smell', 60),
#  ('can be made of linen', 8),
#  ('has tentacles', 5),
#  ('has sharp claws', 13),
#  ('contains seeds', 33),
#  ('is used to make jam', 7),
#  ('is kept in a pot', 15),
#  ('can resonate', 23),
#  ('is rhythmic', 5),
#  ('is popular at parties', 19),
#  ('is made of tissue', 14),
#  ('has a sharp blade', 6),
#  ('is cuboid in shape', 7),
#  ('has a hull', 11),
#  ('has a rudder', 10),
#  ('has legs', 140),
#  ('can be found on canals', 11),
#  ('can be gifted', 7),
#  ('can heat', 6),
#  ('has a top', 13),
#  ('is sold in bags', 5),
#  ('can take part in races', 7),
#  ('has a timer', 9),
#  ('can crawl', 29),
#  ('requires sunlight', 24),
#  ('is semi aquatic', 20),
#  ('can be used in desserts', 31),
#  ('can be a source of entertainment', 54),
#  ('has slots for legs', 10),
#  ('comes in two pieces', 5),
#  ('can maim', 23),
#  ('is nocturnal', 11),
#  ('can be cozy', 7),
#  ('has a reed', 5),
#  ('is worn on upper body', 19),
#  ('has a head', 164),
#  ('is a percussion instrument', 5),
#  ('can hold drinks', 7),
#  ('can be aimed', 19),
#  ('has thin legs', 11),
#  ('can be used for trips', 14),
#  ('can be added to cereal', 5),
#  ('eats insects', 56),
#  ('can waddle', 6),
#  ('can be made of brass', 8),
#  ('has a long nose', 6),
#  ('can hop', 5),
#  ('is found in grass', 5),
#  ('can be plucked', 5),
#  ('is cold blooded', 62),
#  ('is tangy', 7),
#  ('can be used to make furniture', 10),
#  ('can be found in shops', 261),
#  ('is a tool', 50),
#  ('can drool', 59),
#  ('can kill', 75),
#  ('can walk', 112),
#  ('can be used for relaxing', 8),
#  ('is attached to a wire', 7),
#  ('is a pest', 19),
#  ('is played by music bands', 23),
#  ('can eat', 149),
#  ('can eat animals', 24),
#  ('has a windscreen', 11),
#  ('has a long tail', 19),
#  ('has a hard seed', 26),
#  ('can hurt people', 23),
#  ('has a mouth', 152),
#  ('can contain metal', 5),
#  ('has a big seed', 6),
#  ('is crunchy', 15),
#  ('can be swung', 5),
#  ('can transport people', 37),
#  ('can be used for gardening', 10),
#  ('is used for transport', 48),
#  ('can be used in pies', 5),
#  ('is a vessel', 10),
#  ('moves slowly on land', 7),
#  ('can have a muzzle', 5),
#  ('can be fast', 81),
#  ('has twigs', 9),
#  ('has layers', 7),
#  ('is made of cells', 251),
#  ('contains fat', 11),
#  ('has various styles', 37),
#  ('is a predator', 21),
#  ('can keep the body warm', 21),
#  ('is sturdy', 109),
#  ('is found in pubs and bars', 5),
#  ('can be shot', 6),
#  ('can be found in the study', 6),
#  ('has an uneven surface', 10),
#  ('has a stem', 42),
#  ('comes in flavors', 14),
#  ('is cooked by baking', 9),
#  ('has strong muscles', 21),
#  ('is baked in ovens', 5),
#  ('has a waistband', 5),
#  ('is liquid', 16),
#  ('is used as an ingredient in recipes', 69),
#  ('can hit people', 23),
#  ('requires lung power', 9),
#  ('has bullets', 5),
#  ('can be rowed', 5),
#  ('can be blunt', 24),
#  ('can get cold', 27),
#  ('is attracted to sweet things', 6),
#  ('can be played', 23),
#  ('has a hollow body', 16),
#  ('is made using flour', 5),
#  ('can be made of steel', 79),
#  ('can be bent', 7),
#  ('can be sat on', 17),
#  ('can be soft', 72),
#  ('can stab', 10),
#  ('is a large vehicle', 18),
#  ('is slimy', 29),
#  ('is green in color', 32),
#  ('can cause damage', 7),
#  ('can be short', 27),
#  ('can be found in the kitchen', 138),
#  ('has a chamber for bullets', 5),
#  ('can be cut', 61),
#  ('has many petals', 15),
#  ('can be sold fresh', 106),
#  ('can be fancy', 37),
#  ('has fangs', 5),
#  ('can be made of waterproof material', 19),
#  ('has a pointy end', 26),
#  ('is dark in color', 19),
#  ('has a back rest', 8),
#  ('can pull things', 6),
#  ('is hard when raw', 54),
#  ('is played with the mouth', 9),
#  ('can have rubber parts', 26),
#  ('has tail feathers', 36),
#  ('can be unstable', 9),
#  ('is eaten by humans', 109),
#  ('is found in flocks', 6),
#  ('is fermented', 6),
#  ('can be sold in packets', 10),
#  ('is worn on clothes', 7),
#  ('is used to hold food', 7),
#  ('is kept in fridge', 9),
#  ('is streamlined', 45),
#  ('is a sensory organ', 8),
#  ('has a black nose', 8),
#  ('requires plumbing', 5),
#  ('is played with fingers', 17),
#  ('is white inside', 8),
#  ('can run fast', 10),
#  ('can hold its breath for long periods of time', 5),
#  ('can be shriveled', 7),
#  ('can contain passengers', 38),
#  ('can be orange in color', 31),
#  ('has flippers', 6),
#  ('can be used to live in', 5),
#  ('has paws', 24),
#  ('has joints', 8),
#  ('can make loud sounds', 20),
#  ('has a flat bottom', 22),
#  ('carries one person', 14),
#  ('is a poultry bird', 5),
#  ('can be thin', 64),
#  ('can sleep', 152),
#  ('can be used for transportation', 46),
#  ('has a switch', 10),
#  ('can be poisonous', 13),
#  ('has thick fur', 9),
#  ('can be stored in cans or tins', 10),
#  ('has compartments', 15),
#  ('eats', 152),
#  ('is an accessory', 7),
#  ('can climb', 27),
#  ('has buttons', 28),
#  ('is an arthropod', 25),
#  ('has brakes', 16),
#  ('has sleeves', 13),
#  ('can carry a lot of people', 9),
#  ('has roots', 54),
#  ('can be loose', 37),
#  ('can be made of satin', 5),
#  ('is a mollusc', 7),
#  ('can fit in one hand', 23),
#  ('is thrown', 9),
#  ('makes a buzzing sound', 6),
#  ('has petals', 16),
#  ('can be found on beaches', 11),
#  ('is had in summer', 7),
#  ('is purple in color', 15),
#  ('is endangered', 20),
#  ('is leafy', 5),
#  ('can build nests', 35),
#  ('follows a route', 6),
#  ('has a boot', 10),
#  ('has a short tail', 9),
#  ('has big ears', 5),
#  ('has four legs', 64),
#  ('can be crowded', 9),
#  ('has tuning pegs', 5),
#  ('is manmade', 242),
#  ('has teeth', 67),
#  ('can require cleaning', 243),
#  ('can be used as a container', 24),
#  ('eats worms', 5),
#  ('is worn outdoors', 33),
#  ('can be found in a bottle', 11),
#  ('can be found in mountains', 24),
#  ('requires skill to play', 23),
#  ('has ancient origins', 7),
#  ('is a toy', 15),
#  ('can be filled', 8),
#  ('is a wind instrument', 9),
#  ('requires fuel to use', 25),
#  ('has a high alcohol content', 5),
#  ('can scoop', 5),
#  ('can filter water', 5),
#  ('is used during cooking', 114),
#  ('has forelimbs', 97),
#  ('eats flies', 5),
#  ('is a drink', 11),
#  ('has arm holes', 16),
#  ('can fire long range', 5),
#  ('comes in varying lengths', 5),
#  ('contains ligament', 7),
#  ('is a farm animal', 10),
#  ('is connected to a water supply', 5),
#  ('can have sharp blades', 13),
#  ('is fashionable', 31),
#  ('is a raptor', 5),
#  ('can get full', 27),
#  ('grows on trees', 24),
#  ('is a living thing', 233),
#  ('has six legs', 21),
#  ('is used in the kitchen', 31),
#  ('can be found in the playground', 15),
#  ('is used on soil', 6),
#  ('is used to contain objects', 27),
#  ('is good for digestion', 5),
#  ('has an aisle', 6),
#  ('can be found in houses', 178),
#  ('can be found in forests', 98),
#  ('has a strong smell', 55),
#  ('has a flat surface', 28),
#  ('has arms', 8),
#  ('can sing', 15),
#  ('can explode', 33),
#  ('eats vegetables', 5),
#  ('is played by musicians', 23),
#  ('has gills', 16),
#  ('can be uncomfortable', 9),
#  ('has descended from dinosaurs', 36),
#  ('can be used to hunt', 8),
#  ('can be a pet', 20),
#  ('produces wood', 9),
#  ('is hunted by humans', 19),
#  ('can be loud', 87),
#  ('has a dial', 8),
#  ('has an exhaust', 5),
#  ('feeds on fish', 20),
#  ('can be used in sandwiches', 16),
#  ('is seafood', 24),
#  ('is made of soft fabric', 17),
#  ('can be cumbersome to move around', 8),
#  ('requires ammunition', 6),
#  ('can be used to make stew', 29),
#  ('is consumed by drinking', 12),
#  ('is held by ropes', 6),
#  ('is wrinkly', 5),
#  ('can sink', 14),
#  ('can jump', 29),
#  ('is for games', 15),
#  ('has large paws', 7),
#  ('can be refreshing', 35),
#  ('can be knitted', 7),
#  ('has a stern', 7),
#  ('can lift objects', 5),
#  ('is an alcoholic drink', 7),
#  ('is an appliance', 14),
#  ('can roost', 36),
#  ('can be pollinated', 15),
#  ('can be filling', 10),
#  ('can stand on one leg', 35),
#  ('can have rough edges', 20),
#  ('is a garden tool', 11),
#  ('is a habitat for animals', 9),
#  ('can fire projectiles', 10),
#  ('can bleed', 165),
#  ('can run', 38),
#  ('has a segmented body', 14),
#  ('can block out sunlight', 9),
#  ('is flexible', 6),
#  ('is pushed', 5),
#  ('can hold things', 38),
#  ('is coiled', 5),
#  ('can have sharp teeth', 20),
#  ('can be fried', 8),
#  ('can be used by babies', 5),
#  ('can mix ingredients', 6),
#  ('can fly in formation', 9),
#  ('can be used for storage', 27),
#  ('is a beverage', 11),
#  ('has sweet flesh', 22),
#  ('has an engine', 30),
#  ('can contain milk', 13),
#  ('is eaten as meat', 30),
#  ('can be used in toys', 8),
#  ('has large muscles', 13),
#  ('can have cabins', 5),
#  ('has a string', 6),
#  ('has claws', 50),
#  ('is used for farming', 5),
#  ('is found in unhygienic conditions', 19),
#  ('can chase', 11),
#  ('can contain toilets', 9),
#  ('is popular with children', 32),
#  ('can be made of insulated material', 6),
#  ('has racks', 5),
#  ('has a beak', 41),
#  ('is muscular', 21),
#  ('can be made of metal and plastic', 16),
#  ('can be made of fine cloth', 6),
#  ('can make a loud noise', 12),
#  ('can have straps', 13),
#  ('can have a rough texture', 19),
#  ('has a sharp beak', 7),
#  ('transmits messages to the brain', 14),
#  ('can sail', 14),
#  ('is hunted', 16),
#  ('can slide', 20),
#  ('contains vitamins', 15),
#  ('has babies that are called cubs', 10),
#  ('is consumed to celebrate', 9),
#  ('has a big beak', 6),
#  ('has big feet', 5),
#  ('contains oil', 8),
#  ('is curved in shape', 26),
#  ('is fished in nets', 27),
#  ('is used in jazz music', 11),
#  ('has hair', 6),
#  ('is a source of wood', 9),
#  ('can be airborne', 59),
#  ('can have a hot temperature', 13),
#  ('is protective', 19),
#  ('lives in a stable', 10),
#  ('has two handles', 5),
#  ('has a long handle', 15),
#  ('has scales', 21),
#  ('has pedals', 10),
#  ('has babies that are called calves', 11),
#  ('has tires', 16),
#  ('is an electrical appliance', 11),
#  ('is juicy', 27),
#  ('is a weapon', 24),
#  ('is territorial', 9),
#  ('has a tail', 97),
#  ('produces pollen', 15),
#  ('can be found on rivers', 8),
#  ('can be used to make cakes', 8),
#  ('is operated by humans', 74),
#  ('has two legs', 40),
#  ('is a kitchen utensil', 10),
#  ('can be made of glass', 16),
#  ('can be long and thin in shape', 5),
#  ('is manned by a crew', 10),
#  ('requires two hands to play', 20),
#  ('has oars', 5),
#  ('can camouflage', 12),
#  ('has sharp edges', 22),
#  ('requires a power source', 31),
#  ('can be dangerous', 100),
#  ('can sting', 6),
#  ('is playful', 7),
#  ('can house birds', 10),
#  ('can hunt', 18),
#  ('can be used in sports', 24),
#  ('has eight legs', 6),
#  ('has hands', 11),
#  ('can be colorful', 56),
#  ('is a vegetable', 29),
#  ('can be cooked by boiling', 16),
#  ('is smooth on the outside', 9),
#  ('can be moist', 33),
#  ('eats seeds', 18),
#  ('is grown in summer', 6),
#  ('has a center', 22),
#  ('has a deep sound', 5),
#  ('performs photosynthesis', 80),
#  ('is a shellfish', 9),
#  ('can be worn on the back', 10),
#  ('is a marine animal', 30),
#  ('is a dessert', 8),
#  ('can hibernate', 5),
#  ('can be fluffy', 13),
#  ('can be empty', 25),
#  ('can be found in dark places', 5),
#  ('lives in grasslands', 5),
#  ('has a crushing bite', 9),
#  ('can be made of wheat', 6),
#  ('is used by criminals', 24),
#  ('is slow on land', 6),
#  ('can have plastic handles', 7),
#  ('requires electricity', 26),
#  ('can be found on land', 98),
#  ('can come in multiple colors', 95),
#  ('is served at fine-dining restaurants', 14),
#  ('is made of connective tissue', 7),
#  ('is a utensil', 13),
#  ('contains sugar', 45),
#  ('is used for cooking', 5),
#  ('is driven on roads', 12),
#  ('is a herbivore', 52),
#  ('can be difficult to use', 12),
#  ('has a strong back', 5),
#  ('is dried', 10),
#  ('contains juice', 16),
#  ('can be used to organize', 5),
#  ('can be used to pour things', 8),
#  ('produces wool', 6),
#  ('can be consumed with ice', 5),
#  ('has four wheels', 17),
#  ('has flavor', 91),
#  ('lives under water', 30),
#  ('can be used in construction', 5),
#  ('can have a smooth texture', 9),
#  ('is sticky', 7),
#  ('can grow', 242),
#  ('can be sour in taste', 19),
#  ('is used for baking', 12),
#  ('is played with', 16),
#  ('is a machine', 56),
#  ('lives under rocks', 9),
#  ('can be slow', 59),
#  ('is found in freshwater', 8),
#  ('is tropical', 10),
#  ('has a plug', 10),
#  ('can be found on trees', 34),
#  ('is a household item', 44),
#  ('can be squashy', 14),
#  ('can float', 20),
#  ('can be violent', 32),
#  ('contains oil and fat', 9),
#  ('contains gunpowder', 6),
#  ('can be readymade', 9),
#  ('can be yellow in color', 54),
#  ('can work in teams', 7),
#  ('is found in urban areas', 5),
#  ('has moist skin', 5),
#  ('can be used to eat food', 10),
#  ('is kept in a cage', 10),
#  ('can be worn', 41),
#  ('has a hole', 8),
#  ('can breathe', 153),
#  ('has striped patterns', 10),
#  ('is a dried fruit', 5),
#  ('can lead to hangovers', 6),
#  ('grows from a bulb', 15),
#  ('has slots for arms', 14),
#  ('is used by hand', 62),
#  ('is edged', 8),
#  ('is upright', 14),
#  ('can be ridden', 12),
#  ('contains chlorophyll', 9),
#  ('has scaly skin', 21),
#  ('has waxy skin', 18),
#  ('has seeds', 86),
#  ('can be served in a cup', 11),
#  ('is a type of clothing', 36),
#  ('requires water', 101),
#  ('is connected to the body', 9),
#  ('can drink', 152),
#  ('is a firearm', 5),
#  ('has a long neck', 14),
#  ('can be found in the tool box', 14),
#  ('is cylindrical in shape', 17),
#  ('is worn in winter', 13),
#  ('eats rodents and mice', 7),
#  ('is spiky', 9),
#  ('has an anchor', 5),
#  ('has high amounts of calories', 23),
#  ('has a saddle', 5),
#  ('can be eaten cold', 60),
#  ('is common in developing countries', 6),
#  ('has big hind legs', 6),
#  ('has strings', 7),
#  ('is modern', 16),
#  ('is a social animal', 16),
#  ('is flown', 5),
#  ('can be found in fields', 14),
#  ('has patterns on its body', 11),
#  ('can carry diseases', 35),
#  ('is grown by planting', 82),
#  ('can be found in rivers', 19),
#  ('can be suspended', 5),
#  ('can be used to make soup', 36),
#  ('is used during sleeping', 7),
#  ('can make music', 23),
#  ('has wipers', 10),
#  ('can be served in a glass', 11),
#  ('has an insatiable appetite', 12),
#  ('is a mammal', 54),
#  ('has a body', 153),
#  ('has arm rests', 8),
#  ('contains nerves', 10),
#  ('can be steamed', 30),
#  ('is a fish', 14),
#  ('can be found in gardens', 73),
#  ('can be made of nylon', 5),
#  ('is a large cat', 6),
#  ('can be decorative', 15),
#  ('is warm blooded', 90),
#  ('can be used for cleaning', 8),
#  ('can lick', 95),
#  ('can keep the body dry', 9),
#  ('can be found in damp places', 5),
#  ('is ornamental', 5),
#  ('requires pulling', 7),
#  ('can make sounds', 187),
#  ('has small legs', 38),
#  ('can be bland in taste', 10),
#  ('can stand up vertically', 14),
#  ('is used to wash', 6),
#  ('can be emptied', 20),
#  ('sheds its skin', 6),
#  ('can melt under heat', 7),
#  ('can be eaten', 141),
#  ('can make you drunk', 7),
#  ('has a deck', 7),
#  ('has a high pitch', 8),
#  ('has sharp talons', 5),
#  ('is found in animal body', 14),
#  ('is made of muscles', 14),
#  ('can be folded', 5),
#  ('has long legs', 15),
#  ('can be roasted', 35),
#  ('can be acoustic', 5),
#  ('has whiskers', 55),
#  ('is used for digging', 5),
#  ('can be found in cold climate', 7),
#  ('has ears', 95),
#  ('is made up of ingredients', 13),
#  ('has a metal frame', 36),
#  ('is often eaten for breakfast', 17),
#  ('is used in baroque music', 8),
#  ('can be trained', 7),
#  ('provides warmth', 5),
#  ('can reproduce', 164),
#  ('has a metal head', 14)]

# %%
properties = ['can fly', 
              'is aquatic', 
              'has fangs', 
              'has ears', 
              'can swim',
              'is a musical instrument',
              'has wings', 
              'has fins',
              'is a poultry bird',
              'has two legs',
              'is a herbivore',
              'is a carnivore',
              'has ears',
              'has fur',
              'uses electricity',
              'has talons', 
              'is a predator', 
              'is cold blooded', 
              'is warm blooded', 
              'has feet',
              'is a mammal',
              'is a fish',
              'can breathe',
              'produces wool',
              'has a beak',
              'is an invertebrate',
              'is a reptile',
              'can lay eggs',
              'has feathers',
              'is a songbird',
              'has sails',
              'can be found in seas',
              'can spin webs',
              'is a fruit',
              'is a vegetable',
              'can kill people',
              'hunts in packs',
              'is a machine',
              'is planted',
              'has a tail',
              'is a flower',
              'is a weapon',
              'has wheels',
              'is domesticated',
              'can breathe',
              'is a farm animal',
              'can heat',
              'can be sweet in taste',
              'is feline',
              'can make music',
              'is an animal',
              'has striped patterns']

properties = list(set(properties))

print(len(properties))
# Out:
# 50

# %%
for f in world.features:
    print(f)
# Out:
# is worn for swimming
# can be button shaped
# has a trigger
# can be grilled
# is used in fish and chips
# can shoot spikes
# can contain cloth material
# has six strings
# has a floor
# is not a horse
# likes mirrors
# reflects light
# is held sideways
# can have a bin bag
# is a sink
# is a condiment
# can have yellow skin
# is mulled
# can cut down trees
# stores nuts for winter
# can store crockery
# is a chair
# can be unhealthy
# has footboard
# has a cap
# has a cockpit
# can flick out
# uses ink
# has no lid
# is an ornamental fish
# can squirt ink
# has a firm flesh
# comes from cows
# can be fructose
# can go through corks
# uses its tail to balance
# is an aircraft
# is fastened at the front
# wakes up early
# can come in granules
# is put into bouquets
# can be connected to an amplifier
# has an overflow channel
# has a barrow
# can have a lever
# is made of muscle
# is ground
# produces catkin flowers
# can roll
# can be covered in chocolate
# has stitching
# cannot fly
# has a long blade
# can provide warmth
# mimics human speech
# is pink in color
# has a mouthpiece
# can be worn with cufflinks
# comes in different shapes
# is an emergency vehicle
# can be ridden on paths
# can be found on a safari
# flaps its wings fast
# can carry heavy objects
# has metal bands
# is easy to carry
# can peck
# is a siege weapon
# is used in hot air balloons
# uses electricity
# is used for skating
# has fibrous skin
# can be bald
# is made of skin
# is played in groups
# is a cereal
# is used for typing
# can separate food from water
# is eaten by caterpillars
# runs on tracks
# has rounded ears
# has a curvy end
# can have six wheels
# has an orange or yellow beak
# is used to mix eggs
# is a crop
# can produce cider
# has stuffing
# can make butter
# has white speckles
# is hard to get off
# can drag its prey
# can build natural dams
# is made in a brewery
# is a tub
# has a small face
# has a fluffy tail
# is stood on
# has spiked feet
# can strengthen the teeth
# eats shrimp
# has a steering wheel
# is worn on head
# is plush
# is used in ultimate frisbee
# can meow
# is found on the side of head
# comes in different colors
# has depth
# was used to siege castles
# is used to spread
# is a flower
# can fit in the pocket
# can be thick in shape
# is planted
# is orange and yellow in color
# can contain chocolate
# is unsmoked
# has nails
# has laces
# has long arms
# has a joystick
# is a type of coat
# can be found on farms
# can glitter
# can be pushed by the person sitting in it
# can be moored
# is made of tartan
# can carry liquids
# is targeted by pirates
# has a finger loop
# eats grains
# can billow
# can kill people
# has a slot on the head
# has a shade
# has small seeds
# can be used on doors
# does not lay eggs
# can have a belt
# is a canal boat
# does not have seeds
# is luxurious
# requires wind
# lives in small holes
# can be harvested
# can filter
# is airlocked
# can contain fruit flavor
# can be powered by wind
# can stop
# is a gadget
# is an old instrument
# is a monotreme
# has ivory tusks
# can flash
# has a fishy smell
# is reusable
# has cups
# is a symbol of love
# eats from trees
# has orange feet
# is bred
# can protect eyes
# has a yellow and orange beak
# has big eyelashes
# is used in graduation ceremonies
# is used while eating
# is attracted to food
# is a squirrel
# contains bacteria
# is fed to babies
# contains a light source
# can be sweet in taste
# has a long body
# can be eaten raw
# can be rolled
# can have a visor
# is used for touching and feeling
# eats green leaves
# is spherical in shape
# can be used to kill animals
# can be messy to use
# has no arms
# is worn by Muslims
# has pores
# is aimed at targets
# is fragile and delicate
# uses radiation
# can burst
# can have one hump
# can be made of paper
# is a flavor of milk
# can have padding
# tends to be quiet
# has wings
# is a small axe
# can be used to extract things
# can be hit
# can be without a back
# is used to grate cheese
# has attachment points
# has a shell
# has wires and cables
# is a songbird
# can be eaten with honey
# can have inscriptions
# is creamy
# makes a neighing sound
# can be vanilla flavored
# is soft when ripe
# has holes
# is used to push up breasts
# can boil water
# is used in chemistry
# is put on snowmen
# can be warm
# can be long
# is used in forestry
# can be made into juice
# can be caught
# is a preserve
# contains aluminum
# can propel through air
# has a port side
# allows movement
# has a corkscrew
# dries quickly
# is popular at barbecues
# has a soft body
# is paired with forks
# can drain water
# can be tenor
# hides in grass
# contains marrow
# can move
# is planted on the ground
# is a small bird
# has a glossy surface
# is chewy
# is used in an emergency
# can scratch
# has a brown center
# has walls
# can hold or contain liquid
# can be green in color
# is a tree
# facilitates sight
# has capillaries
# is found outdoors
# can be found by swimming pools
# is worn under shoes
# can be crushed
# has tassels
# has a container
# is a small knife
# can crow
# has a thorax
# has antlers
# has an elastic string
# can improve eyesight
# is worn in  a pool
# has a hard exoskeleton
# has eyes
# is a pulse
# has a flat screen
# can contain additives
# can be served with butter
# has yellow eyes
# has pleats
# can get beached
# is a seed
# is picked
# can be blue in color
# is paired with saucers
# can cut flesh
# likes honey
# has a big tail
# has a metal lid
# contains a pearl
# is a bird of prey
# is a part of the human body
# has a cocoon
# is peeled
# can blow in the wind
# can be found on lakes
# is eaten by slugs
# can be made of wool
# has lactose
# has pith
# has an eyeball
# is a citrus fruit
# has a hundred legs
# has sheets
# can be sold in cartons
# can be upholstered
# can be found living in large groups
# has a starboard side
# has floats
# is difficult to balance on
# uses radar
# can swoop down
# can be used while cooking pasta
# buries head in sand
# is footwear
# grows from caterpillars
# lives in a hive
# is attached to the skin
# is kept in a hutch
# can malfunction
# has straps
# is made of ground grain
# can fly backwards
# is extravagant
# can be made of gold
# is sold in a pot
# is wide in middle
# requires a helmet
# is used with screws
# basks in the sun
# holds the body
# fires bullets
# is an ape
# can sniff
# is liked by dogs
# requires coffee beans
# has ventricles
# can be found in the wild
# has bars
# is ironed
# contains credit cards
# is a woodwind instrument
# has a pommel
# can be eaten in strips
# covers legs
# can have papers on it
# has a receiver
# has rockers
# is worn on the legs
# has tubes
# can be noisy
# has black colored seeds
# hunts in packs
# is an insect
# is used to warm food quickly
# is used for skateboarding
# has stamens
# has feathers
# has soft meat
# is pulled by dogs
# snuffles
# is eaten by squirrels
# can be made with raspberries
# can be worn with scarves
# has blue lights
# has thick skin
# can support the body
# has an exoskeleton
# is worn in the kitchen
# can make a squeaky noise
# does not cover much skin
# is addictive
# is a type of ale
# can make a crashing sound
# is used to pull carts
# can climb trees
# uses a drill bit
# can speak
# is used to make chips
# moves back and forth
# is used by photographers
# can sprout
# is a crustacean
# is used in laundromats
# contains fiber
# can crease
# has furry skin
# is a weed
# lives in kennels
# can be found at the hardware store
# is a spade
# is used for hiding
# has two claws
# can be used as a weapon
# can be stubbed
# can be used to blend
# can rub
# contains high cholesterol
# is used by bartenders
# can be used to throw over long distances
# can protect from the sun
# makes big waves
# has acorns
# is commonly consumed in the morning
# can be light brown in color
# has two lines
# can travel long distances
# has shelves
# can be powered by steam
# has a saggy neck
# has prongs
# is eaten with crackers
# can hang from the ceiling
# has multiple tools in it
# can carry objects
# is used to shoot birds
# can walk sideways
# can be used as an alarm
# has thin petals
# has sensitive bones
# can be cold
# has soft wood
# is a type of boat
# carries its young one in its pouch
# is a type of pram
# has a handle
# can open windows
# can affect urine
# has a mast
# is a big seed
# lives in jungles
# has feet
# is wide in shape
# has a big nose
# has big wings
# can be salty in taste
# is decorative
# is not flammable
# can be served from a tap
# has varying resolutions
# uses soap
# can be found in hot climate
# can have long sleeves
# is cutlery
# can have freckles
# can regenerate
# is used for plucking
# has large horns
# can have a wooden frame
# is used to make aspirin
# is a body part
# can charge
# is on Christmas cards
# eats hay
# is played by a drummer
# is used for washing
# can contain leather
# is found in hospitals
# can be red in color
# can be found in restaurants and cafes
# is used at night
# is used to make a drink
# is used in workshops
# has long hair
# can contain decoration
# can be worn for workouts
# made of net
# is a sweetener
# can be used to carry around documents
# is deciduous
# has a pin
# is used for toasting
# can be pinstriped
# can be cooked
# can be skinny
# is a vehicle
# is a plant
# has a pulp
# has a speaker
# eats krill
# is used for pointing
# keeps food fresh
# can become a plague
# can play audio
# can be styled
# has a slim body
# can be made of chainmail
# has two halves
# is made of silver
# is made of elastic
# has buckles
# can be used to chop vegetable
# is a zucchini
# can be made with pears
# has a dagger board
# can make coffee
# has an arrow head
# can be a bunk
# has a shin
# has a keyboard
# can dive underwater
# is used during sickness
# is used in archery
# has a large wingspan
# has big antlers
# has a trunk
# has a shell shape
# has a seat
# has four doors
# is paired with knives
# bruises over time
# has a curved beak
# is a dairy product
# has large rear wheels
# can support spectacles
# can swim
# is a primate
# is violent
# can be filled with jam
# is used in combat
# can be found underground
# can get chapped
# is produced by breasts of mammals
# is eaten by animals
# can go into a sock
# has bedding
# can have green skin
# is used in playing football
# is a flowering plant
# can be pink in color
# is used in supermarkets
# uses water
# is biotic
# has four strings
# can be pumped
# has a horn
# is bowl shaped
# can be used to play hockey
# can be tall
# is dry
# is contained in chocolates
# charges money to travel
# is used for watering
# has good hearing
# has a conductor
# is eaten by birds
# can sieve
# has a base
# is worn on the face
# has a frame
# has yellow petals
# can eat other birds
# is worn on feet
# is used for writing
# is a type of furniture
# requires pedaling
# is worn by humans
# can contain ham
# can be attached to a wall
# produces mucus
# has a sharp point
# is stealthy
# can be found in supermarkets
# is a bed
# can be fished
# has a rope
# can be found at weddings
# is used for writing letters
# can be made of polyester
# has a thin beak
# has a mattress
# can store milk
# can contain dressing
# swims fast
# has purple skin
# is zesty
# is a source of energy
# has a fatal sting
# has a hard surface
# can be made of canvas material
# can be found on tables
# has a green stalk
# gives birth to chicks
# is part of a suit
# can clean utensils
# lays eggs on beach
# likes to be independent
# has cream
# can fly
# has orange flesh
# is worn by horse riders
# can be taken on walks
# made of fibres
# can require electricity
# can be made from berries
# can be viscous
# supports breasts
# eats nuts
# has a zip
# is used to stir
# can be used to eat cereal
# is reclusive
# is poetic
# can be strong in taste
# collects nuts
# has a metal end
# can be found in damp weather
# can have a bottle opener
# is a spear
# can spray harmful scent
# helps an injured person move
# is used by writers
# can be flexible
# is a farming tool
# is bred with roosters
# can be covered in lipstick
# is used to hang things up
# has ridges
# has a phallic shape
# is a gun
# is v-shaped
# traps prey in web
# is part of the circulatory system
# sheds leaves in autumn
# can box
# is used in cakes
# can spin
# makes stops
# has fins
# can throw rocks
# has an optic nerve
# is round in shape
# can be spread on bread
# can be found in boats or ships
# is common in processed food
# has casing
# is used for coffee
# helps chewing
# can glide
# has a hard core
# is used for whipping food
# is a chest of drawers
# is used by builders
# can be used on rough waters
# has an ink ribbon
# is harvested from trees
# can unravel
# eats slugs
# is agile
# eats meat
# is carved
# can be used to wash cars
# is bell shaped
# can survive if cut in half
# can be claustrophobic
# has temperature controls
# can be made using liquid crystal
# keeps its eggs warm by its foot
# is a big boat
# can remove skin
# is worn when cold
# has a yellow center
# can provide shade
# is spiral shaped
# can eat plants
# has condiments
# has three major bones
# can be used to make sandcastles
# stores garbage
# has little flowers
# has babies that are called kids
# is used to hit nails
# is often delivered
# is religious
# has oily glands
# can land
# has fur
# is used for levelling
# can regrow its tail
# is solitary
# can gallop
# prevents escape
# is useful for athletics
# can trample
# has grip tape
# can have a smoky flavor
# has a rotating dish
# is used to carry garden waste
# has a covered deck
# can make holes
# has a flat end
# has black and white stripes
# can be eaten with chips
# is found on the face
# can have candles
# can require batteries
# is worn by goalkeepers
# drinks milk for nourishment
# has a neck
# makes a screeching sound
# can be bootcut
# can come in multiple shapes
# is fired from guns
# is worn by knights
# is a cooking utensil
# is worn on construction sites
# can be covered in lip balm
# is a grain
# can be covered
# can whip cream
# has two shells
# has windows
# has a fur hood
# is a garnish
# is part of casual wear
# protects feet
# can be dextrous
# can be black in color
# is friendly to humans
# has leathery skin
# can chirp
# has hooves
# has patches on its body
# has two nostrils
# has a stumpy tail
# is for a ruler
# contains water
# makes noise with its legs
# can be placed on the floor
# has wheels
# can wrap around the body
# can have jewels on it
# can be golden in color
# is used in snow
# is used to heat bread
# uses sonic waves to communicate
# keeps feet warm
# has a bucket
# has flaky skin
# has a small head
# can protect from spills
# can be used for gambling
# has buds
# is found on pub tables
# can be made with strawberries
# is from the Andes
# can provide water
# eats cheese
# is used for whisking
# has metal blades
# can be fastened
# can contain eggs
# is perishable
# is made of fur
# can be found in seas
# is used by people who cannot walk
# is a popular pet
# requires warm conditions
# can remove corks
# can protect against winds
# has corners
# is found on ships
# can be cut into slices
# can be made of wood and metal
# can have split ends
# has a small beak
# is cut into rings
# has red pulp
# is found on water
# is about 100 microns thick
# is a type of hat
# can be used to fill pools
# is a large deer
# can have hexagonal heads
# can contain foam
# can sneeze
# can tick
# has a jagged edge
# can be carbonated
# has four chambers
# has a sprayer
# turns into a butterfly
# can be made of hair
# contains money
# has a smooth base
# is traditional
# can melt
# can be inflated
# can contain bubbles
# can be spongy
# can hold things in place
# has edible skin
# is a tube
# contains a foot
# is mixed with other drinks
# is feline
# has hard and tough skin
# has curved legs
# is required for movement
# has green leaves
# has colorful feathers
# lives in colonies
# has an arm
# is used by the navy
# is hard to see
# is found in the arctic
# is in a tea bag
# is a type of potato
# can be used to keep pets
# has two blades
# can go into a shoe
# is docile
# can be coated with flavor
# can growl
# is a scooter
# has a pixelated screen
# made of gelatine
# can get knotted
# requires moisture
# can be used to make smoothies
# has a detergent compartment
# is worn by a bride
# is a flatfish
# makes a croaking sound
# can be used with knives
# is used to make cheese
# has an antenna
# can be rectangular in shape
# can blink
# can be used to shape stones
# is a corvid
# moves slowly
# can be made using pottery
# can be found on plants
# can be glucose
# is worn at home
# is a public transportation
# has a symmetrical shape
# is made by boiling fruit
# is made of churned milk
# can prance
# is used to make biscuits
# lays larva
# has inedible skin
# has a cartridge
# grows on a stalk
# can lay eggs
# is played with hands
# is a type of trousers
# can make honey
# can store wine
# is a squash
# is made using butter
# is used on pavements
# contains salt
# can sit
# can prevent separation of things
# has a curly shape
# has thin leaves
# has multiple accessories
# can be made of wood and fabric
# can have a large surface area
# can be squeezed
# contains coins
# can turn into a pupa
# can be posh
# can float in air
# is a water bird
# can store food
# can bite
# has pink ears
# can be white in color
# can be chunky
# can see in the dark
# can be colored
# is eaten by panda bears
# is a part of the body
# can contain hot water
# is a delicacy
# can be grey in color
# is used in desserts
# can be controlled with sticks
# has a mirror
# has a long beak
# has air conditioning
# is a part of the primate body
# can be transparent
# can wriggle
# is found in all vertebrates
# has bank notes
# is moveable
# has a sting in its tail
# has silent flight
# is smoky
# is used on pizza
# can be battered
# can transport goods
# has a canal
# can be found by the fire
# has a stone head
# can be driven by horses
# is used to lick
# can carry salmonella
# follows the sun
# can be listened to
# can be sold frozen
# was used by nobles
# can pierce or impale
# can be made of stone
# can be found in zoos
# uses echolocation
# eats snails
# is used to cover the body
# provides strong wood
# has sails
# can be bright blue in color
# makes a sound when shaken
# is added to tea
# has a red breast
# can eat smaller birds
# has small bones
# has antioxidants
# hunts gazelles and antelopes
# can be found in a dam
# is worn on breasts
# can be attached to a tractor
# is worn by cyclists
# has a sting
# is buoyant
# is rigid
# has puppies
# has a bedroom
# has an electric hook up
# makes grunting sounds
# can be tied
# can be used for breakfast
# is a scavenger
# helps prepare food
# is used to type
# is known to have short memory
# is low-powered
# can have multiple taps
# has a spike
# can fly fast
# has a smooth texture
# is hunted by Orcas
# can migrate
# keeps pets safe
# is made of dead cells
# is screwed
# makes a tapping sound
# eats leaves
# can be used to make drinks
# carries lifeboats
# is used to pull out hair
# is a mobile home
# is low in calories
# has a flat blade
# is used with a screwdriver
# can carry things
# has a crust
# has skin
# can be locked
# is used by performers
# lives in a den
# absorbs water
# can stop sharp objects
# can be added to alcoholic drinks
# can be worn on the shoulder
# swims upstream
# can be black and white in color
# displays minutes
# is swimwear
# can be found on caravan sites
# can contain tomato
# has a tight seal
# can see
# is used for recreation
# is a fruit
# is used at skateparks
# is accompanied with singing
# is yellow and black in color
# can be found in bedrooms
# can hydrate the body
# can be found on driveways
# can house animals
# has two ventricles
# can be healed
# makes a bleating noise
# can cut and chop wood
# is produced by mammals
# can gather in big numbers
# can blow up
# is kicked
# has doors
# contains yeast
# is a receptacle for water
# is common in summer
# has blood vessels
# is wheeled
# has yellow and orange flesh
# has tannins
# has good eyesight
# keeps hands warm
# can pick up food
# has talons
# contains fabric parts
# can be served in tubs
# can be brown in color
# can contain a ring
# is considered friendly
# is controlled
# is a soft drink
# is a small spade
# has big petals
# has a curly tail
# has a jelly like texture
# can be made of leather
# can be found in water
# can be found on arms
# holds liquid
# is a brass instrument
# is hard to kill
# can be made of netting
# is a bomb
# is used for make up
# wears a bridle
# can cut through paper
# can have a triangular shape
# has horns
# can be used for recycling materials
# is used for ploughing
# has a collar
# has seams
# can be made of silk
# is electric
# has a wide back
# can be used to denote numbers
# can have a sidecar
# has propellers
# can live near the water
# is not worn outside
# comes in sticks
# is aerodynamic
# is paired with a nut
# is tube shaped
# is made by bakers
# contains potassium
# has flashing lights
# can have a lid
# can fragment into pieces
# is made with jelly mix
# can store alcohol
# is a sword
# is an animal
# has heating plates
# makes a knocking sound
# has a pulse
# can be silver in color
# lives on the ground
# can hold fruit
# can produce milk
# can be wrapped around the body
# is used to put out a fire
# is a symbol of wealth
# can be thick
# has two wheels
# has skids
# can have kitchen equipment
# can recline
# is used with cutlery
# is used for display
# has fluffy seeds
# has humps
# is used in weddings
# is kept indoors
# is bovine
# has a spout
# has big claws
# can be eaten with bread
# screens programs
# is used in seas
# can be used by armed forces
# can attached to walls
# has no hull
# is an antique
# has two arm rests
# can gnaw
# has a pilot
# is used by plumbers
# is used in cafeterias
# can be used to hide a secret passageway
# can curl up
# is worn on the front
# is used to make risotto
# leaves a trail
# has rings
# can support body weight
# is worn around the waist
# is played sitting down
# is a cephalopod
# is a laxative
# has slimy skin
# can be oily
# is made of sheer fabric
# is part of low diet food
# can contain photos
# can have a rubber band
# has a line in the middle
# can overflow
# is used to throw things
# can erode
# was used in castles
# eats algae
# can be made of fake or real leather
# has pockets
# comes in different varieties
# is silver in color
# can be made of ivory
# slides downhill
# is used for serving punch drinks
# is used to hold small objects
# has edges
# can be kept in a tank
# has spiky skin
# carries two people
# is found in fruit
# is elevated
# is attracted to shiny objects
# is a snack
# can be found in the living room
# has a nose
# can be made of soft fabric
# contains receipts
# is aquatic
# is attached to the wrist
# is diving equipment
# resembles a horse
# can be found on ponds
# has multiple compartments
# has controls
# is made of alcohol
# is a string instrument
# can be made of lace
# is near the lungs
# has a water source
# transports oil
# can be found underwater
# is used in birthdays
# can be driven
# is used to see around corners
# is a reptile
# can spray liquid
# is a snake
# is played by cellists
# is found in airports
# contains carbohydrates
# is a long tube
# can contain alcohol
# can be bought and sold at supermarkets
# can be sold at fairs
# is a container
# contains circuit boards
# reports news
# is made of flesh
# can have a wooden handle
# is pocket sized
# can be made of plastic
# has branches
# can be found in dining rooms
# can be bass
# can have a hearing aid
# has edible seeds
# is involved in movement
# can be used to tidy
# can be bitter in taste
# has valves
# is connected to muscles
# has a tongue
# can live in anthills
# is used by artisans and carpenters
# is streaky
# uses gas
# has a bumpy stalk
# can be made of wood
# hunts seals
# can scrape
# has frilly petals
# has a stretcher
# can hover
# has an ankle
# is a game
# has lights
# can have spots on its body
# has a face
# can be savory
# has an elbow
# has an iris
# is construction material
# can bounce
# is used by clowns
# contains spirit
# has an open top
# has a drain hole
# can last a long time
# has hexagons
# comes in pairs
# can be used to shoot something
# is eaten with wine
# is worn on formal occasions
# has suckers
# is used by farmers
# has a big engine
# can pollinate flowers
# is a freshwater fish
# is common in schools
# displays hours
# is draped
# is used during walking
# is made in a mould
# can be produced by goats
# is controlled by a human
# has pincers
# can play different notes
# requires twisting
# can get muddy
# is a symbol of wisdom
# is often eaten with cream
# can be made of kevlar
# is blind
# can be used to entertain
# has protein
# is made of malt
# has a grip
# can heat water
# is a root vegetable
# can be made of fabric
# can be painted
# has slots for fingers
# has a grill
# has a fanned tail
# is an electronic saw
# can give birth to mules
# has poisonous leaves
# has friendly bacteria
# has a hood
# has a trailer
# is a vulture
# can scuttle
# can be digital
# is used by a puppeteer
# has fingerholes
# is used on hills
# can have red skin
# develops from flowers
# is a thistle
# is good for soil
# is used for grooming hair
# can be used for building and repairing
# can have a bell
# can be filled with custard
# is used while brushing teeth
# is an organ
# is brittle
# has more than four wheels
# can cause tears when chopped
# looks like a ruler
# has technology
# is eaten by cows
# has a bad smell
# has slats
# has a big body
# has colored petals
# has patches
# is found in a harbor
# pumps blood
# has one surface
# is a parrot
# can be made of lycra
# is made of ice
# can be found in burgers
# grows from follicles
# has large jaws
# can cling
# can hiss
# originates in China
# can reproduce quickly
# can be made of heat resistant material
# is connected by strings
# is used by hairdressers and barbers
# is served in a bowl
# has males carry the eggs
# has a screla
# howls at night
# can contain springs
# is used to tighten bolts
# can be spicy and tangy
# can be used to chop
# can make a honking noise
# has a neck strap
# can be curly
# has bark
# has tawny color
# has giant axons
# is used by parents
# can have blankets
# has six sides
# is a type of food
# has a strong flavor
# can have a computer
# maneuvers other boats
# can cause injuries
# has a hard shell
# can be made of metal
# is grown in warm climate
# can be found in parties
# is pressurised
# is biblical
# has a stick
# is made of toweling
# can detect light
# makes a rattling sound
# grows on vines
# is often sold by kids
# can be scary
# can be found on cupboards
# prevents babies from falling
# is played in blues music
# has an extravagant tail
# is pressed
# can roar
# has keys
# has big eyes
# is used by soldiers
# is brown and white in color
# can be found in the toolshed
# has a long face
# can be found in utility rooms
# is indulgent
# can be made of oats
# has webbed feet
# is a small horse
# is a melon
# has bones
# is required for speaking
# can be sold salted
# is used on flowerbeds
# is made of hops
# is flaky
# has waterproof fur
# is sold in crates
# has a thermostat
# can be made of denim
# is eaten with gravy
# is set free at weddings
# can be found in swarms
# has a furry texture
# has dots on its faces
# has two eyes
# can have a stone head
# can be used to make pastries
# makes a bellowing sound
# can be made of wooden planks
# can be found at picnics
# has thorns
# is made of fermented milk
# is solidified
# has yellow flesh
# has two legs for each segment
# has a streamlined body
# has multiple parts
# is pink when cooked
# is made of animal hide
# requires a detergent tablet
# can be flavored
# pulls boats
# can carry leaves
# is shaped like a box
# is pear shaped
# is used by woodcutters
# is a type of bag
# is an allergen
# has black and yellow stripes
# is white in color
# can cut
# is a bird
# is hunted by sealions
# is chopped
# is used to make holes in walls
# can be stuffed
# lives in herds
# has volume control
# can heat food
# can be a residential property
# has a circular head
# is usually taller than wide
# is loyal
# has pipes
# is held in hand
# makes a cawing sound
# has a strong bite
# can be scooped
# made of iron
# can strut
# is sharp
# has cushions
# has four wings
# is used for standing
# is domesticated
# can be bright
# has ball bearings
# is used for boiling
# is used for deliveries
# is blown to play
# has beneficial properties
# can be kept in a bowl
# is powered by air
# breeds rapidly
# is used to clear leaves
# has large teeth
# can have a hem
# can be found in a garage
# cleans dishes
# has waterproof feathers
# is an old tool
# can dig
# can shatter
# is a big spider
# has a striped tail
# likes milk
# is portable
# can be durable
# can quack
# is yellow and brown in color
# has large wheels
# can trot
# can be banned in a drought
# has floppy ears
# can burn
# is used as a shroud
# is usually sat on by old people
# can attract insects
# is used as ammunition
# can pounce
# has long seats
# is used by burglars
# contains air bubbles
# has a curved section
# has froth
# has underwire
# is bought from a butchers
# has cannonballs
# can have a cork
# can carry missiles
# can make you fart
# has a tube
# can be used for sweeping
# contains explosive material
# can be grown
# is green and white in color
# has an arch
# can wag its tail
# has a dreamy sound
# goes through metamorphosis
# is played by an organist
# has a freezer
# is a type of spoon
# consumes planktons
# is used to make crisps
# has a brim
# is a wine
# has a bushy tail
# can fertilize eggs
# has a beaver tail
# can suck blood
# is drunk with food
# is placed in the center of the room
# can swing
# is a sea creature
# can shed tears
# is worn around the neck
# has yellow seeds
# can be bouncy
# is made of hide
# is a herb
# is made in a mill
# can be made of flannel
# is grown in fields
# has a rim
# requires skill to use
# is used to make drugs
# is underwear
# is worn after bath
# has a skirt
# contains sap
# can be spread
# has an eardrum
# is involved in special occasions
# has two feet
# can be used to make bread
# can protect the ears
# has spears
# has a heel
# is made of two slices of bread
# can be a distraction
# can be used to play table tennis
# is soft when cooked
# can be made of ceramic
# is a baby cow
# is a rodent
# is used to catch fish
# can vibrate
# has thick wool
# is plain colored
# is kept in falconries
# is used to hang frames
# contains strings
# is found on a pitch
# was used in medieval warfare
# can beep
# can open
# has seatbelts
# is the largest animal
# has five petals
# can cause destruction
# is used in lab experiments
# is eaten as a steak
# is preyed on by lions
# is brushed
# can be used for resting
# can contain a kitchen
# can hurt
# can be screwed
# can be made of metal and rubber
# adds flavor to food
# has long antenna
# has a wide end
# is used by chefs
# is eaten in salad
# is attached to the scalp
# lives in shoals
# has a long tongue
# is an invertebrate
# is a musical instrument
# has beady eyes
# has a compartment
# spins clothes
# is boiled alive
# is made of cocoa
# lives in a huddle
# can be pyramidal in shape
# is oval shaped
# can flutter
# has leaves
# can be found at orchestras
# is handheld
# returns back
# is used to pull ploughs
# can pollute the environment
# can have metal strings
# makes a humming sound
# can have a label
# has a good sense of smell
# can be baked
# can be made of linen
# has tentacles
# is used by electricians
# has sharp claws
# can have a duvet
# contains seeds
# is made from grapes
# is eaten as pork sausages
# can snap its jaws
# is caught by spiders
# is attached to a finger
# is heated on the stove
# is shimmery
# is hunted by polar bears
# is used to make jam
# can chew through wood
# is kept in a pot
# can be worn by wizards and witches
# is used to wash food
# can stop bullets
# can resonate
# is rhythmic
# is popular at parties
# is made of tissue
# can join things
# resembles a guitar
# is used in string ensembles
# has a sharp blade
# is cuboid in shape
# has chambers
# has a zoom
# is worn to balls
# has a hull
# eats bananas
# can be used for sawing
# has a rudder
# is used to clear garden debris
# can be used to wash dishes
# is used for sweeping
# has legs
# can be found on canals
# can be gifted
# is used in cosmetic products
# can heat
# has a top
# has a flat head
# can toast waffles
# is eaten with eggs
# has projectiles
# is used to make wine
# has a long trunk
# can make raisins
# is sold in bags
# has small leaves
# is thought to be cunning
# is hidden behind skin
# can prevent mess
# is made of pig's meat
# can liquify
# can take part in races
# has belt loops
# has a timer
# is regal
# is porous
# has garden equipment
# has handles at both ends
# is an arachnid
# is green when unripe
# can have a motor
# can be blonde
# is eaten with dips
# can have a radio device
# can be worn with a tie
# can be found in vanity cabinets
# is a small boat
# can crawl
# is a pale grape
# is a military vehicle
# moves food around
# requires sunlight
# can be found on legs
# is semi aquatic
# is a table
# can have flat or curved leaves
# has storage space
# can have a rubber duck inside it
# can have two decks
# can be used in desserts
# can be a source of entertainment
# can be shaved
# has slots for legs
# has a mantle
# can be pulled by animals
# has a basin
# can scald
# comes in two pieces
# has a moustache
# is fine-grained
# has stations
# can make people feel seasick
# can produce classical music
# can maim
# is kept in the freezer
# is nocturnal
# can be cozy
# belongs to the onion family
# is used by lumberjacks
# has weapons
# has a memory card
# is held under the chin
# is played by a violinist
# has a reed
# is worn on upper body
# can have a tap for warm and cold water
# is quick to grow
# has a semi circular shape
# has a flat top
# has three keys
# is speckled
# is dried out
# has a head
# can get congested
# is a chair with wheels
# can be used to tighten
# is a percussion instrument
# can dart around in the air
# makes a howling sound
# is a grape
# is used to make opium
# can hold drinks
# has markings
# has a shaft
# can hang upside down
# is used to sunbathe
# can be aimed
# has thin legs
# is a companion for humans
# can be used for trips
# can be controlled by a hand
# is used to inhale air
# is faster than walking
# can be bad for the teeth
# can be added to cereal
# eats insects
# has cupboards
# has a flat body
# can thicken
# hears through its legs
# can waddle
# can absorb shocks
# eats nectar
# can be made of brass
# can be found in nests
# is a part of smart phones
# is a pipe
# is worn under clothes
# has a luggage area
# grows in winter
# has thick scales
# has powdery texture
# contains identification
# has a long nose
# can hop
# is found in the chest
# is paired with a hat
# is found in grass
# can be plucked
# is a source of media
# is cold blooded
# is a gastropod
# is tangy
# can be used to make furniture
# can be found in shops
# is a tool
# has a viewer
# is also called eggplant
# has a plate
# can be found in factories
# can drool
# can kill
# can carry books
# has black spots
# can walk
# has a sleeping area
# can be used for relaxing
# is attached to a wire
# is a pest
# can squawk
# comes in blocks
# gives birth to ducklings
# is for small animals
# is a small motorbike
# can swivel
# has a tank
# eats fruit
# has bellows
# is served with meat and potatoes
# can jump out of the water
# is crystalline
# has mechanical parts
# can be messy to eat
# contains a knee
# has beds
# can be found near crops
# tows boats
# joins shoulder to hand
# can be found in a kitchen drawer
# can be packed in sachets
# has pentagons
# is used during kissing
# is a ship
# is a horse
# can breed quickly
# is used to trap
# can rip
# is played by music bands
# can be found in caves
# has a spiky skin
# can be added to cake
# is used to conceal
# can be decaffeinated
# can be operated by pirates
# is eaten as beef
# is used to make lemonade
# eats scraps
# can live long
# is an explosive
# is a big fruit
# can be used for announcements
# can eat
# can eat animals
# has a windscreen
# used to have antennas
# has knobs
# is soluble
# has a long tail
# is used by artists and sculptors
# has a cargo hold
# is used by paramedics
# has a hard seed
# can keep rabbits
# eats aphids
# is not a finger
# is frozen
# has white meat
# can unscrew
# has a red crest
# can hurt people
# has a mouth
# has big front teeth
# can contain metal
# has a big seed
# is used with flour
# is paired with a shield
# has bitter skin
# is crunchy
# can have contact lenses
# can have wire mesh
# is cup shaped
# has folded skin
# can be swung
# has leather straps
# can be hit with a hammer
# has an optic disc
# can be toasted
# can damage crops
# is attached to a gun
# has strong teeth
# rinses water
# is semicircular in shape
# can transport people
# can have a orange belly
# can have scratches
# can be used for gardening
# is the size of one's fist
# can provide fitness
# can travel across countries
# shrinks when cooked
# can handle different kinds of coffees
# is used to serve food
# is used for transport
# has thin stems
# contains fish oil
# can be used in pies
# can be used while reading
# can keep the head warm
# has buttons for options
# gives birth to cygnets
# can catch fishes
# is a vessel
# has a chauffeur
# is vermin
# has port holes
# is grainy
# moves slowly on land
# can have a muzzle
# is heart shaped
# can make a whistling noise
# can be fast
# made of wood and bristles
# is a ball
# is caught in lobster pots
# is used in winter
# has sticky grip
# is worn like a shoe
# is used for taking a bath
# has twigs
# is red when ripe
# has layers
# is attached to a tap
# can open cans
# is used during running
# requires tuning
# has a black beak
# is made of cells
# contains fat
# has various styles
# is a predator
# can quench thirst
# is used for heating food
# can keep the body warm
# can eat into objects
# is sturdy
# is found in pubs and bars
# carries food and drinks
# is used for hygiene
# can be shot
# has a large gun
# is a robe
# can be found in the study
# is used in fishing
# has information
# has an uneven surface
# has a safety catch
# has tusks
# is herded by dogs
# is eaten at thanksgiving
# can be launched
# has a stem
# has a strong tail
# has a short life span
# can focus
# can be plump
# comes in flavors
# is used on wood
# has handlebars
# is hit with a stick
# is cooked by baking
# has strong muscles
# has a hole to blow in air
# resembles a human
# has a slot for detergent
# is seasonal
# is baked in ovens
# has a waistband
# is below the eyes
# can be used to make flavored bread
# can be sent in the post
# has seeds on outside
# can fire arrows
# can be used by one person
# is liquid
# can walk long distances
# is orange and black in color
# is used as an ingredient in recipes
# can plough
# can hit people
# can contain croutons
# requires lung power
# has bullets
# has a variety of breeds
# can be rowed
# can be blunt
# can be used on car wheels
# is clunky
# can be made into shapes
# can entertain
# has bells
# has equipment
# grows on cobs
# is used in zoos
# has cuffs
# is a shoe with wheels
# has cones
# can be made with a sock
# has red petals
# is put in muffins
# can get cold
# can cool the body down
# goes well with chicken
# is attracted to sweet things
# can be played
# has a filter
# is fastened at the back
# is a clam
# has a lemony taste
# can pinch
# has a kernel
# can have black spots
# can be added to a hot drink
# has astronauts
# is native to Peru
# has long feathers
# is a big spoon
# has a hollow body
# can ruminate
# is made using flour
# is eaten by Koala bears
# has a black centre
# can be made of steel
# can be bent
# can be sat on
# can be soft
# can stab
# is used for lounging
# can be made of wood and string
# has a siphon
# is found in bathrooms
# is a lizard
# can bray
# has soft wool
# can defrost food
# facilitates speech
# can use milk
# is hung over the fireplace
# is a large vehicle
# can collect nectar
# can have striped patterns
# can be deflated
# can be popped
# is played with drumsticks
# is slimy
# has brown spots
# can print
# is used to strain vegetables
# hides in leaf piles
# is hunted by foxes
# can be lied on
# has keys that are black and white in color
# is green in color
# can rock
# is used in water
# is worn on the lower half of the body
# can cause damage
# is added to coffee
# has brown skin
# can be short
# can be found in the kitchen
# has many pipes
# can climb walls
# is a temporary home
# has a chamber for bullets
# is part of a train
# can be sold with honey flavor
# can be cut
# can crush things
# is a symbol of peace
# has dog food
# is made of fermented grain
# has a towbar
# grows on palm trees
# can pollinate
# has small feet
# has knuckles
# has removable parts
# can be used to play baseball
# is used by doctors
# has many petals
# is a healthy snack
# can be used to make flour
# has a large mouth
# can have a hammer shaped head
# can be sold fresh
# is a type of sock
# is held between the legs
# submerges under water
# is nightwear
# has a big head
# can be messy
# can be fancy
# is useful in moving houses
# has fangs
# has a cuticle
# can be made of waterproof material
# grows on bushes
# makes a cooing sound
# can pout
# is a rooster
# has rough skin
# is rushed
# has a pointy end
# is narrow in shape
# can be used on eyes
# has wax
# has eyelids
# gives birth to joeys
# drags itself along
# is dark in color
# has pink flesh
# can keep the ears warm
# can produce steam
# contains chemicals
# is used by waiters
# has a back rest
# can pull things
# can be used for watering the plants
# is hard when raw
# is played with the mouth
# can seat more than one person
# can resemble a person
# can have rubber parts
# has tail feathers
# adds air to a mixture
# can be environmentally friendly
# has claws with strong grip
# can be unstable
# is eaten by humans
# has a lobe
# is used for watersports
# is yellow in color
# is found in flocks
# can be used to play basketball
# is sold by coffee shops
# has a magazine
# is fermented
# can be sold in packets
# has rotating eyes
# can protect the body
# is made of grapes
# has a hook
# can be flavored with lemon
# is worn on clothes
# can raise attention
# has a ringing sound
# can be found in swamps
# is covered by ribs
# is wound up on a reel
# is used to hold food
# has runners
# can be dressed up
# can be attached to a car
# has a headband
# is kept in fridge
# is used with saucepans
# has a strap
# can protect the head
# has trousers and a jacket
# is streamlined
# is a sensory organ
# has ropes
# can have decorations
# can have three legs
# can have white petals
# has a thin skin
# has a black nose
# is used in the sea
# is light colored
# requires plumbing
# grows in bunches
# comes in cubes
# is a symbol of remembrance
# has a lining
# runs on a wheel
# is a larva
# is played by a harpist
# consumes fabric
# is found in bars
# makes a ribbit sound
# is paired with chairs
# can grate vegetables
# eats left over carcass
# can have its wings clipped
# grows short
# can be eaten dried
# is played with fingers
# is white inside
# can run fast
# can be made of bronze
# can be used as a dip
# is suspended
# is made of curved wires
# can squirt
# can bob its head
# has pink feet
# can hold its breath for long periods of time
# can be shriveled
# is good for bones
# is easy to store
# can contain passengers
# can be recycled
# is used to taste food
# can be orange in color
# is coniferous
# can be eaten with fruit
# beats its chest
# has flippers
# can be used to live in
# is made of wooden logs
# lives in cold water
# has pigments
# can be found in lawns
# has paws
# has a long barrel
# is made at vineyards
# has joints
# requires sieving
# can be frightening
# can be made of polystyrene
# can make loud sounds
# has a flat bottom
# is used to open wine
# can be made of cream
# has a shaped end
# carries one person
# can be made from goat's milk
# is made using dough
# is a poultry bird
# is a mouth organ
# has mucus
# is worn by gymnasts
# can cut through fabric
# can be thin
# has a chain
# is for work
# can be resilient
# can have long fur
# can guard
# uses radio frequencies
# is known to headbutt
# eats carrots
# lives on icebergs
# reverses the image
# can sleep
# can be used for transportation
# has a zip at the back
# has a spiral texture
# is made of calcium carbonate
# is a stick
# has a switch
# is made of small parts
# is a member of the carp family
# can be poisonous
# is used on Christmas pudding
# is used in cold countries
# is stored in brine
# has thick fur
# has small front wheels
# is used by people who smoke
# can be stored in cans or tins
# can be found on motorways
# has gems
# can be difficult to digest
# has a tuner
# can be rickety
# has compartments
# eats
# is distilled
# can tinkle
# is an accessory
# can contain nuts
# can climb
# is overfished
# can be infested by fleas
# pecks trees
# is played by a saxophonist
# has buttons
# is an arthropod
# can hold cigarettes
# has brakes
# can be made from sheep's milk
# has sleeves
# is in the centre of the face
# can be made of cashmere
# has slots for bread
# can be made of fleece
# can carry a lot of people
# lives in a mound
# attaches to rocks
# is played by people in kilts
# has roots
# can be loose
# has radio stations
# can make a hooting sound
# slithers
# does close
# scurries on the ground
# can be made of pyrex
# is found in libraries
# is a hermaphrodite
# can be made of satin
# is used in sauces
# shows films
# is red with black spots
# sits on a perch
# is used for cruises
# has a round end
# has hairy legs
# is sterile
# is a stretched car
# is watched
# can have a ring on it
# can be used by carpenters
# is a digit
# shoots up in the sky
# has pointed ends
# can melt in the mouth
# has a double ended paddle
# is found in circuses
# can be held in the palm
# can be used to play rugby
# is played by pianists
# is a mollusc
# can be found near the toilet
# has fingers
# is used to make cornflakes
# is used by surgeons
# is given on valentines day
# has living areas
# receives and converts signal
# can be attached to an oven
# has thrusters
# can fit in one hand
# is thrown
# is filled with presents during Christmas
# is made of minerals
# is pork
# has a crest
# makes a buzzing sound
# can hold living things
# has petals
# is found in warm waters
# can be made in a teapot
# has ruffles
# can be found on beaches
# has a green case
# can be wobbly
# can be made using a tire
# can be found inside graves
# has a strong recoil
# is had in summer
# is attached to a rope
# can protect the face
# is purple in color
# has a thick body
# is endangered
# can transmit malaria
# has footrests
# is used to make guacamole
# can be found on desks
# is used to rescue people
# is leafy
# can be wholegrain
# can build nests
# follows a route
# has a boot
# has a short tail
# has a prong
# has big ears
# can be dyed
# is used in periscopes
# can rub its wings
# is a symbol of power
# has four legs
# has channels
# is worn by nuns
# can be crowded
# uses warm water
# displays moving images
# has tuning pegs
# can be used to clean floors
# is light when empty
# has sharp blades
# builds nests on the ground
# is manmade
# can be sucrose
# keeps legs warm
# can produce mournful music
# is hunted by whales
# is used in fall
# has teeth
# makes a panting noise
# is a dress
# has slots for cutlery
# can spill oil
# can require cleaning
# can be a trophy
# is found in a cathedral
# lives in a sty
# can hold sand
# can carry more than its weight
# can be found in cellars
# is chunky
# can provide shelter
# is found near tables
# has a duck bill
# can save time
# retracts into its shell
# is played with a bow
# is a parasite
# has a pointed nose
# is a dried plum
# runs on wheels
# can be used as a container
# can be padded with straw and hay
# has grooves
# can be found near a chair
# can be found in large estates
# can have rooms
# can have a lamp
# eats worms
# can be made of ebony
# is worn outdoors
# pecks wood for food
# has a hatch for entering
# has helicopter seeds
# can drill
# can be found in a bottle
# can be found in mountains
# has two hands
# can be found on furry animals
# can help balance the body
# can chip
# contains screws
# requires skill to play
# is made of fruit and sugar
# is used to pull farming equipment
# is worn around hips
# can contain tea
# is a salad vegetable
# can be covered in cloth
# is noticeable
# can survive nuclear attacks
# has a nozzle
# can be topped with flakes
# can contain chicken
# has ancient origins
# is a Christmas tree
# is a toy
# can be filled
# is a wind instrument
# requires fuel to use
# has cogs
# can chop food
# has a high alcohol content
# can scoop
# can filter water
# can be found in barns
# is used during cooking
# is dusty
# can be used to make chilli
# is used to peel vegetables
# is a media device
# is popular in country music
# can come in pieces
# has forelimbs
# eats flies
# contains a spring
# has barbs
# has a lens
# is worn under trousers
# has spirals
# can be robotic
# has a drain
# is a drink
# has low alcohol content
# keeps the body warm in the water
# is cold
# is beachwear
# can chill food
# is known as a squeeze box
# has arm holes
# eats wood
# is affected during a cold
# can contain a waistcoat
# can fire long range
# can detect sounds
# is a small glass ball
# is consumed by licking
# is used on ice
# can be used while watching television
# has a window
# made of wine
# comes in varying lengths
# has strong jaws
# is made of juniper berries
# is used by police
# can serve food on board
# can be tied around the waist
# contains ligament
# is used by surfers and divers
# is used to dig holes
# has a screw-on lid
# is a farm animal
# has a thick stem
# has residents
# has a proboscis
# is a tuber vegetable
# can be made from cow's milk
# is for drawing a straight line
# is connected to a water supply
# can be unsalted
# can have sharp blades
# has spores
# can beat
# is made of dough
# can hold books
# is a dried grape
# can grate
# is eaten by elephants
# is fashionable
# is a raptor
# can get full
# has a periscope
# is crockery
# resembles a tortoise
# grows on trees
# has a flat tail
# is wrapped
# has rods
# can have lice
# is a living thing
# has six legs
# is used for fighting
# has a rind
# can be used while making pasta
# is used in the kitchen
# can be crumbly
# has blubber
# contains stock
# can be filled with cream
# can be found in the playground
# is used on soil
# has a bridge
# is aboriginal
# develops from a tadpole
# can be covered in lip gloss
# is used by dancers
# is used to contain objects
# is good for digestion
# is used to eat food
# is chased by cats
# is drunk in pints
# is pulled by oxen
# can be spread on scones
# is used to make cricket bats
# is worn by businessmen and businesswomen
# is used in ballet
# has two ear covers
# has an aisle
# can be found in houses
# has a cargo container
# can be found in forests
# can be eaten mashed
# has a strong smell
# is a lifeboat
# is used in hospital
# can be made as as espresso
# is calamari
# has a flat surface
# is used for shopping
# has arms
# is a canine
# can be strummed
# can sing
# can be used for drinking
# can explode
# can purr
# comes in different designs
# thumps its feat
# is public transport
# eats vegetables
# is played by musicians
# is aged
# has lumpy skin
# has gills
# has wind blowing through it
# is operated with the hand
# can compress and expand
# can be uncomfortable
# has trotters
# has descended from dinosaurs
# can be used to hunt
# supports the body
# is made of fibula
# can be a pet
# has five toes
# comes in cloves
# is compact in shape
# produces wood
# is shot at high speed
# is hunted by humans
# has a pupil
# has two atria
# is often used when knitting
# is made of keratin
# can avoid traffic jams
# is professional clothing
# can go into wall
# has tastebuds
# can be found in cars
# contains calcium
# requires corkscrew to open
# can be loud
# has a dial
# can contain pastrami
# can fetch ball
# has numbers from one to 12
# has no handlebars
# has an exhaust
# feeds on fish
# is kept in a magazine
# can be used in sandwiches
# has a stand
# can run on nuclear power
# can cling to rocks
# can kick
# can break when dropped
# is seafood
# can be without a brim
# is a marsupial
# has spokes
# is on the foot
# is made of soft fabric
# has turbinates
# can have glasses
# is a flying rodent
# can be cumbersome to move around
# requires ammunition
# can be found in pet shops
# has a cornea
# is used for breaking in
# has a lever
# can be struck by the head
# goes into sheaths
# ...
# is popular with children
# can be made of insulated material
# has a cannon
# has a thick shell
# has a turret
# is used in locks
# emits light
# is connected to tendons
# can be used in tennis
# has racks
# can infect animals
# has a beak
# is muscular
# has a green top
# contains nozzles
# can be made of metal and plastic
# has a shirt
# can be made of fine cloth
# is attached to pipes
# has knives
# can have a kidney shape
# has wrinkled skin
# can make a loud noise
# can have straps
# can be used manually
# is used to pot plants
# travels in an arc
# can have a rough texture
# is red when cooked
# is used to cut grass
# has a sharp beak
# can have one or two floors
# can be tied around the back
# can be pale yellow in color
# can contain cheese
# made of cartilage
# can have a baby seat
# is found at football games
# can be kneaded
# gives birth to piglets
# is kept in a jar
# is made of blood vessels
# transmits messages to the brain
# can sail
# has a screen
# is hunted
# has big nostrils
# eats pet fish food
# can be hard to clean
# is part of the mouth
# has a tight surface
# is eaten with custard
# can slide
# can contain meat
# has rotating blades
# can be found at formal gatherings
# contains vitamins
# can die after stinging
# is gloopy
# has babies that are called cubs
# can be used for napping
# is consumed to celebrate
# has small petals
# can be cream in color
# is used for hearing
# has a bow at the front
# is used to flatten dough
# has a big beak
# looks like a small cabbage
# is used for firewood
# is struck
# can play music
# has three wheels
# has big feet
# can infest
# is used to pluck eyebrows
# is found in the desert
# can be mild in taste
# has pillows
# is contained in icing
# can poke
# has a pink flesh
# were used in mines
# contains oil
# has a strong beak
# is prickly
# is upright while swimming
# is curved in shape
# has a throttle
# has a glass door
# is fished in nets
# is used in jazz music
# is used to loosen bolts
# can be used on a beach
# has hair
# is a source of wood
# does not die when it stings
# is used to carry patients
# can be airborne
# lives in Antarctica
# can have a hot temperature
# has moving parts
# can secure things
# is protective
# is an amphibian
# is brewed
# can be found in dirty restaurants
# is added to easter eggs
# requires balancing
# lives in a stable
# can fall
# can contain vegetables
# has a beard
# has two handles
# is a status symbol
# is used to make peanut butter
# has a long handle
# is used against weeds
# contains feathers
# has scales
# is orange in color
# has pedals
# is a beetle
# likes to chase strings
# can sting repeatedly
# grows from stalks
# can have engravings on it
# can ambush its prey
# is an old version of a piano
# has babies that are called calves
# has hinges
# is produced by distilling wine
# is office wear
# takes time to ripen
# has tires
# can provide support
# is illegal
# is for hand to hand combat
# has wire loops
# can be part of an armor
# is for showing approval
# is an electrical appliance
# is used by physically disabled people
# can peel
# is extinct in the United Kingdom
# is juicy
# can store clothes
# can provide energy
# can measure
# is a weapon
# is used for cigarettes
# is territorial
# can be soundproof
# has long eyelashes
# can have a food bowl
# can press
# has a septum
# is used in chowder
# has a tail
# is used by cavemen
# produces pollen
# is a power tool
# can be wrinkly
# has a tail for balance
# is knee length
# is found in docks
# is used to cut on
# can be found in workspaces
# has short front limbs
# can be found on rivers
# can be used to make cakes
# has cone cells
# is operated by humans
# has two legs
# is a kitchen utensil
# absorbs sweat
# has silver bark
# can be made with a stick
# can be used to communicate
# can fly high
# requires a license
# has rubber tires
# is used on rough terrains
# has edible bones
# can be made of glass
# can be made of cardboard
# can be made of wicker
# can have short sleeves
# has drawers
# has a flap
# has pointy ears
# can be long and thin in shape
# goes up and down
# made of shells
# is mass produced
# can have a star shape at the end
# is a baby sheep
# can cause farting
# has a horn on its nose
# is manned by a crew
# requires two hands to play
# has oars
# has a big shell
# has a sticky tongue
# can be high definition
# can camouflage
# lives in deep waters
# has sharp edges
# is a saw
# can go without drinking water
# has bulbous eyes
# lets you see behind
# is durable
# can be blue and black in color
# requires a power source
# can be made using a kettle
# is used before planting
# can be dangerous
# can sting
# is playful
# can house birds
# is drunk alone
# is used manually
# can help organize schedules
# has one wheel at front and two at back
# can hunt
# is a bottom-dweller
# is made with lemons
# can be used in sports
# is used when putting up shelves
# has eight legs
# is confining
# is slow on roads
# can split items
# is displayed on walls
# is a yam
# is worn on hands
# has hands
# is a limb
# can be colorful
# is a vegetable
# has a curved blade
# is cruel
# can be cooked by boiling
# requires a ticket to board
# has a moving blade
# has baleen
# is smooth on the outside
# is a spirit
# can be a unit of measurement
# can be moist
# can be pasteurised
# is preserved
# has clothes
# can squirt out water
# can be stacked
# is worn after a shower
# eats seeds
# has two rocking legs
# has a shell on its back
# can be served in a cone
# is grown in summer
# has metal cymbals
# has bristles
# uses conditioner
# has arteries
# has a round door
# can be jumped on
# has a center
# keeps food cool
# has a deep sound
# can dry the body
# can capture memories
# is crispy when cooked
# can have objects on top
# can infect pets
# is used for planting
# can be used to play cricket
# can be made from corn
# can contain salami
# contains pastry
# can prevent injury
# performs photosynthesis
# can be made of straw
# is a shellfish
# can be worn on the back
# is a marine animal
# is a dessert
# goes into space
# has a fingerprint
# can be made of blackcurrant
# can hibernate
# is popular in winter
# takes photographs
# has a rich taste
# can clamp
# can contain piercings
# has tracks
# can be used to hit
# can be fluffy
# has a captain
# can be empty
# can bark
# is worn in bed
# collects food
# is between the mouth and eyes
# can be found in dark places
# has dangly bits around its beak
# is fruity
# can wade
# lives in grasslands
# is used in coronations
# has paper
# is attached to the leg
# makes a mooing sound
# can be covered in sprinkles
# is a stimulant
# is purchased in sets
# is played by pressing keys
# is attached to a string
# has several eyes
# is used to strain
# has a crushing bite
# can be made of wheat
# can have a basket
# has a shutter
# can skip traffic lights
# is killed for ivory
# has a flame
# has a nail clipper
# is digital
# is a deer
# is used by criminals
# is diamond shape
# can cut through metal
# is slow on land
# is found on hills
# has long branches
# has a good memory
# can be attached to a plane
# has caffeine
# washes fabrics
# can make you fall
# is used to kill whales
# can have plastic handles
# is made at hot temperatures
# has toes
# is used as bait for fishing
# is a type of jacket
# requires electricity
# is thrust
# can be found on land
# can come in multiple colors
# can be lactose
# is used to harvest
# can rotate its head
# is served at fine-dining restaurants
# attracts bees
# is made of connective tissue
# is emulsified
# has a forked tongue
# can remove nails
# can be found in workshops
# is a utensil
# has two prongs
# contains sugar
# is considered to be proud
# is used for cooking
# is driven on roads
# has a flat beak
# can cut through forrest vegetation
# is used to write
# has a padded ball
# is controlled by computers
# is flammable
# is a herbivore
# has black fur
# can have fruity bits in it
# has a clutch
# can be found in the sewers
# is consumed with tea
# can be found inside buildings
# can be grizzly
# can be blown
# has green flesh
# is used by mechanics
# can be difficult to use
# is pushed with feet
# can protect from harsh weather
# can be made of corduroy
# has a strong back
# can take videos
# can be found in rock pools
# can be made as a cappuccino
# can store sauce
# can taste
# is dried
# is an alternative to showers
# contains juice
# can be used to organize
# can be used to pour things
# looks like a stick
# can be used to bend things
# produces wool
# can make a twangy sound
# has a twitchy nose
# is the leg of a pig
# washes clothes
# can be consumed with ice
# has a wet nose
# has bent legs
# has four wheels
# can be used with toast
# has flavor
# lives under water
# can be used in construction
# is produced by mammary glands
# can have a smooth texture
# is sparkling wine
# can come in bars
# is attracted to light
# is used to cut hay
# can be pitted
# is hunted for its skin
# has a sharp edge
# is an aphrodisiac
# has a heart shaped center
# is worn at bedtime
# has a funnel
# is used on trousers
# provides light
# is for toddlers
# wears shoes
# is sticky
# is used to gather
# can be used to keep clean
# is used in sponge cakes
# is used by firefighters
# can grow
# has an amplifier
# can be sour in taste
# is fizzy
# is used for baking
# has long spines
# has two or more slots
# is a wild flower
# can be grated
# can chew
# can be fair
# has one foot
# is played with
# has a motor
# can rise
# is a machine
# is worn at hospitals
# can be skimmed
# has eight eyes
# has a triangular shape
# can hold things together
# can be infected
# uses microwave radiation
# contains liquid
# has a siren
# lives under rocks
# can be slow
# is found in freshwater
# is eaten as bacon
# has a rotating chamber
# has a bulbous end
# is quick to cook
# is tropical
# has a plug
# is used at tea-time
# can have kittens
# can be found on trees
# is a household item
# has a retina
# does drag along the ground
# has sharp spines
# can be squashy
# has loud sirens
# can float
# can flatten
# has a chin strap
# is dark red in color
# is kept in vinegar
# can be violent
# can wallow
# disperses seeds in the wind
# has a jacket
# contains oil and fat
# is eaten by Inuits and Eskimos
# has a harsh sound
# contains gunpowder
# can be readymade
# has a loud cry
# has a part for thumb
# can contain pasta or noodles
# is peaty
# can be yellow in color
# has dials
# can work in teams
# is used for smelling
# is found in urban areas
# has moist skin
# has a disc shape
# contains a thigh
# has white stripes
# can be used to eat food
# has small horns
# is eaten with a spoon
# is kept in a cage
# is elliptical in shape
# can be tailored
# can be worn
# cannot have metal placed in it
# has velcro
# is composed of florets
# has a hole
# can breathe
# has short hair
# has striped patterns
# is a dried fruit
# can lead to hangovers
# eats dirt
# can be used to guide blind people
# grows from a bulb
# uses hot air currents to fly
# can be stretched
# can contain rodents
# can be made of enamel
# has slots for arms
# is used by hand
# is edged
# is upright
# is used to serve
# has a stock
# has a spade like end
# can contain lettuce
# is used while riding a bike
# has a storage area
# can be ridden
# does jump long distances
# can produce smoke
# contains chlorophyll
# is fired
# has scaly skin
# has big leaves
# can be made from wheat
# is essential
# has structure
# is clapped together
# has waxy skin
# has seeds
# can be served in a cup
# has a tap
# is a type of clothing
# can be found in the north pole
# can be used to give directions
# is pickled
# has compound eyes
# requires water
# has chains
# is shaped like a tree
# has numbers from one to 6
# can fire torpedoes
# prefers muddy water
# has black stripes
# is connected to the body
# can wink
# can drink
# is a firearm
# has a long neck
# comes from grains
# can be found in the tool box
# can be made of wire
# drags its knuckles while walking
# is used to zest a lemon
# is a bike
# was pulled by horses
# is cylindrical in shape
# is worn in winter
# has strong legs
# hatches from a chrysalis
# is used in board games
# has humanlike features
# eats rodents and mice
# can be used for transport
# can damage buildings
# is used for making cake
# is spiky
# is used in church
# is headwear
# can store food in its cheeks
# is a firework
# has a large belly
# can be worn with suspenders
# contains a tibia
# has an anchor
# has armor
# is found on mountain paths
# is concave in shape
# is shorn
# can stain
# is worn with a suit
# has a clasp
# has a smooth skin
# has gears
# can be disposable
# has high amounts of calories
# has a hole in its center
# can be served in a mug
# is reared for veal
# has paddles
# can store chutney
# can scavenge in bins
# is a hot drink
# has a saddle
# is used to raise toast
# has a pouch
# can be found in offices
# can be used on a frying pan
# has atria
# is a pickled cucumber
# is killed by salt
# can soar
# can be eaten cold
# chases balls
# can be served as an appetizer
# is hard to open
# has eight tentacles
# eats rabbits
# has medicinal properties
# contains gluten
# can be found in the pubic region
# is used with a bow
# eats from branches
# is common in developing countries
# has big hind legs
# has strings
# is a small chair
# is found on bedside tables
# is modern
# is a social animal
# can be tied into a knot
# is a staple food
# has a hilt
# is a spider
# is a long car
# is flown
# is shaped like a bulb
# is dark blue
# can be found in fields
# is made from fermented apples
# has patterns on its body
# makes a laughing sound
# can carry diseases
# is grown by planting
# can broadcast
# can cause an itch
# can be found in rivers
# is produced by udders
# can be used to chop meat
# is a medical instrument
# is stored in a barrel
# can be suspended
# can be used to make soup
# is used in moussaka
# is a form of imprisonment
# is used to shape things
# is used during sleeping
# can store water
# can make music
# has wipers
# is eaten by anteaters
# can contain a shower
# goes with spades
# is a fungus
# can be served in a glass
# has an insatiable appetite
# is also called maize
# can go stale
# has one wheel
# is a mammal
# contains vinegar
# can be stored in tins
# has a body
# has arm rests
# is a bivalve
# contains nerves
# can be steamed
# has dark ringed eyes
# can contain fruit
# has a narrow body
# is pulled back
# can be made of plastic and metal
# is a fish
# is steered
# can be found in gardens
# contains a bag
# can be made of nylon
# resembles the letter Y
# is helpful for sore throats
# is a large cat
# can be decorative
# is used in plays
# has a tip which fits the screw
# is warm blooded
# is played in brass bands
# can be used for cleaning
# can be broken
# is an infant
# can lick
# can keep the body dry
# is caught by tickling
# can be found in damp places
# has dots
# is known as the king of the jungle
# is attached to the shoulder
# has bottoms
# is ornamental
# is blocked by nets
# has spines
# requires pulling
# is a home for pet animals
# has a taxi driver
# can build
# can make sounds
# is grown in paddy fields
# can keep pet animals
# has a thick mane
# is used in sushi
# is used to make statues
# is made of coffee beans
# has small legs
# is used for breathing
# can be bland in taste
# has fuzzy skin
# can stand up vertically
# is used to wash
# is kicked into a goal
# is located in the eye socket
# can canter
# has a round head
# can be emptied
# has a wheel
# has a bag of air
# is vital for life
# sheds its skin
# can be made from barley
# is used to dissect
# can melt under heat
# contains tubes
# has a throat pouch
# can be eaten
# has small holes
# has a dorsal fin
# can make you drunk
# is used to cut crops
# has a deck
# is played with a pick
# is used to scrape bowls
# has a high pitch
# is paired with gloves
# is worn with flippers
# can keep babies safe
# can be used to flip food
# can be filled with helium
# has metal bars
# can be used to make tea
# is tightened
# can contain flowers
# can be straight
# has sharp talons
# is red and black in color
# can be used to mix
# has a breastplate
# is worn to interviews
# can spin webs
# is a hard working animal
# can be hazel in color
# can protect against weapons
# can be analog
# can store beer and ale
# is blue in color
# is found in animal body
# lays big eggs
# is inflated with air
# can be used for school trips
# is attached to the hand
# can be tightened with a spanner
# is used to throw stones
# can be used to slice
# is made of muscles
# is found in pods
# can be used to make food
# can be folded
# contains iron
# measures time
# can wake someone up
# is used for eating
# is served with tonic
# has a rotor
# has long legs
# made of animal skin
# has a chest
# has a spiky back
# has bright feathers
# has a brush
# protects the body from the cold
# can be pulled by a tractor
# is ripe in autumn
# can be roasted
# can be acoustic
# has small ears
# has whiskers
# is used for digging
# can be found in cold climate
# is used in agriculture
# guides larger boats
# is an axe
# has ears
# can make puree
# is operated by sailors
# is made up of ingredients
# has a metal frame
# displays numbers
# is often eaten for breakfast
# is part of a drum kit
# is used in baroque music
# can be rented
# has transistors
# can be trained
# is used in water sports
# provides warmth
# can reproduce
# is a fashion accessory
# contains veins
# has a metal head
# has a large center
# is historical
# is used in stews
# is evergreen
# is made of cast iron
# has spiky leaves

# %%
world.feature_space['is domesticated']['positive']
# Out:
# ['guinea_pig',
#  'pigeon',
#  'duck',
#  'horse',
#  'rat',
#  'goose',
#  'lamb',
#  'goat',
#  'chicken',
#  'turkey',
#  'cow',
#  'sheep',
#  'buffalo',
#  'llama',
#  'canary',
#  'mouse',
#  'calf',
#  'cat',
#  'camel',
#  'dove',
#  'budgie',
#  'rabbit',
#  'goldfish',
#  'dog',
#  'donkey',
#  'pig']

# %%
world.concept_features['guitar']
# Out:
# {'can be a source of entertainment',
#  'can be acoustic',
#  'can be bass',
#  'can be connected to an amplifier',
#  'can be loud',
#  'can be made of metal',
#  'can be made of plastic',
#  'can be made of wood',
#  'can be played',
#  'can be plucked',
#  'can be strummed',
#  'can have metal strings',
#  'can have straps',
#  'can make music',
#  'can make sounds',
#  'can play different notes',
#  'can produce classical music',
#  'can require cleaning',
#  'can require electricity',
#  'can resonate',
#  'has a bridge',
#  'has a fretboard',
#  'has a handle',
#  'has a hard surface',
#  'has a hole',
#  'has a hollow body',
#  'has a long neck',
#  'has a neck',
#  'has knobs',
#  'has six strings',
#  'has strings',
#  'has tuning pegs',
#  'is a musical instrument',
#  'is a string instrument',
#  'is curved in shape',
#  'is handheld',
#  'is held in hand',
#  'is manmade',
#  'is played by music bands',
#  'is played by musicians',
#  'is played with a pick',
#  'is played with fingers',
#  'is played with hands',
#  'is portable',
#  'is used in jazz music',
#  'requires skill to play',
#  'requires skill to use',
#  'requires two hands to play'}

# %%
import random
random.seed(42)

# %%
pair = random.sample(candidates, 2)
