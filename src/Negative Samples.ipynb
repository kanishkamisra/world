# %%
import torch

from collections import defaultdict, Counter
from semantic_memory import memory, vsm_utils

# %%
world = memory.Memory(
    concept_path="../data/concept_senses.csv",
    feature_path="../data/xcslb_compressed.csv",
    matrix_path="../data/concept_matrix.txt",
    feature_metadata="../data/feature_lexicon.csv",
)

world.create()
# Out:
# 521it [00:00, 2829.98it/s]

# %%
world.categories['vehicle']
# Out:
# ['bicycle',
#  'buggy',
#  'bus',
#  'car',
#  'caravan',
#  'carriage',
#  'cart',
#  'coach',
#  'glider',
#  'helicopter',
#  'limousine',
#  'lorry',
#  'moped',
#  'motorcycle',
#  'rocket',
#  'sledge',
#  'tank',
#  'taxi',
#  'tractor',
#  'train',
#  'tricycle',
#  'trolley',
#  'truck',
#  'van',
#  'wheelbarrow',
#  'wheelchair',
#  'airplane',
#  'ambulance',
#  'unicycle']

# %%
feature = 'can fly' # target property
n = 1 # number of negative samples

# %%
positives = world.feature_space[feature]['positive']

# %%
# sort negatives by similarity (generalized wup)
# for all negatives, get sims with rest of positive; select 
rest = world.feature_space[feature]['negative']

sims = [world.taxonomy.generalized_wup_sim(positives + [c]) for c in rest]
v, i = torch.topk(torch.tensor(sims), k = n * len(positives))
sampled = [rest[ii] for ii in i]

# %%
sampled
# Out:
# ['yoyo',
#  'rattle',
#  'raft',
#  'doll',
#  'earmuffs',
#  'catapult',
#  'sink',
#  'box',
#  'dice',
#  'puppet',
#  'armor',
#  'peeler',
#  'bin',
#  'chandelier',
#  'basket',
#  'chopping_board',
#  'bag',
#  'hair',
#  'ball',
#  'clamp',
#  'harpoon',
#  'table',
#  'barrel',
#  'basin',
#  'train',
#  'bathtub',
#  'hoe',
#  'jar',
#  'strainer',
#  'chest_of_drawers',
#  'tray',
#  'lamp',
#  'mirror',
#  'caterpillar',
#  'club',
#  'spirit_level',
#  'coach',
#  'drill',
#  'plow',
#  'dresser',
#  'wallet',
#  'sledge',
#  'bolt',
#  'bomb',
#  'rake',
#  'bookcase',
#  'camera',
#  'bottle',
#  'cupboard',
#  'bowl',
#  'worm',
#  'ladle',
#  'cage',
#  'rollerskate']

# %%
world.categories
# Out:
# defaultdict(None,
#             {'animal': ['bat',
#               'bear',
#               'beaver',
#               'buffalo',
#               'calf',
#               'camel',
#               'cat',
#               'cheetah',
#               'chipmunk',
#               'cow',
#               'crocodile',
#               'deer',
#               'dog',
#               'donkey',
#               'fox',
#               'frog',
#               'gerbil',
#               'giraffe',
#               'goat',
#               'gorilla',
#               'guinea_pig',
#               'hamster',
#               'hedgehog',
#               'hippo',
#               'horse',
#               'hyena',
#               'kangaroo',
#               'lamb',
#               'leopard',
#               'lion',
#               'lizard',
#               'llama',
#               'monkey',
#               'moose',
#               'mouse',
#               'panther',
#               'pig',
#               'platypus',
#               'pony',
#               'porcupine',
#               'rabbit',
#               'raccoon',
#               'rat',
#               'rattlesnake',
#               'rhino',
#               'seal',
#               'sheep',
#               'skunk',
#               'squirrel',
#               'tiger',
#               'toad',
#               'tortoise',
#               'wolf',
#               'zebra',
#               'alligator',
#               'elephant',
#               'iguana',
#               'otter',
#               'ox'],
#              'appliance': ['blender',
#               'camera',
#               'coffee_maker',
#               'dishwasher',
#               'kettle',
#               'microwave',
#               'radio',
#               'stove',
#               'television',
#               'toaster',
#               'typewriter',
#               'washing_machine',
#               'oven',
#               'refrigerator'],
#              'bird': ['budgie',
#               'buzzard',
#               'canary',
#               'chicken',
#               'cockerel',
#               'crane',
#               'dove',
#               'duck',
#               'falcon',
#               'flamingo',
#               'goose',
#               'hawk',
#               'heron',
#               'hummingbird',
#               'kingfisher',
#               'magpie',
#               'nightingale',
#               'parakeet',
#               'partridge',
#               'peacock',
#               'pelican',
#               'penguin',
#               'pigeon',
#               'raven',
#               'robin',
#               'seagull',
#               'sparrow',
#               'starling',
#               'swan',
#               'turkey',
#               'woodpecker',
#               'wren',
#               'eagle',
#               'emu',
#               'ostrich',
#               'owl'],
#              'body part': ['bone',
#               'finger',
#               'foot',
#               'hair',
#               'heart',
#               'leg',
#               'lips',
#               'nose',
#               'thumb',
#               'toe',
#               'tongue',
#               'arm',
#               'ear',
#               'eye'],
#              'clothing': ['belt',
#               'bikini',
#               'blouse',
#               'bra',
#               'cap',
#               'cape',
#               'cloak',
#               'coat',
#               'dress',
#               'dressing_gown',
#               'gloves',
#               'gown',
#               'helmet',
#               'jacket',
#               'jeans',
#               'knickers',
#               'leotard',
#               'mitten',
#               'parka',
#               'pajama',
#               'robe',
#               'scarf',
#               'shawl',
#               'shirt',
#               'skirt',
#               'sock',
#               'stocking',
#               'suit',
#               'sweater',
#               'swimsuit',
#               'tights',
#               'trouser',
#               'veil',
#               'wetsuit',
#               'apron',
#               'armor',
#               'earmuffs'],
#              'container': ['bag',
#               'barrel',
#               'basin',
#               'basket',
#               'bathtub',
#               'bin',
#               'bottle',
#               'bowl',
#               'box',
#               'bucket',
#               'cage',
#               'cup',
#               'hutch',
#               'jar',
#               'jug',
#               'mug',
#               'satchel',
#               'sink',
#               'wallet',
#               'ashtray'],
#              'drink': ['beer',
#               'brandy',
#               'champagne',
#               'cider',
#               'coffee',
#               'gin',
#               'lemonade',
#               'tea',
#               'whiskey',
#               'wine'],
#              'fish': ['carp',
#               'cod',
#               'flounder',
#               'goldfish',
#               'herring',
#               'mackerel',
#               'minnow',
#               'salmon',
#               'sardine',
#               'seahorse',
#               'shark',
#               'trout',
#               'tuna',
#               'eel'],
#              'flower': ['buttercup',
#               'carnation',
#               'daffodil',
#               'daisy',
#               'dandelion',
#               'geranium',
#               'hyacinth',
#               'lily',
#               'marigold',
#               'pansy',
#               'poppy',
#               'rose',
#               'sunflower',
#               'tulip',
#               'orchid'],
#              'food': ['bacon',
#               'bread',
#               'butter',
#               'cake',
#               'cheese',
#               'chocolate',
#               'cookie',
#               'currant',
#               'donut',
#               'flour',
#               'gherkin',
#               'ham',
#               'jam',
#               'jelly',
#               'ketchup',
#               'mayonnaise',
#               'milk',
#               'pie',
#               'prune',
#               'raisin',
#               'rice',
#               'sandwich',
#               'soup',
#               'sugar',
#               'sultana',
#               'yoghurt',
#               'ice_cream'],
#              'fruit': ['banana',
#               'blueberry',
#               'cherry',
#               'coconut',
#               'date',
#               'grape',
#               'grapefruit',
#               'kiwi',
#               'lemon',
#               'lime',
#               'mango',
#               'melon',
#               'nectarine',
#               'nut',
#               'peach',
#               'peanut',
#               'pear',
#               'pineapple',
#               'plum',
#               'raspberry',
#               'rhubarb',
#               'satsuma',
#               'strawberry',
#               'tangerine',
#               'watermelon',
#               'apple',
#               'apricot',
#               'orange'],
#              'furniture': ['bed',
#               'bench',
#               'bookcase',
#               'chair',
#               'chandelier',
#               'chest_of_drawers',
#               'clock',
#               'cradle',
#               'cupboard',
#               'deckchair',
#               'desk',
#               'dresser',
#               'lamp',
#               'mirror',
#               'rocking_chair',
#               'sofa',
#               'stool',
#               'table',
#               'throne',
#               'armchair'],
#              'invertebrate': ['bee',
#               'beetle',
#               'butterfly',
#               'caterpillar',
#               'centipede',
#               'cockroach',
#               'cricket',
#               'dragonfly',
#               'flea',
#               'grasshopper',
#               'hornet',
#               'housefly',
#               'ladybird',
#               'locust',
#               'millipede',
#               'mosquito',
#               'moth',
#               'scorpion',
#               'slug',
#               'snail',
#               'spider',
#               'stick_insect',
#               'tarantula',
#               'termite',
#               'wasp',
#               'worm',
#               'ant'],
#              'kitchenware': ['can_opener',
#               'chopping_board',
#               'colander',
#               'corkscrew',
#               'fork',
#               'grater',
#               'ladle',
#               'peeler',
#               'plate',
#               'rolling_pin',
#               'spatula',
#               'spoon',
#               'strainer',
#               'tray',
#               'whisk'],
#              'music': ['bagpipe',
#               'banjo',
#               'castanets',
#               'cello',
#               'clarinet',
#               'cymbal',
#               'drum',
#               'flute',
#               'french_horn',
#               'gong',
#               'guitar',
#               'harmonica',
#               'harp',
#               'harpsichord',
#               'piano',
#               'saxophone',
#               'tambourine',
#               'trombone',
#               'trumpet',
#               'tuba',
#               'violin',
#               'accordion',
#               'organ'],
#              'sea creature': ['clam',
#               'crab',
#               'crayfish',
#               'dolphin',
#               'jellyfish',
#               'lobster',
#               'mussel',
#               'prawn',
#               'scallop',
#               'shrimp',
#               'squid',
#               'turtle',
#               'walrus',
#               'whale',
#               'octopus',
#               'oyster'],
#              'tool': ['bolt',
#               'broom',
#               'chainsaw',
#               'chisel',
#               'clamp',
#               'crowbar',
#               'drill',
#               'hammer',
#               'hatchet',
#               'hoe',
#               'hose',
#               'knife',
#               'machete',
#               'nail',
#               'penknife',
#               'pliers',
#               'plow',
#               'rake',
#               'saw',
#               'scalpel',
#               'scissors',
#               'screw',
#               'screwdriver',
#               'scythe',
#               'shovel',
#               'spade',
#               'spanner',
#               'spirit_level',
#               'trowel',
#               'tweezer',
#               'axe'],
#              'toy': ['ball',
#               'balloon',
#               'boomerang',
#               'dice',
#               'doll',
#               'football',
#               'frisbee',
#               'kite',
#               'marble',
#               'puppet',
#               'rattle',
#               'rollerskate',
#               'skateboard',
#               'swing',
#               'yoyo'],
#              'tree': ['birch',
#               'chestnut',
#               'fir',
#               'pine',
#               'sycamore',
#               'willow',
#               'elm',
#               'eucalyptus',
#               'oak'],
#              'vegetable': ['bean',
#               'broccoli',
#               'brussels_sprout',
#               'cabbage',
#               'carrot',
#               'cauliflower',
#               'celery',
#               'corn',
#               'cucumber',
#               'garlic',
#               'leek',
#               'lettuce',
#               'mushroom',
#               'parsley',
#               'pea',
#               'potato',
#               'pumpkin',
#               'radish',
#               'spinach',
#               'sweet_potato',
#               'tomato',
#               'turnip',
#               'zucchini',
#               'artichoke',
#               'asparagus',
#               'avocado',
#               'eggplant',
#               'olive',
#               'onion'],
#              'vehicle': ['bicycle',
#               'buggy',
#               'bus',
#               'car',
#               'caravan',
#               'carriage',
#               'cart',
#               'coach',
#               'glider',
#               'helicopter',
#               'limousine',
#               'lorry',
#               'moped',
#               'motorcycle',
#               'rocket',
#               'sledge',
#               'tank',
#               'taxi',
#               'tractor',
#               'train',
#               'tricycle',
#               'trolley',
#               'truck',
#               'van',
#               'wheelbarrow',
#               'wheelchair',
#               'airplane',
#               'ambulance',
#               'unicycle'],
#              'water vehicle': ['barge',
#               'boat',
#               'canoe',
#               'dinghy',
#               'ferry',
#               'houseboat',
#               'kayak',
#               'raft',
#               'ship',
#               'speedboat',
#               'submarine',
#               'tugboat',
#               'yacht',
#               'oil_tanker'],
#              'weapon': ['bayonet',
#               'bomb',
#               'bow',
#               'bullet',
#               'cannon',
#               'catapult',
#               'club',
#               'crossbow',
#               'dagger',
#               'grenade',
#               'gun',
#               'harpoon',
#               'pistol',
#               'revolver',
#               'rifle',
#               'shotgun',
#               'spear',
#               'sword',
#               'arrow']})

# %%
world.categories[world.lexicon[positives[0]].category]
# Out:
# ['bicycle',
#  'buggy',
#  'bus',
#  'car',
#  'caravan',
#  'carriage',
#  'cart',
#  'coach',
#  'glider',
#  'helicopter',
#  'limousine',
#  'lorry',
#  'moped',
#  'motorcycle',
#  'rocket',
#  'sledge',
#  'tank',
#  'taxi',
#  'tractor',
#  'train',
#  'tricycle',
#  'trolley',
#  'truck',
#  'van',
#  'wheelbarrow',
#  'wheelchair',
#  'airplane',
#  'ambulance',
#  'unicycle']

# %%
positive_rest = set()
rest = (set(world.concepts) - positive_rest) - set(positives)
for c in positives:
    for cc in world.categories[world.lexicon[c].category]:
        if cc not in positives:
            positive_rest.add(cc)

# %%
sims = [world.taxonomy.generalized_wup_sim(positives + [c]) for c in positive_rest]

# %%
v, i = torch.topk(torch.tensor(sims), k = n * len(positives))
sampled = [positive_rest[ii] for ii in i]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [32], in <cell line: 2>()
#       1 v, i = torch.topk(torch.tensor(sims), k = n * len(positives))
# ----> 2 sampled = [positive_rest[ii] for ii in i]
#
# Input In [32], in <listcomp>(.0)
#       1 v, i = torch.topk(torch.tensor(sims), k = n * len(positives))
# ----> 2 sampled = [positive_rest[ii] for ii in i]
#
# TypeError: 'set' object is not subscriptable

# %%
world.taxonomy.generalized_wup_sim(positives + ['penguin'])
# Out:
# 0.2956989247311828

# %%
world.vectors(positives).max(0).values.unsqueeze(0)
# Out:
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]])

# %%
v, i = vsm_utils.jaccard(world.vectors(positives).max(0).values.unsqueeze(0), world.vectors(rest)).topk(len(positives))

# %%
v
# Out:
# tensor([[0.1366, 0.1335, 0.1308, 0.1307, 0.1261, 0.1250, 0.1230, 0.1215, 0.1199,
#          0.1199, 0.1196, 0.1195, 0.1194, 0.1183, 0.1182, 0.1180, 0.1171, 0.1169,
#          0.1169, 0.1165, 0.1160, 0.1155, 0.1133, 0.1131, 0.1127, 0.1125, 0.1119,
#          0.1119, 0.1113, 0.1113, 0.1109, 0.1109, 0.1107, 0.1107, 0.1107, 0.1107,
#          0.1099, 0.1095, 0.1095, 0.1093, 0.1089, 0.1088, 0.1087, 0.1083, 0.1080,
#          0.1080, 0.1078, 0.1073, 0.1073, 0.1072, 0.1070, 0.1070, 0.1070, 0.1062]])

# %%
[rest[ii] for ii in i[0]]
# Out:
# ['cockerel',
#  'ostrich',
#  'mouse',
#  'penguin',
#  'wolf',
#  'alligator',
#  'squirrel',
#  'tiger',
#  'hyena',
#  'rat',
#  'fox',
#  'emu',
#  'rabbit',
#  'lizard',
#  'lion',
#  'leopard',
#  'kangaroo',
#  'horse',
#  'crocodile',
#  'frog',
#  'cheetah',
#  'chipmunk',
#  'beaver',
#  'hamster',
#  'donkey',
#  'raccoon',
#  'seal',
#  'gorilla',
#  'tortoise',
#  'toad',
#  'bear',
#  'gerbil',
#  'cow',
#  'iguana',
#  'giraffe',
#  'calf',
#  'guinea_pig',
#  'hippo',
#  'llama',
#  'platypus',
#  'lamb',
#  'pony',
#  'monkey',
#  'goat',
#  'camel',
#  'ox',
#  'panther',
#  'sheep',
#  'otter',
#  'elephant',
#  'buffalo',
#  'rhino',
#  'zebra',
#  'cat']

# %%
world.taxonomy.wup_sim('airplane', 'glider')
# Out:
# 0.8461538461538461

# %%
torch.argmax(torch.tensor([0.1, 0.1, 0.1, 0.05]))
# Out:
# tensor(0)

# %%
world.features
# Out:
# ['absorbs sweat',
#  'absorbs water',
#  'adds air to a mixture',
#  'adds flavor to food',
#  'allows movement',
#  'attaches to rocks',
#  'attracts bees',
#  'basks in the sun',
#  'beats its chest',
#  'belongs to the onion family',
#  'breeds rapidly',
#  'bruises over time',
#  'builds nests on the ground',
#  'buries head in sand',
#  'can absorb shocks',
#  'can affect urine',
#  'can ambush its prey',
#  'can attached to walls',
#  'can attract insects',
#  'can avoid traffic jams',
#  'can bark',
#  'can be a bunk',
#  'can be a distraction',
#  'can be a pet',
#  'can be a residential property',
#  'can be a source of entertainment',
#  'can be a trophy',
#  'can be a unit of measurement',
#  'can be acoustic',
#  'can be added to a hot drink',
#  'can be added to alcoholic drinks',
#  'can be added to cake',
#  'can be added to cereal',
#  'can be aimed',
#  'can be airborne',
#  'can be analog',
#  'can be attached to a DVD player',
#  'can be attached to a car',
#  'can be attached to a plane',
#  'can be attached to a tractor',
#  'can be attached to a tree',
#  'can be attached to a wall',
#  'can be attached to an oven',
#  'can be attached to bicycles',
#  'can be bad for the teeth',
#  'can be baked',
#  'can be bald',
#  'can be banned in a drought',
#  'can be bass',
#  'can be battered',
#  'can be bent',
#  'can be bitter in taste',
#  'can be black and white in color',
#  'can be black in color',
#  'can be bland in taste',
#  'can be blonde',
#  'can be blown',
#  'can be blue and black in color',
#  'can be blue in color',
#  'can be blunt',
#  'can be bootcut',
#  'can be bought and sold at supermarkets',
#  'can be bouncy',
#  'can be bright',
#  'can be bright blue in color',
#  'can be broken',
#  'can be brown in color',
#  'can be button shaped',
#  'can be carbonated',
#  'can be caught',
#  'can be chunky',
#  'can be claustrophobic',
#  'can be coated with flavor',
#  'can be cold',
#  'can be colored',
#  'can be colorful',
#  'can be connected to an amplifier',
#  'can be consumed with ice',
#  'can be controlled by a hand',
#  'can be controlled with sticks',
#  'can be cooked',
#  'can be cooked by boiling',
#  'can be covered',
#  'can be covered in chocolate',
#  'can be covered in cloth',
#  'can be covered in lip balm',
#  'can be covered in lip gloss',
#  'can be covered in lipstick',
#  'can be covered in sprinkles',
#  'can be cozy',
#  'can be cream in color',
#  'can be crowded',
#  'can be crumbly',
#  'can be crushed',
#  'can be cumbersome to move around',
#  'can be curly',
#  'can be cut',
#  'can be cut into slices',
#  'can be dangerous',
#  'can be decaffeinated',
#  'can be decorative',
#  'can be deflated',
#  'can be dextrous',
#  'can be difficult to digest',
#  'can be difficult to use',
#  'can be digital',
#  'can be disposable',
#  'can be dressed up',
#  'can be driven',
#  'can be driven by horses',
#  'can be durable',
#  'can be dyed',
#  'can be eaten',
#  'can be eaten cold',
#  'can be eaten dried',
#  'can be eaten in strips',
#  'can be eaten mashed',
#  'can be eaten raw',
#  'can be eaten with bread',
#  'can be eaten with chips',
#  'can be eaten with fruit',
#  'can be eaten with honey',
#  'can be emptied',
#  'can be empty',
#  'can be environmentally friendly',
#  'can be fair',
#  'can be fancy',
#  'can be fast',
#  'can be fastened',
#  'can be filled',
#  'can be filled with cream',
#  'can be filled with custard',
#  'can be filled with helium',
#  'can be filled with jam',
#  'can be filling',
#  'can be fished',
#  'can be flared',
#  'can be flavored',
#  'can be flavored with lemon',
#  'can be flexible',
#  'can be fluffy',
#  'can be folded',
#  'can be found at formal gatherings',
#  'can be found at orchestras',
#  'can be found at picnics',
#  'can be found at the hardware store',
#  'can be found at weddings',
#  'can be found by swimming pools',
#  'can be found by the fire',
#  'can be found in a bottle',
#  'can be found in a dam',
#  'can be found in a garage',
#  'can be found in a kitchen drawer',
#  'can be found in barns',
#  'can be found in bedrooms',
#  'can be found in boats or ships',
#  'can be found in burgers',
#  'can be found in cars',
#  'can be found in caves',
#  'can be found in cellars',
#  'can be found in cold climate',
#  'can be found in damp places',
#  'can be found in damp weather',
#  'can be found in dark places',
#  'can be found in dining rooms',
#  'can be found in dirty restaurants',
#  'can be found in factories',
#  'can be found in fields',
#  'can be found in forests',
#  'can be found in gardens',
#  'can be found in hot climate',
#  'can be found in houses',
#  'can be found in large estates',
#  'can be found in lawns',
#  'can be found in mountains',
#  'can be found in nests',
#  'can be found in offices',
#  'can be found in parties',
#  'can be found in pet shops',
#  'can be found in restaurants and cafes',
#  'can be found in rivers',
#  'can be found in rock pools',
#  'can be found in seas',
#  'can be found in sheds',
#  'can be found in shops',
#  'can be found in supermarkets',
#  'can be found in swamps',
#  'can be found in swarms',
#  'can be found in the kitchen',
#  'can be found in the living room',
#  'can be found in the north pole',
#  'can be found in the playground',
#  'can be found in the pubic region',
#  'can be found in the sewers',
#  'can be found in the study',
#  'can be found in the tool box',
#  'can be found in the toolshed',
#  'can be found in the wild',
#  'can be found in utility rooms',
#  'can be found in vanity cabinets',
#  'can be found in workshops',
#  'can be found in workspaces',
#  'can be found in zoos',
#  'can be found inside buildings',
#  'can be found inside graves',
#  'can be found living in large groups',
#  'can be found near a chair',
#  'can be found near crops',
#  'can be found near garbage dumps',
#  'can be found near the toilet',
#  'can be found on a safari',
#  'can be found on animals',
#  'can be found on arms',
#  'can be found on beaches',
#  'can be found on canals',
#  'can be found on caravan sites',
#  'can be found on cupboards',
#  'can be found on desks',
#  'can be found on driveways',
#  'can be found on farms',
#  'can be found on furry animals',
#  'can be found on lakes',
#  'can be found on land',
#  'can be found on legs',
#  'can be found on motorways',
#  'can be found on plants',
#  'can be found on ponds',
#  'can be found on rivers',
#  'can be found on tables',
#  'can be found on trees',
#  'can be found underground',
#  'can be found underwater',
#  'can be fried',
#  'can be frightening',
#  'can be fructose',
#  'can be gifted',
#  'can be glucose',
#  'can be golden in color',
#  'can be grated',
#  'can be green in color',
#  'can be grey in color',
#  'can be grilled',
#  'can be grizzly',
#  'can be grown',
#  'can be hard to clean',
#  'can be harvested',
#  'can be hazel in color',
#  'can be healed',
#  'can be held in the palm',
#  'can be high definition',
#  'can be hit',
#  'can be hit with a hammer',
#  'can be infected',
#  'can be infested by fleas',
#  'can be inflated',
#  'can be jumped on',
#  'can be kept in a bowl',
#  'can be kept in a tank',
#  'can be kneaded',
#  'can be knitted',
#  'can be lactose',
#  'can be laid on its side',
#  'can be launched',
#  'can be lied on',
#  'can be light brown in color',
#  'can be listened to',
#  'can be locked',
#  'can be long',
#  'can be long and thin in shape',
#  'can be loose',
#  'can be loud',
#  'can be made as a cappuccino',
#  'can be made as as espresso',
#  'can be made from barley',
#  'can be made from berries',
#  'can be made from corn',
#  "can be made from cow's milk",
#  "can be made from goat's milk",
#  "can be made from sheep's milk",
#  'can be made from wheat',
#  'can be made in a teapot',
#  'can be made into juice',
#  'can be made into shapes',
#  'can be made of blackcurrant',
#  'can be made of brass',
#  'can be made of bronze',
#  'can be made of canvas material',
#  'can be made of cardboard',
#  'can be made of cashmere',
#  'can be made of ceramic',
#  'can be made of chainmail',
#  'can be made of corduroy',
#  'can be made of cream',
#  'can be made of denim',
#  'can be made of ebony',
#  'can be made of enamel',
#  'can be made of fabric',
#  'can be made of fake or real leather',
#  'can be made of fine cloth',
#  'can be made of flannel',
#  'can be made of fleece',
#  'can be made of glass',
#  'can be made of gold',
#  'can be made of hair',
#  'can be made of heat resistant material',
#  'can be made of insulated material',
#  'can be made of ivory',
#  'can be made of kevlar',
#  'can be made of lace',
#  'can be made of leather',
#  'can be made of linen',
#  'can be made of lycra',
#  'can be made of metal',
#  'can be made of metal and plastic',
#  'can be made of metal and rubber',
#  'can be made of netting',
#  'can be made of nylon',
#  'can be made of oats',
#  'can be made of paper',
#  'can be made of plastic',
#  'can be made of plastic and metal',
#  'can be made of polyester',
#  'can be made of polystyrene',
#  'can be made of pyrex',
#  'can be made of satin',
#  'can be made of silk',
#  'can be made of soft fabric',
#  'can be made of steel',
#  'can be made of stone',
#  'can be made of straw',
#  'can be made of waterproof material',
#  'can be made of wheat',
#  'can be made of wicker',
#  'can be made of wire',
#  'can be made of wood',
#  'can be made of wood and fabric',
#  'can be made of wood and metal',
#  'can be made of wood and string',
#  'can be made of wooden planks',
#  'can be made of wool',
#  'can be made using a kettle',
#  'can be made using a tire',
#  'can be made using liquid crystal',
#  'can be made using pottery',
#  'can be made with a sock',
#  'can be made with a stick',
#  'can be made with apples',
#  'can be made with pears',
#  'can be made with raspberries',
#  'can be made with strawberries',
#  'can be matured',
#  'can be messy',
#  'can be messy to eat',
#  'can be messy to use',
#  'can be mild in taste',
#  'can be milked by a machine',
#  'can be moist',
#  'can be moored',
#  'can be noisy',
#  'can be oily',
#  'can be operated by pirates',
#  'can be orange in color',
#  'can be packed in sachets',
#  'can be padded with straw and hay',
#  'can be painted',
#  'can be pale yellow in color',
#  'can be part of an armor',
#  'can be pasteurised',
#  'can be pink in color',
#  'can be pinstriped',
#  'can be pitted',
#  'can be placed on the floor',
#  'can be played',
#  'can be plucked',
#  'can be plump',
#  'can be poisonous',
#  'can be pollinated',
#  'can be popped',
#  'can be posh',
#  'can be powered by steam',
#  'can be powered by wind',
#  'can be produced by goats',
#  'can be pulled by a tractor',
#  'can be pulled by animals',
#  'can be pumped',
#  'can be pushed by the person sitting in it',
#  'can be pyramidal in shape',
#  'can be readymade',
#  'can be rectangular in shape',
#  'can be recycled',
#  'can be red in color',
#  'can be refreshing',
#  'can be rented',
#  'can be resilient',
#  'can be rickety',
#  'can be ridden',
#  'can be ridden on paths',
#  'can be roasted',
#  'can be robotic',
#  'can be rolled',
#  'can be rowed',
#  'can be salty in taste',
#  'can be sat on',
#  'can be savory',
#  'can be scary',
#  'can be scooped',
#  'can be screwed',
#  'can be sent in the post',
#  'can be served as an appetizer',
#  'can be served from a tap',
#  'can be served in a cone',
#  'can be served in a cup',
#  'can be served in a glass',
#  'can be served in a mug',
#  'can be served in tubs',
#  'can be served with butter',
#  'can be served with ice cream',
#  'can be shaved',
#  'can be short',
#  'can be shot',
#  'can be shriveled',
#  'can be silver in color',
#  'can be skimmed',
#  'can be skinny',
#  'can be slow',
#  'can be soft',
#  'can be sold at fairs',
#  'can be sold fresh',
#  'can be sold frozen',
#  'can be sold in cartons',
#  'can be sold in packets',
#  'can be sold salted',
#  'can be sold with honey flavor',
#  'can be soundproof',
#  'can be sour in taste',
#  'can be spicy and tangy',
#  'can be spongy',
#  'can be spread',
#  'can be spread on bread',
#  'can be spread on scones',
#  'can be squashy',
#  'can be squeezed',
#  'can be stacked',
#  'can be steamed',
#  'can be stored in cans or tins',
#  'can be stored in tins',
#  'can be straight',
#  'can be stretched',
#  'can be strong in taste',
#  'can be struck by the head',
#  'can be strummed',
#  'can be stubbed',
#  'can be stuffed',
#  'can be styled',
#  'can be sucrose',
#  'can be suspended',
#  'can be sweet in taste',
#  'can be swung',
#  'can be tailored',
#  'can be taken on walks',
#  'can be tall',
#  'can be tenor',
#  'can be thick',
#  'can be thick in shape',
#  'can be thin',
#  'can be tied',
#  'can be tied around the back',
#  'can be tied around the waist',
#  'can be tied into a knot',
#  'can be tightened with a spanner',
#  'can be toasted',
#  'can be topped with flakes',
#  'can be trained',
#  'can be transparent',
#  'can be uncomfortable',
#  'can be unhealthy',
#  'can be unsalted',
#  'can be unstable',
#  'can be upholstered',
#  'can be used as a container',
#  'can be used as a dip',
#  'can be used as a weapon',
#  'can be used as an alarm',
#  'can be used by armed forces',
#  'can be used by babies',
#  'can be used by carpenters',
#  'can be used by one person',
#  'can be used for announcements',
#  'can be used for breakfast',
#  'can be used for building and repairing',
#  'can be used for cleaning',
#  'can be used for drinking',
#  'can be used for frying',
#  'can be used for gambling',
#  'can be used for gardening',
#  'can be used for napping',
#  'can be used for recycling materials',
#  'can be used for relaxing',
#  'can be used for resting',
#  'can be used for sawing',
#  'can be used for school trips',
#  'can be used for storage',
#  'can be used for sweeping',
#  'can be used for transport',
#  'can be used for transportation',
#  'can be used for trips',
#  'can be used for watering the plants',
#  'can be used in construction',
#  'can be used in desserts',
#  'can be used in pies',
#  'can be used in sandwiches',
#  'can be used in sports',
#  'can be used in surgeries',
#  'can be used in tennis',
#  'can be used in toys',
#  'can be used manually',
#  'can be used on a beach',
#  'can be used on a frying pan',
#  'can be used on car wheels',
#  'can be used on doors',
#  'can be used on eyes',
#  'can be used on rough waters',
#  'can be used to bend things',
#  'can be used to blend',
#  'can be used to carry around documents',
#  'can be used to chop',
#  'can be used to chop meat',
#  'can be used to chop vegetable',
#  'can be used to clean floors',
#  'can be used to communicate',
#  'can be used to denote numbers',
#  'can be used to eat cereal',
#  'can be used to eat food',
#  'can be used to entertain',
#  'can be used to extract things',
#  'can be used to fill pools',
#  'can be used to flip food',
#  'can be used to give directions',
#  'can be used to guide blind people',
#  'can be used to hide a secret passageway',
#  'can be used to hit',
#  'can be used to hunt',
#  'can be used to keep clean',
#  'can be used to keep pets',
#  'can be used to kill animals',
#  'can be used to live in',
#  'can be used to make bread',
#  'can be used to make cakes',
#  'can be used to make chilli',
#  'can be used to make drinks',
#  'can be used to make flavored bread',
#  'can be used to make flour',
#  'can be used to make food',
#  'can be used to make furniture',
#  'can be used to make pastries',
#  'can be used to make sandcastles',
#  'can be used to make smoothies',
#  'can be used to make soup',
#  'can be used to make stew',
#  'can be used to make tea',
#  'can be used to mix',
#  'can be used to organize',
#  'can be used to play baseball',
#  'can be used to play basketball',
#  'can be used to play cricket',
#  'can be used to play hockey',
#  'can be used to play rugby',
#  'can be used to play squash',
#  'can be used to play table tennis',
#  'can be used to pour things',
#  'can be used to shape stones',
#  'can be used to shoot something',
#  'can be used to slice',
#  'can be used to throw over long distances',
#  'can be used to tidy',
#  'can be used to tighten',
#  'can be used to wash cars',
#  'can be used to wash dishes',
#  'can be used while cooking pasta',
#  'can be used while making pasta',
#  'can be used while reading',
#  'can be used while watching television',
#  'can be used with knives',
#  'can be used with toast',
#  'can be vanilla flavored',
#  'can be violent',
#  'can be viscous',
#  'can be warm',
#  'can be weighted or biased',
#  'can be white in color',
#  'can be wholegrain',
#  'can be without a back',
#  'can be without a brim',
#  'can be wobbly',
#  'can be worn',
#  'can be worn by wizards and witches',
#  'can be worn for workouts',
#  'can be worn on the back',
#  'can be worn on the shoulder',
#  'can be worn with a tie',
#  'can be worn with cufflinks',
#  'can be worn with scarves',
#  'can be worn with suspenders',
#  'can be woven',
#  'can be wrapped around the body',
#  'can be wrinkly',
#  'can be yellow in color',
#  'can beat',
#  'can become a plague',
#  'can beep',
#  'can billow',
#  'can bite',
#  'can bleed',
#  'can blink',
#  'can block out sunlight',
#  'can blow in the wind',
#  'can blow up',
#  'can bob its head',
#  'can boil water',
#  'can bounce',
#  'can box',
#  'can bray',
#  'can break when dropped',
#  'can breathe',
#  'can breed quickly',
#  'can broadcast',
#  'can build',
#  'can build natural dams',
#  'can build nests',
#  'can burn',
#  'can burst',
#  'can camouflage',
#  'can canter',
#  'can capture memories',
#  'can carry a lot of people',
#  'can carry books',
#  'can carry diseases',
#  'can carry heavy objects',
#  'can carry leaves',
#  'can carry liquids',
#  'can carry missiles',
#  'can carry more than its weight',
#  'can carry objects',
#  'can carry salmonella',
#  'can carry things',
#  'can catch fishes',
#  'can catch things',
#  'can cause an itch',
#  'can cause damage',
#  'can cause destruction',
#  'can cause farting',
#  'can cause injuries',
#  'can cause tears when chopped',
#  'can change its color',
#  'can charge',
#  'can chase',
#  'can chew',
#  'can chew through wood',
#  'can chill food',
#  'can chip',
#  'can chirp',
#  'can choke',
#  'can chop food',
#  'can clamp',
#  'can clean utensils',
#  'can climb',
#  'can climb trees',
#  'can climb walls',
#  'can cling',
#  'can cling to rocks',
#  'can collect nectar',
#  'can come in bars',
#  'can come in granules',
#  'can come in multiple colors',
#  'can come in multiple shapes',
#  'can come in pieces',
#  'can compress and expand',
#  'can contain a kitchen',
#  'can contain a ring',
#  'can contain a shower',
#  'can contain a spring',
#  'can contain a waistcoat',
#  'can contain additives',
#  'can contain alcohol',
#  'can contain bubbles',
#  'can contain cheese',
#  'can contain chicken',
#  'can contain chocolate',
#  'can contain cloth material',
#  'can contain croutons',
#  'can contain decoration',
#  'can contain dressing',
#  'can contain eggs',
#  'can contain flowers',
#  'can contain foam',
#  'can contain fruit',
#  'can contain fruit flavor',
#  'can contain hair',
#  'can contain ham',
#  'can contain hot water',
#  'can contain icing',
#  'can contain leather',
#  'can contain lettuce',
#  'can contain meat',
#  'can contain metal',
#  'can contain milk',
#  'can contain nuts',
#  'can contain passengers',
#  'can contain pasta or noodles',
#  'can contain pastrami',
#  'can contain photos',
#  'can contain piercings',
#  'can contain rodents',
#  'can contain salami',
#  'can contain springs',
#  'can contain tea',
#  'can contain toilets',
#  'can contain tomato',
#  'can contain vegetables',
#  'can cool the body down',
#  'can cover ears',
#  'can crawl',
#  'can crease',
#  'can croak',
#  'can crow',
#  'can crush things',
#  'can curl up',
#  'can cut',
#  'can cut and chop wood',
#  'can cut down trees',
#  'can cut flesh',
#  'can cut through fabric',
#  'can cut through forrest vegetation',
#  'can cut through metal',
#  'can cut through paper',
#  'can damage buildings',
#  'can damage crops',
#  'can dart around in the air',
#  'can defrost food',
#  'can detect light',
#  'can detect sounds',
#  'can detect vibrations',
#  'can die after stinging',
#  'can dig',
#  'can dive underwater',
#  'can drag its prey',
#  'can drain water',
#  'can drill',
#  'can drink',
#  'can drool',
#  'can drown its prey',
#  'can dry the body',
#  'can eat',
#  'can eat animals',
#  'can eat into objects',
#  'can eat other birds',
#  'can eat plants',
#  'can eat smaller birds',
#  'can entertain',
#  'can erode',
#  'can explode',
#  'can fall',
#  'can fertilize eggs',
#  'can fetch ball',
#  'can filter',
#  'can filter water',
#  'can fire arrows',
#  'can fire long range',
#  'can fire projectiles',
#  'can fire torpedoes',
#  'can fit in one hand',
#  'can fit in the pocket',
#  'can flash',
#  'can flatten',
#  'can flick out',
#  'can float',
#  'can float in air',
#  'can flutter',
#  'can fly',
#  'can fly backwards',
#  'can fly fast',
#  'can fly high',
#  'can fly in formation',
#  'can focus',
#  'can fragment into pieces',
#  'can gallop',
#  'can gather in big numbers',
#  'can get beached',
#  'can get chapped',
#  'can get cold',
#  'can get congested',
#  'can get full',
#  'can get knotted',
#  'can get muddy',
#  'can give birth to mules',
#  'can glide',
#  'can glitter',
#  'can gnaw',
#  'can go into a shoe',
#  'can go into a sock',
#  'can go into wall',
#  'can go stale',
#  'can go through corks',
#  'can go without drinking water',
#  'can grate',
#  'can grate vegetables',
#  'can grow',
#  'can growl',
#  'can guard',
#  'can handle different kinds of coffees',
#  'can hang from the ceiling',
#  'can hang upside down',
#  'can have a baby seat',
#  'can have a basket',
#  'can have a bell',
#  'can have a belt',
#  'can have a bin bag',
#  'can have a bottle opener',
#  'can have a computer',
#  'can have a cork',
#  'can have a duvet',
#  'can have a food bowl',
#  'can have a hammer shaped head',
#  'can have a headboard',
#  'can have a hearing aid',
#  'can have a hem',
#  'can have a hot temperature',
#  'can have a kidney shape',
#  'can have a label',
#  'can have a lamp',
#  'can have a large surface area',
#  'can have a lever',
#  'can have a lid',
#  'can have a minibar',
#  'can have a motor',
#  'can have a muzzle',
#  'can have a orange belly',
#  'can have a radio device',
#  'can have a ring on it',
#  'can have a rough texture',
#  'can have a rubber band',
#  'can have a rubber duck inside it',
#  'can have a sidecar',
#  'can have a smoky flavor',
#  'can have a smooth texture',
#  'can have a star shape at the end',
#  'can have a stone head',
#  'can have a tap for warm and cold water',
#  'can have a triangular shape',
#  'can have a visor',
#  'can have a wooden frame',
#  'can have a wooden handle',
#  'can have an attached tap',
#  'can have blankets',
#  'can have cabins',
#  'can have candles',
#  'can have contact lenses',
#  'can have decorations',
#  'can have engravings on it',
#  'can have flat or curved leaves',
#  'can have freckles',
#  'can have fruity bits in it',
#  'can have glasses',
#  'can have green skin',
#  'can have hexagonal heads',
#  'can have inscriptions',
#  'can have its wings clipped',
#  'can have jewels on it',
#  'can have kitchen equipment',
#  'can have kittens',
#  'can have lice',
#  'can have long fur',
#  'can have long sleeves',
#  'can have metal strings',
#  'can have multiple taps',
#  'can have objects on top',
#  'can have one hump',
#  'can have one or two floors',
#  'can have padding',
#  'can have papers on it',
#  'can have plastic handles',
#  'can have red skin',
#  'can have rooms',
#  'can have rough edges',
#  'can have rubber parts',
#  'can have scratches',
#  'can have sharp blades',
#  'can have short sleeves',
#  'can have six wheels',
#  'can have split ends',
#  'can have straps',
#  'can have striped patterns',
#  'can have three legs',
#  'can have two decks',
#  'can have two humps',
#  'can have white petals',
#  'can have wire mesh',
#  'can have yellow skin',
#  'can heat',
#  'can heat food',
#  'can heat water',
#  'can help balance the body',
#  'can help organize schedules',
#  'can hibernate',
#  'can hiss',
#  'can hit people',
#  'can hold ash',
#  'can hold books',
#  'can hold cigarettes',
#  'can hold drinks',
#  'can hold fruit',
#  'can hold its breath for long periods of time',
#  'can hold living things',
#  'can hold or contain liquid',
#  'can hold sand',
#  'can hold things',
#  'can hold things in place',
#  'can hold things together',
#  'can hop',
#  'can house animals',
#  'can house birds',
#  'can hover',
#  'can hunt',
#  'can hurt',
#  'can hurt people',
#  'can hydrate the body',
#  'can improve eyesight',
#  'can infect animals',
#  'can infect pets',
#  'can infest',
#  'can infuse',
#  'can join things',
#  'can jump',
#  'can jump out of the water',
#  'can keep babies safe',
#  'can keep pet animals',
#  'can keep rabbits',
#  'can keep the body dry',
#  'can keep the body warm',
#  'can keep the ears warm',
#  'can keep the head warm',
#  'can kick',
#  'can kill',
#  'can kill people',
#  'can land',
#  'can last a long time',
#  'can lay eggs',
#  'can lead to hangovers',
#  'can lick',
#  'can lift objects',
#  'can liquify',
#  'can live in anthills',
#  'can live long',
#  'can live near the water',
#  'can maim',
#  'can make a clucking noise',
#  'can make a crashing sound',
#  'can make a honking noise',
#  'can make a hooting sound',
#  'can make a loud noise',
#  'can make a squeaky noise',
#  'can make a twangy sound',
#  'can make a whistling noise',
#  'can make butter',
#  'can make coffee',
#  'can make holes',
#  'can make honey',
#  'can make loud sounds',
#  'can make music',
#  'can make people feel seasick',
#  'can make puree',
#  'can make raisins',
#  'can make sounds',
#  'can make surfaces smooth',
#  'can make you drunk',
#  'can make you fall',
#  'can make you fart',
#  'can malfunction',
#  'can measure',
#  'can melt',
#  'can melt in the mouth',
#  'can melt under heat',
#  'can meow',
#  'can migrate',
#  'can mix ingredients',
#  'can move',
#  'can open',
#  'can open cans',
#  'can open windows',
#  'can overflow',
#  'can peck',
#  'can peel',
#  'can pick up food',
#  'can pierce or impale',
#  'can pinch',
#  'can play audio',
#  'can play different notes',
#  'can play music',
#  'can plough',
#  'can poke',
#  ...]

# %%
n = 3
feature = 'can be found in supermarkets'
positives = world.feature_space[feature]['positive']
rest = world.feature_space[feature]['negative']

print(f'POSITIVES: {len(positives)}; NEGATIVES: {len(rest)}')

negatives = []
for concept in positives:
    space = list(set(rest) - set(negatives))
    # get nearest neighbor from rest - concept
    if len(space) > n:
        sims = world.similarity(concept, space)
        vs, idx = torch.topk(sims, n)
        sampled = [space[i] for i in idx.flatten()]
        negatives.extend(sampled)
    else:
        sims = world.similarity(concept, rest)
        vs, idx = torch.topk(sims, n)
        sampled = [rest[i] for i in idx.flatten()]
        negatives.extend(sampled)
# Out:
# POSITIVES: 265; NEGATIVES: 256

# %%
len(negatives)
# Out:
# 795

# %%
len(rest), len(positives)
# Out:
# (256, 54)

# %%
world.similarity(positives[0], rest)
# Out:
# tensor([[0.0612, 0.0355, 0.3269, 0.0068, 0.0072, 0.0183, 0.0168, 0.0614, 0.0654,
#          0.0833, 0.0157, 0.0600, 0.0161, 0.0075, 0.0504, 0.0000, 0.0381, 0.0381,
#          0.0545, 0.0068, 0.0556, 0.2947, 0.0667, 0.0598, 0.0600, 0.0504, 0.0769,
#          0.0227, 0.0278, 0.0210, 0.0583, 0.0084, 0.0194, 0.0632, 0.2667, 0.0182,
#          0.0792, 0.0190, 0.1368, 0.0198, 0.0072, 0.2857, 0.0594, 0.1031, 0.0095,
#          0.0680, 0.0800, 0.0603, 0.0536, 0.0727, 0.0700, 0.0194, 0.0000, 0.0086,
#          0.0079, 0.0326, 0.0156, 0.0642, 0.0278, 0.3529, 0.0777, 0.4839, 0.0084,
#          0.0000, 0.0160, 0.0690, 0.0079, 0.0276, 0.0479, 0.1275, 0.0648, 0.1042,
#          0.1485, 0.0177, 0.0190, 0.4184, 0.3333, 0.0083, 0.0160, 0.3095, 0.0153,
#          0.3049, 0.0583, 0.0270, 0.0541, 0.0165, 0.0163, 0.0082, 0.0556, 0.0159,
#          0.1351, 0.0545, 0.0179, 0.0707, 0.0085, 0.0318, 0.0070, 0.0500, 0.0261,
#          0.0357, 0.0561, 0.0081, 0.0481, 0.0000, 0.0156, 0.0588, 0.0566, 0.0180,
#          0.0918, 0.0729, 0.4583, 0.0168, 0.0414, 0.0231, 0.0208, 0.0227, 0.0000,
#          0.1293, 0.0612, 0.0000, 0.0566, 0.0078, 0.0276, 0.0143, 0.0612, 0.0074,
#          0.0373, 0.0600, 0.0707, 0.0076, 0.0603, 0.0577, 0.0000, 0.0550, 0.0088,
#          0.0762, 0.0082, 0.0083, 0.0071, 0.0654, 0.0303, 0.0588, 0.0625, 0.2323,
#          0.1239, 0.0336, 0.0426, 0.0286, 0.0347, 0.0000, 0.0183, 0.0550, 0.0172,
#          0.0980, 0.0700, 0.0084, 0.0182, 0.0156, 0.0080, 0.0329, 0.0185, 0.0226,
#          0.0185, 0.0163, 0.3789, 0.0082, 0.0174, 0.0161, 0.0092, 0.0566, 0.0078,
#          0.0541, 0.0550, 0.0405, 0.0545, 0.0722, 0.0135, 0.0160, 0.0000, 0.0299,
#          0.0000, 0.0096, 0.0205, 0.0259, 0.0272, 0.0156, 0.0784, 0.0200, 0.0270,
#          0.0139, 0.0128, 0.0748, 0.0865, 0.0214, 0.0642, 0.0849, 0.0177, 0.0000,
#          0.0938, 0.0280, 0.0632, 0.0722, 0.0556, 0.0600, 0.0526, 0.0093, 0.0290,
#          0.0442, 0.0155, 0.0333, 0.0631, 0.0503, 0.0265, 0.2617, 0.0614, 0.0000,
#          0.0338, 0.0083, 0.0205, 0.0167, 0.0000, 0.0598, 0.0180, 0.0000, 0.0175,
#          0.0734, 0.0352, 0.1509, 0.0000, 0.1081, 0.0068, 0.0208, 0.0560, 0.0619,
#          0.0278, 0.0654, 0.0242, 0.0081, 0.0069, 0.0088, 0.0318, 0.0196, 0.0078,
#          0.0087, 0.0069, 0.3402, 0.0321, 0.0095, 0.0414, 0.0432, 0.0214, 0.4494,
#          0.0625, 0.0226, 0.0069, 0.0549, 0.0000, 0.0088, 0.0204, 0.1130, 0.0079,
#          0.0165, 0.0244, 0.0583, 0.0179, 0.0276, 0.0150, 0.3626, 0.3723, 0.0327,
#          0.0690, 0.0150, 0.0160, 0.0721, 0.0068, 0.0083, 0.0154, 0.0180, 0.0216,
#          0.2967, 0.0076, 0.0149, 0.0068, 0.0083, 0.0625, 0.0426, 0.0226, 0.1284,
#          0.0408, 0.0155, 0.0291, 0.0000, 0.0336, 0.0175, 0.0080, 0.0163, 0.0067,
#          0.0150, 0.0138, 0.0588, 0.0274, 0.0541, 0.0693, 0.0000, 0.0210, 0.0174,
#          0.0065, 0.0755, 0.0648, 0.0226, 0.0583, 0.0609, 0.0066, 0.0392, 0.0000,
#          0.0379, 0.0227, 0.0231, 0.0000, 0.0079, 0.0400, 0.0265, 0.0294, 0.1102,
#          0.0156, 0.1800, 0.0000, 0.0367, 0.0071, 0.0268, 0.0549, 0.0299, 0.1121,
#          0.0769, 0.0423, 0.0073, 0.0100, 0.0926, 0.0174, 0.0673, 0.1200, 0.0490,
#          0.0081, 0.0150, 0.0000, 0.0076, 0.0370, 0.0069, 0.0531, 0.0577, 0.0160,
#          0.0577, 0.0174, 0.0594, 0.0312, 0.0631, 0.0545, 0.0550, 0.0231, 0.0268,
#          0.0296, 0.0180, 0.0282, 0.3604, 0.0175, 0.0865, 0.0556, 0.0149, 0.0588,
#          0.1321, 0.0177, 0.0320, 0.3111, 0.0159, 0.0159, 0.0196, 0.0481, 0.0000,
#          0.0609, 0.0532, 0.0526, 0.0734, 0.3000, 0.0242, 0.0082, 0.0377, 0.0508,
#          0.0150, 0.0278, 0.0244, 0.0177, 0.0600, 0.1313, 0.0583, 0.0067, 0.2941,
#          0.0088, 0.0254, 0.0000, 0.0000, 0.0192, 0.0157, 0.0172, 0.0957, 0.0541,
#          0.0189, 0.0594, 0.0667, 0.0067, 0.3933, 0.0152, 0.4062, 0.0000, 0.0992,
#          0.0325, 0.0625, 0.0083, 0.0380, 0.0190, 0.0139, 0.1081, 0.0084, 0.0071,
#          0.0095, 0.0282, 0.3438, 0.5750, 0.0792, 0.2674, 0.3625, 0.0566, 0.0180,
#          0.0159, 0.0526, 0.4886, 0.0571, 0.0566, 0.2292, 0.0000, 0.0221, 0.0240,
#          0.0292, 0.0472, 0.1383, 0.2584, 0.4831, 0.0189, 0.0556, 0.0374, 0.0299,
#          0.1186, 0.0133, 0.0167, 0.0376, 0.2418, 0.2772, 0.0541, 0.0085, 0.0174,
#          0.0085, 0.0387, 0.0169, 0.2788, 0.0088, 0.0606, 0.0350, 0.0076]])

# %%
world.verbalize('airplane', 'can fly')
# Out:
# 'an airplane can fly.'
