# %%
import csv
import spacy

# %%
nlp = spacy.load("en_core_web_sm")

# %%
feature_metadata = []
with open('../data/feature_metadata.csv', 'r') as f:
    reader = csv.DictReader(f)
    for line in reader:
        print(line)
# Out:
# {'phrase': 'has keys', 'feature_type': 'visual perceptual'}
# {'phrase': 'is a musical instrument', 'feature_type': 'taxonomic'}
# {'phrase': 'can make music', 'feature_type': 'functional'}
# {'phrase': 'can be loud', 'feature_type': 'other perceptual'}
# {'phrase': 'can make loud sounds', 'feature_type': 'other perceptual'}
# {'phrase': 'can be noisy', 'feature_type': 'other perceptual'}
# {'phrase': 'has buttons', 'feature_type': 'visual perceptual'}
# {'phrase': 'can be played', 'feature_type': 'functional'}
# {'phrase': 'can make sounds', 'feature_type': 'other perceptual'}
# {'phrase': 'can be made of wood', 'feature_type': 'visual perceptual'}
# {'phrase': 'produces wood', 'feature_type': 'visual perceptual'}
# {'phrase': 'has bellows', 'feature_type': 'visual perceptual'}
# {'phrase': 'is known as a squeeze box', 'feature_type': 'taxonomic'}
# {'phrase': 'is used in folk music', 'feature_type': 'functional'}
# {'phrase': 'can be made of metal', 'feature_type': 'visual perceptual'}
# {'phrase': 'can contain metal', 'feature_type': 'visual perceptual'}
# {'phrase': 'requires skill to play', 'feature_type': 'encyclopedic'}
# {'phrase': 'can compress and expand', 'feature_type': 'visual perceptual'}
# {'phrase': 'is powered by air', 'feature_type': 'encyclopedic'}
# {'phrase': 'has a handle', 'feature_type': 'visual perceptual'}
# {'phrase': 'can have straps', 'feature_type': 'visual perceptual'}
# {'phrase': 'can be black and white in color', 'feature_type': 'visual perceptual'}
# {'phrase': 'is black and white in color', 'feature_type': 'visual perceptual'}
# {'phrase': 'is handheld', 'feature_type': 'functional'}
# {'phrase': 'can play different notes', 'feature_type': 'functional'}
# {'phrase': 'has french origins', 'feature_type': 'encyclopedic'}
# {'phrase': 'can be heavy', 'feature_type': 'other perceptual'}
# {'phrase': 'can contain leather', 'feature_type': 'visual perceptual'}
# {'phrase': 'can be made of leather', 'feature_type': 'visual perceptual'}
# {'phrase': 'can be made of plastic', 'feature_type': 'visual perceptual'}
# {'phrase': 'can fly', 'feature_type': 'functional'}
# {'phrase': 'has wings', 'feature_type': 'visual perceptual'}
# {'phrase': 'can transport people', 'feature_type': 'functional'}
# {'phrase': 'can be used for transportation', 'feature_type': 'functional'}
# {'phrase': 'can carry things', 'feature_type': 'functional'}
# {'phrase': 'can carry objects', 'feature_type': 'functional'}
# {'phrase': 'has an engine', 'feature_type': 'visual perceptual'}
# {'phrase': 'contains aluminum', 'feature_type': 'visual perceptual'}
# {'phrase': 'has a pilot', 'feature_type': 'encyclopedic'}
# {'phrase': 'has a seat', 'feature_type': 'visual perceptual'}
# {'phrase': 'has wheels', 'feature_type': 'visual perceptual'}
# {'phrase': 'is used for transport', 'feature_type': 'taxonomic'}
# {'phrase': 'can be used for transport', 'feature_type': 'taxonomic'}
# {'phrase': 'has windows', 'feature_type': 'visual perceptual'}
# {'phrase': 'can travel across countries', 'feature_type': 'encyclopedic'}
# {'phrase': 'has a cockpit', 'feature_type': 'visual perceptual'}
# {'phrase': 'can be fast', 'feature_type': 'visual perceptual'}
# {'phrase': 'can fly fast', 'feature_type': 'visual perceptual'}
# {'phrase': 'can land', 'feature_type': 'functional'}
# {'phrase': 'can pollute the environment', 'feature_type': 'functional'}
# {'phrase': 'has a tail', 'feature_type': 'visual perceptual'}
# {'phrase': 'is aerodynamic', 'feature_type': 'encyclopedic'}
# {'phrase': 'is streamlined', 'feature_type': 'encyclopedic'}
# {'phrase': 'is flown', 'feature_type': 'encyclopedic'}
# {'phrase': 'is found in airports', 'feature_type': 'encyclopedic'}
# {'phrase': 'can be white in color', 'feature_type': 'visual perceptual'}
# {'phrase': 'can transport goods', 'feature_type': 'functional'}
# {'phrase': 'has a luggage area', 'feature_type': 'encyclopedic'}
# {'phrase': 'has a nose', 'feature_type': 'visual perceptual'}
# {'phrase': 'has propellers', 'feature_type': 'visual perceptual'}
# {'phrase': 'has technology', 'feature_type': 'encyclopedic'}
# {'phrase': 'is a vehicle', 'feature_type': 'taxonomic'}
# {'phrase': 'is manmade', 'feature_type': 'encyclopedic'}
# {'phrase': 'is modern', 'feature_type': 'encyclopedic'}
# {'phrase': 'can be used by armed forces', 'feature_type': 'functional'}
# {'phrase': 'has teeth', 'feature_type': 'visual perceptual'}
# {'phrase': 'can be found in water', 'feature_type': 'encyclopedic'}
# {'phrase': 'has scales', 'feature_type': 'visual perceptual'}
# {'phrase': 'is a reptile', 'feature_type': 'taxonomic'}
# {'phrase': 'is green in color', 'feature_type': 'visual perceptual'}
# {'phrase': 'can be green in color', 'feature_type': 'visual perceptual'}
# {'phrase': 'can have sharp teeth', 'feature_type': 'visual perceptual'}
# {'phrase': 'is an animal', 'feature_type': 'taxonomic'}
# {'phrase': 'can swim', 'feature_type': 'functional'}
# {'phrase': 'has a long tail', 'feature_type': 'visual perceptual'}
# {'phrase': 'can be dangerous', 'feature_type': 'encyclopedic'}
# {'phrase': 'has legs', 'feature_type': 'visual perceptual'}
# {'phrase': 'eats meat', 'feature_type': 'functional'}
# {'phrase': 'has eyes', 'feature_type': 'visual perceptual'}
# {'phrase': 'has small legs', 'feature_type': 'visual perceptual'}
# {'phrase': 'can eat', 'feature_type': 'functional'}
# {'phrase': 'is used for eating', 'feature_type': 'functional'}
# {'phrase': 'can lay eggs', 'feature_type': 'encyclopedic'}
# {'phrase': 'has a large mouth', 'feature_type': 'visual perceptual'}
# {'phrase': 'has a mouth', 'feature_type': 'visual perceptual'}
# {'phrase': 'is a predator', 'feature_type': 'taxonomic'}
# {'phrase': 'can bite', 'feature_type': 'functional'}
# {'phrase': 'can peck', 'feature_type': 'functional'}
# {'phrase': 'can kill people', 'feature_type': 'functional'}
# {'phrase': 'has a strong tail', 'feature_type': 'visual perceptual'}
# {'phrase': 'has large jaws', 'feature_type': 'visual perceptual'}
# {'phrase': 'has large teeth', 'feature_type': 'visual perceptual'}
# {'phrase': 'has claws', 'feature_type': 'visual perceptual'}
# {'phrase': 'can be scary', 'feature_type': 'encyclopedic'}
# {'phrase': 'can eat animals', 'feature_type': 'functional'}
# {'phrase': 'can hunt', 'feature_type': 'functional'}
# {'phrase': 'can kill', 'feature_type': 'functional'}
# {'phrase': 'has a long nose', 'feature_type': 'visual perceptual'}
# {'phrase': 'has four legs', 'feature_type': 'visual perceptual'}
# {'phrase': 'has skin', 'feature_type': 'visual perceptual'}
# {'phrase': 'is made of skin', 'feature_type': 'visual perceptual'}
# {'phrase': 'is made of hide', 'feature_type': 'visual perceptual'}
# {'phrase': 'can be violent', 'feature_type': 'encyclopedic'}
# {'phrase': 'is found in america', 'feature_type': 'encyclopedic'}
# {'phrase': 'can breathe', 'feature_type': 'functional'}
# {'phrase': 'is used for breathing', 'feature_type': 'functional'}
# {'phrase': 'can move', 'feature_type': 'functional'}
# {'phrase': 'can be brown in color', 'feature_type': 'visual perceptual'}
# {'phrase': 'is cold blooded', 'feature_type': 'encyclopedic'}
# {'phrase': 'is found in freshwater', 'feature_type': 'encyclopedic'}
# {'phrase': 'is hunted for its skin', 'feature_type': 'functional'}
# {'phrase': 'is stealthy', 'feature_type': 'encyclopedic'}
# {'phrase': 'basks in the sun', 'feature_type': 'encyclopedic'}
# {'phrase': 'can drag its prey', 'feature_type': 'encyclopedic'}
# {'phrase': 'can drown its prey', 'feature_type': 'encyclopedic'}
# {'phrase': 'feeds on fish', 'feature_type': 'functional'}
# {'phrase': 'can ambush its prey', 'feature_type': 'encyclopedic'}
# {'phrase': 'can be found in rivers', 'feature_type': 'encyclopedic'}
# {'phrase': 'can be found in swamps', 'feature_type': 'encyclopedic'}
# {'phrase': 'can be found on land', 'feature_type': 'encyclopedic'}
# {'phrase': 'has a crushing bite', 'feature_type': 'functional'}
# {'phrase': 'has feet', 'feature_type': 'visual perceptual'}
# {'phrase': 'has strong jaws', 'feature_type': 'visual perceptual'}
# {'phrase': 'has small feet', 'feature_type': 'visual perceptual'}
# {'phrase': 'has thick scales', 'feature_type': 'visual perceptual'}
# {'phrase': 'has thick skin', 'feature_type': 'visual perceptual'}
# {'phrase': 'has yellow eyes', 'feature_type': 'visual perceptual'}
# {'phrase': 'is an amphibian', 'feature_type': 'taxonomic'}
# {'phrase': 'can camouflage', 'feature_type': 'visual perceptual'}
# {'phrase': 'is endangered', 'feature_type': 'encyclopedic'}
# {'phrase': 'can be found in zoos', 'feature_type': 'encyclopedic'}
# {'phrase': 'is used in zoos', 'feature_type': 'encyclopedic'}
# {'phrase': 'can be slow', 'feature_type': 'visual perceptual'}
# {'phrase': 'can be found in the wild', 'feature_type': 'encyclopedic'}
# {'phrase': 'has a siren', 'feature_type': 'other perceptual'}
# {'phrase': 'is used in an emergency', 'feature_type': 'functional'}
# {'phrase': 'has lights', 'feature_type': 'visual perceptual'}
# {'phrase': 'is used by paramedics', 'feature_type': 'encyclopedic'}
# {'phrase': 'is found in hospitals', 'feature_type': 'functional'}
# {'phrase': 'has flashing lights', 'feature_type': 'visual perceptual'}
# {'phrase': 'has medical equipment', 'feature_type': 'encyclopedic'}
# {'phrase': 'is an emergency vehicle', 'feature_type': 'taxonomic'}
# {'phrase': 'is used to rescue people', 'feature_type': 'functional'}
# {'phrase': 'has four wheels', 'feature_type': 'visual perceptual'}
# {'phrase': 'is used to carry patients', 'feature_type': 'functional'}
# {'phrase': 'has blue lights', 'feature_type': 'visual perceptual'}
# {'phrase': 'has equipment', 'feature_type': 'encyclopedic'}
# {'phrase': 'can be driven', 'feature_type': 'functional'}
# {'phrase': 'can skip traffic lights', 'feature_type': 'encyclopedic'}
# {'phrase': 'is essential', 'feature_type': 'encyclopedic'}
# {'phrase': 'is rushed', 'feature_type': 'encyclopedic'}
# {'phrase': 'has a stretcher', 'feature_type': 'visual perceptual'}
# {'phrase': 'has loud sirens', 'feature_type': 'other perceptual'}
# {'phrase': 'is driven on roads', 'feature_type': 'functional'}
# {'phrase': 'has beds', 'feature_type': 'encyclopedic'}
# {'phrase': 'has a steering wheel', 'feature_type': 'visual perceptual'}
# {'phrase': 'can be bright', 'feature_type': 'visual perceptual'}
# {'phrase': 'can have rubber parts', 'feature_type': 'visual perceptual'}
# {'phrase': 'is an insect', 'feature_type': 'taxonomic'}
# {'phrase': 'has six legs', 'feature_type': 'visual perceptual'}
# {'phrase': 'lives in colonies', 'feature_type': 'encyclopedic'}
# {'phrase': 'can be black in color', 'feature_type': 'visual perceptual'}
# {'phrase': 'can be red in color', 'feature_type': 'visual perceptual'}
# {'phrase': 'has an antenna', 'feature_type': 'visual perceptual'}
# {'phrase': 'is durable', 'feature_type': 'encyclopedic'}
# {'phrase': 'is sturdy', 'feature_type': 'encyclopedic'}
# {'phrase': 'can be strong in taste', 'feature_type': 'encyclopedic'}
# {'phrase': 'has strong muscles', 'feature_type': 'encyclopedic'}
# {'phrase': 'has a tough surface', 'feature_type': 'encyclopedic'}
# {'phrase': 'can be found in nests', 'feature_type': 'functional'}
# {'phrase': 'can build nests', 'feature_type': 'functional'}
# {'phrase': 'can crawl', 'feature_type': 'functional'}
# {'phrase': 'has a body', 'feature_type': 'visual perceptual'}
# {'phrase': 'has a segmented body', 'feature_type': 'visual perceptual'}
# {'phrase': 'is a social animal', 'feature_type': 'encyclopedic'}
# {'phrase': 'eats leaves', 'feature_type': 'functional'}
# {'phrase': 'can carry more than its weight', 'feature_type': 'functional'}
# {'phrase': 'can be found underground', 'feature_type': 'encyclopedic'}
# {'phrase': 'has a queen', 'feature_type': 'encyclopedic'}
# {'phrase': 'collects food', 'feature_type': 'functional'}
# {'phrase': 'can live in anthills', 'feature_type': 'encyclopedic'}
# {'phrase': 'can sting', 'feature_type': 'other perceptual'}
# {'phrase': 'can work in teams', 'feature_type': 'functional'}
# {'phrase': 'has a head', 'feature_type': 'visual perceptual'}
# {'phrase': 'has an exoskeleton', 'feature_type': 'visual perceptual'}
# {'phrase': 'has pincers', 'feature_type': 'visual perceptual'}
# {'phrase': 'is a hard working animal', 'feature_type': 'encyclopedic'}
# {'phrase': 'is a living thing', 'feature_type': 'encyclopedic'}
# {'phrase': 'can carry leaves', 'feature_type': 'functional'}
# {'phrase': 'has a thorax', 'feature_type': 'visual perceptual'}
# {'phrase': 'is a pest', 'feature_type': 'encyclopedic'}
# {'phrase': 'is an arthropod', 'feature_type': 'taxonomic'}
# {'phrase': 'is eaten by anteaters', 'feature_type': 'functional'}
# {'phrase': 'can be poisonous', 'feature_type': 'encyclopedic'}
# {'phrase': 'is made of cells', 'feature_type': 'encyclopedic'}
# {'phrase': 'is a fruit', 'feature_type': 'taxonomic'}
# {'phrase': 'grows on trees', 'feature_type': 'encyclopedic'}
# {'phrase': 'contains seeds', 'feature_type': 'visual perceptual'}
# {'phrase': 'can grow', 'feature_type': 'functional'}
# {'phrase': 'grows on a stalk', 'feature_type': 'visual perceptual'}
# {'phrase': 'has a stem', 'feature_type': 'visual perceptual'}
# {'phrase': 'is round in shape', 'feature_type': 'visual perceptual'}
# {'phrase': 'has a center', 'feature_type': 'encyclopedic'}
# {'phrase': 'has flavor', 'feature_type': 'other perceptual'}
# {'phrase': 'is peeled', 'feature_type': 'visual perceptual'}
# {'phrase': 'can be eaten', 'feature_type': 'functional'}
# {'phrase': 'is juicy', 'feature_type': 'other perceptual'}
# {'phrase': 'is crunchy', 'feature_type': 'other perceptual'}
# {'phrase': 'can be sweet in taste', 'feature_type': 'other perceptual'}
# {'phrase': 'contains vitamins', 'feature_type': 'encyclopedic'}
# {'phrase': 'can be sour in taste', 'feature_type': 'other perceptual'}
# {'phrase': 'has a pulp', 'feature_type': 'visual perceptual'}
# {'phrase': 'is made of flesh', 'feature_type': 'visual perceptual'}
# {'phrase': 'has a glossy surface', 'feature_type': 'visual perceptual'}
# {'phrase': 'can come in multiple colors', 'feature_type': 'visual perceptual'}
# {'phrase': 'can produce cider', 'feature_type': 'functional'}
# {'phrase': 'contains fiber', 'feature_type': 'encyclopedic'}
# {'phrase': 'is a type of food', 'feature_type': 'taxonomic'}
# {'phrase': 'can be refreshing', 'feature_type': 'other perceptual'}
# {'phrase': 'can be used in pies', 'feature_type': 'functional'}
# {'phrase': 'has a hard seed', 'feature_type': 'visual perceptual'}
# {'phrase': 'is used to throw stones', 'feature_type': 'visual perceptual'}
# {'phrase': 'can be orange in color', 'feature_type': 'visual perceptual'}
# {'phrase': 'is dried', 'feature_type': 'visual perceptual'}
# {'phrase': 'can be yellow in color', 'feature_type': 'visual perceptual'}
# {'phrase': 'has a furry texture', 'feature_type': 'visual perceptual'}
# {'phrase': 'can be soft', 'feature_type': 'other perceptual'}
# {'phrase': 'is made of soft fabric', 'feature_type': 'other perceptual'}
# {'phrase': 'is soft', 'feature_type': 'other perceptual'}
# {'phrase': 'is used to make jam', 'feature_type': 'functional'}
# {'phrase': 'is grown in warm climate', 'feature_type': 'encyclopedic'}
# {'phrase': 'can be used in desserts', 'feature_type': 'functional'}
# {'phrase': 'is used in desserts', 'feature_type': 'functional'}
# {'phrase': 'has edible skin', 'feature_type': 'encyclopedic'}
# {'phrase': 'can be eaten dried', 'feature_type': 'functional'}
# {'phrase': 'can be made of fabric', 'feature_type': 'visual perceptual'}
# {'phrase': 'contains fabric parts', 'feature_type': 'visual perceptual'}
# {'phrase': 'is protective', 'feature_type': 'functional'}
# {'phrase': 'can be used during cooking', 'feature_type': 'functional'}
# {'phrase': 'can be cooked', 'feature_type': 'functional'}
# {'phrase': 'is used for cooking', 'feature_type': 'functional'}
# {'phrase': 'is used during cooking', 'feature_type': 'functional'}
# {'phrase': 'can be worn', 'feature_type': 'functional'}
# {'phrase': 'has straps', 'feature_type': 'visual perceptual'}
# {'phrase': 'has strings', 'feature_type': 'visual perceptual'}
# {'phrase': 'contains strings', 'feature_type': 'visual perceptual'}
# {'phrase': 'is worn on clothes', 'feature_type': 'functional'}
# {'phrase': 'has compartments', 'feature_type': 'visual perceptual'}
# {'phrase': 'can be found in the kitchen', 'feature_type': 'encyclopedic'}
# {'phrase': 'can be tied', 'feature_type': 'functional'}
# {'phrase': 'is a type of clothing', 'feature_type': 'taxonomic'}
# {'phrase': 'can be used to keep clean', 'feature_type': 'functional'}
# {'phrase': 'has a neck strap', 'feature_type': 'visual perceptual'}
# {'phrase': 'can protect from spills', 'feature_type': 'functional'}
# {'phrase': 'can be tied around the back', 'feature_type': 'functional'}
# {'phrase': 'is worn on the front', 'feature_type': 'visual perceptual'}
# {'phrase': 'can contain pictures', 'feature_type': 'visual perceptual'}
# {'phrase': 'is used by women', 'feature_type': 'functional'}
# {'phrase': 'is used by chefs', 'feature_type': 'functional'}
# {'phrase': 'is used to cover the body', 'feature_type': 'functional'}
# {'phrase': 'can be colorful', 'feature_type': 'visual perceptual'}
# {'phrase': 'can get dirty', 'feature_type': 'visual perceptual'}
# {'phrase': 'lives in dirty environments', 'feature_type': 'visual perceptual'}
# {'phrase': 'can prevent mess', 'feature_type': 'functional'}
# {'phrase': 'has pockets', 'feature_type': 'encyclopedic'}
# {'phrase': 'can be tied around the waist', 'feature_type': 'visual perceptual'}
# {'phrase': 'can have striped patterns', 'feature_type': 'visual perceptual'}
# {'phrase': 'has striped patterns', 'feature_type': 'visual perceptual'}
# {'phrase': 'is attached to the hand', 'feature_type': 'visual perceptual'}
# {'phrase': 'is a body part', 'feature_type': 'taxonomic'}
# {'phrase': 'is made of muscles', 'feature_type': 'encyclopedic'}
# {'phrase': 'is muscular', 'feature_type': 'encyclopedic'}
# {'phrase': 'has an elbow', 'feature_type': 'visual perceptual'}
# {'phrase': 'is a limb', 'feature_type': 'taxonomic'}
# {'phrase': 'has blood vessels', 'feature_type': 'encyclopedic'}
# {'phrase': 'is attached to the shoulder', 'feature_type': 'visual perceptual'}
# {'phrase': 'can lift objects', 'feature_type': 'functional'}
# {'phrase': 'comes in pairs', 'feature_type': 'visual perceptual'}
# {'phrase': 'has hair', 'feature_type': 'visual perceptual'}
# {'phrase': 'has joints', 'feature_type': 'visual perceptual'}
# {'phrase': 'allows movement', 'feature_type': 'functional'}
# {'phrase': 'can be bent', 'feature_type': 'other perceptual'}
# {'phrase': 'is attached to the wrist', 'feature_type': 'visual perceptual'}
# {'phrase': 'contains fat', 'feature_type': 'encyclopedic'}
# {'phrase': 'contains veins', 'feature_type': 'encyclopedic'}
# {'phrase': 'is a part of the human body', 'feature_type': 'encyclopedic'}
# {'phrase': 'can be flexible', 'feature_type': 'other perceptual'}
# {'phrase': 'is connected to the body', 'feature_type': 'encyclopedic'}
# {'phrase': 'can be thin', 'feature_type': 'visual perceptual'}
# {'phrase': 'is made of tissue', 'feature_type': 'encyclopedic'}
# {'phrase': 'joins shoulder to hand', 'feature_type': 'functional'}
# {'phrase': 'has fingers', 'feature_type': 'visual perceptual'}
# {'phrase': 'has slots for fingers', 'feature_type': 'visual perceptual'}
# {'phrase': 'contains ligament', 'feature_type': 'visual perceptual'}
# {'phrase': 'has three major bones', 'feature_type': 'encyclopedic'}
# {'phrase': 'can be robotic', 'feature_type': 'encyclopedic'}
# {'phrase': 'is a part of the primate body', 'feature_type': 'encyclopedic'}
# {'phrase': 'can be short', 'feature_type': 'visual perceptual'}
# {'phrase': 'is concise', 'feature_type': 'visual perceptual'}
# {'phrase': 'is skin colored', 'feature_type': 'visual perceptual'}
# {'phrase': 'is involved in movement', 'feature_type': 'functional'}
# {'phrase': 'contains nerves', 'feature_type': 'encyclopedic'}
# {'phrase': 'has arm rests', 'feature_type': 'visual perceptual'}
# {'phrase': 'has arms', 'feature_type': 'visual perceptual'}
# {'phrase': 'has slots for arms', 'feature_type': 'visual perceptual'}
# {'phrase': 'has mechanical arms', 'feature_type': 'visual perceptual'}
# {'phrase': 'has cushions', 'feature_type': 'visual perceptual'}
# {'phrase': 'can be sat on', 'feature_type': 'functional'}
# {'phrase': 'has a back rest', 'feature_type': 'visual perceptual'}
# {'phrase': 'is a type of furniture', 'feature_type': 'taxonomic'}
# {'phrase': 'can be found in the living room', 'feature_type': 'encyclopedic'}
# {'phrase': 'can be used for relaxing', 'feature_type': 'encyclopedic'}
# {'phrase': 'can have padding', 'feature_type': 'visual perceptual'}
# {'phrase': 'can be cozy', 'feature_type': 'other perceptual'}
# {'phrase': 'carries one person', 'feature_type': 'functional'}
# {'phrase': 'can be used by one person', 'feature_type': 'functional'}
# {'phrase': 'can contain springs', 'feature_type': 'visual perceptual'}
# {'phrase': 'can be found by the fire', 'feature_type': 'encyclopedic'}
# {'phrase': 'can be used while reading', 'feature_type': 'functional'}
# {'phrase': 'can recline', 'feature_type': 'functional'}
# {'phrase': 'can be covered', 'feature_type': 'visual perceptual'}
# {'phrase': 'has two arm rests', 'feature_type': 'visual perceptual'}
# {'phrase': 'is usually sat on by old people', 'feature_type': 'encyclopedic'}
# {'phrase': 'can take up a lot of space', 'feature_type': 'visual perceptual'}
# {'phrase': 'can be used for napping', 'feature_type': 'functional'}
# {'phrase': 'can be used while watching television', 'feature_type': 'functional'}
# {'phrase': 'can be found in houses', 'feature_type': 'encyclopedic'}
# {'phrase': 'can be squashy', 'feature_type': 'other perceptual'}
# {'phrase': 'can be upholstered', 'feature_type': 'encyclopedic'}
# {'phrase': 'can keep the body warm', 'feature_type': 'other perceptual'}
# {'phrase': 'can provide warmth', 'feature_type': 'other perceptual'}
# {'phrase': 'can contain foam', 'feature_type': 'visual perceptual'}
# {'phrase': 'is used in combat', 'feature_type': 'functional'}
# {'phrase': 'can stop bullets', 'feature_type': 'functional'}
# {'phrase': 'is worn by knights', 'feature_type': 'encyclopedic'}
# {'phrase': 'has a hard surface', 'feature_type': 'other perceptual'}
# {'phrase': 'has multiple parts', 'feature_type': 'encyclopedic'}
# {'phrase': 'can stop sharp objects', 'feature_type': 'functional'}
# {'phrase': 'can be made of chainmail', 'feature_type': 'visual perceptual'}
# {'phrase': 'has a breastplate', 'feature_type': 'visual perceptual'}
# {'phrase': 'can be made of kevlar', 'feature_type': 'visual perceptual'}
# {'phrase': 'has a helmet', 'feature_type': 'visual perceptual'}
# {'phrase': 'is used by soldiers', 'feature_type': 'functional'}
# {'phrase': 'can protect against weapons', 'feature_type': 'functional'}
# {'phrase': 'can protect the body', 'feature_type': 'functional'}
# {'phrase': 'has ancient origins', 'feature_type': 'encyclopedic'}
# {'phrase': 'was used by nobles', 'feature_type': 'encyclopedic'}
# {'phrase': 'can be silver in color', 'feature_type': 'visual perceptual'}
# {'phrase': 'is used with a bow', 'feature_type': 'functional'}
# {'phrase': 'has a pointy end', 'feature_type': 'visual perceptual'}
# {'phrase': 'is sharp', 'feature_type': 'other perceptual'}
# {'phrase': 'has a sharp blade', 'feature_type': 'other perceptual'}
# {'phrase': 'has sharp blades', 'feature_type': 'other perceptual'}
# {'phrase': 'is a weapon', 'feature_type': 'taxonomic'}
# {'phrase': 'can be used as a weapon', 'feature_type': 'taxonomic'}
# {'phrase': 'is fired', 'feature_type': 'functional'}
# {'phrase': 'can be used to give directions', 'feature_type': 'functional'}
# {'phrase': 'contains feathers', 'feature_type': 'visual perceptual'}
# {'phrase': 'has feathers', 'feature_type': 'visual perceptual'}
# {'phrase': 'is used for pointing', 'feature_type': 'functional'}
# {'phrase': 'can hurt', 'feature_type': 'functional'}
# {'phrase': 'can propel through air', 'feature_type': 'functional'}
# {'phrase': 'is aimed at targets', 'feature_type': 'functional'}
# {'phrase': 'is used in archery', 'feature_type': 'functional'}
# {'phrase': 'can be used to kill animals', 'feature_type': 'functional'}
# {'phrase': 'has a shaft', 'feature_type': 'visual perceptual'}
# {'phrase': 'has projectiles', 'feature_type': 'functional'}
# {'phrase': 'can be aimed', 'feature_type': 'functional'}
# {'phrase': 'can be straight', 'feature_type': 'visual perceptual'}
# {'phrase': 'has a stone head', 'feature_type': 'visual perceptual'}
# {'phrase': 'can pierce or impale', 'feature_type': 'functional'}
# {'phrase': 'can be used in toys', 'feature_type': 'taxonomic'}
# {'phrase': 'is a toy', 'feature_type': 'taxonomic'}
# {'phrase': 'can be used to hunt', 'feature_type': 'functional'}
# {'phrase': 'is a vegetable', 'feature_type': 'taxonomic'}
# {'phrase': 'has a heart shaped center', 'feature_type': 'encyclopedic'}
# {'phrase': 'has leaves', 'feature_type': 'visual perceptual'}
# {'phrase': 'can be grown', 'feature_type': 'functional'}
# {'phrase': 'has layers', 'feature_type': 'visual perceptual'}
# {'phrase': 'is a flower', 'feature_type': 'visual perceptual'}
# {'phrase': 'is a plant', 'feature_type': 'taxonomic'}
# {'phrase': 'is eaten in salad', 'feature_type': 'functional'}
# {'phrase': 'is purple in color', 'feature_type': 'visual perceptual'}
# {'phrase': 'can be found in supermarkets', 'feature_type': 'encyclopedic'}
# {'phrase': 'requires water', 'feature_type': 'encyclopedic'}
# {'phrase': 'uses water', 'feature_type': 'encyclopedic'}
# {'phrase': 'can reproduce', 'feature_type': 'functional'}
# {'phrase': 'has petals', 'feature_type': 'visual perceptual'}
# {'phrase': 'has roots', 'feature_type': 'visual perceptual'}
# {'phrase': 'has seeds', 'feature_type': 'visual perceptual'}
# {'phrase': 'is a thistle', 'feature_type': 'encyclopedic'}
# {'phrase': 'can be cooked by boiling', 'feature_type': 'functional'}
# {'phrase': 'can be bitter in taste', 'feature_type': 'other perceptual'}
# {'phrase': 'is spiky', 'feature_type': 'visual perceptual'}
# {'phrase': 'is used on pizza', 'feature_type': 'functional'}
# {'phrase': 'can be made of glass', 'feature_type': 'visual perceptual'}
# {'phrase': 'can hold ash', 'feature_type': 'functional'}
# {'phrase': 'is used for cigarettes', 'feature_type': 'functional'}
# {'phrase': 'is used to contain objects', 'feature_type': 'functional'}
# {'phrase': 'has a strong smell', 'feature_type': 'other perceptual'}
# {'phrase': 'is used by people who smoke', 'feature_type': 'functional'}
# {'phrase': 'is found in pubs and bars', 'feature_type': 'encyclopedic'}
# {'phrase': 'can hold cigarettes', 'feature_type': 'visual perceptual'}
# {'phrase': 'can be made of ceramic', 'feature_type': 'visual perceptual'}
# {'phrase': 'can be found on tables', 'feature_type': 'encyclopedic'}
# {'phrase': 'is not flammable', 'feature_type': 'encyclopedic'}
# {'phrase': 'has a base', 'feature_type': 'visual perceptual'}
# {'phrase': 'is found on pub tables', 'feature_type': 'encyclopedic'}
# {'phrase': 'can be rectangular in shape', 'feature_type': 'visual perceptual'}
# {'phrase': 'can be made of stone', 'feature_type': 'visual perceptual'}
# {'phrase': 'can have a stone head', 'feature_type': 'visual perceptual'}
# {'phrase': 'is planted on the ground', 'feature_type': 'encyclopedic'}
# {'phrase': 'can affect urine', 'feature_type': 'encyclopedic'}
# {'phrase': 'has spears', 'feature_type': 'visual perceptual'}
# {'phrase': 'can be long and thin in shape', 'feature_type': 'visual perceptual'}
# {'phrase': 'can be served with butter', 'feature_type': 'encyclopedic'}
# {'phrase': 'is grown in summer', 'feature_type': 'encyclopedic'}
# {'phrase': 'is common in summer', 'feature_type': 'encyclopedic'}
# {'phrase': 'is had in summer', 'feature_type': 'encyclopedic'}
# {'phrase': 'is popular in England and United Kingdom', 'feature_type': 'encyclopedic'}
# {'phrase': 'is seasonal', 'feature_type': 'encyclopedic'}
# {'phrase': 'is soft when cooked', 'feature_type': 'encyclopedic'}
# {'phrase': 'has a bumpy stalk', 'feature_type': 'visual perceptual'}
# {'phrase': 'is an aphrodisiac', 'feature_type': 'functional'}
# {'phrase': 'is white inside', 'feature_type': 'visual perceptual'}
# {'phrase': 'is also called eggplant', 'feature_type': 'taxonomic'}
# {'phrase': 'is used in moussaka', 'feature_type': 'functional'}
# {'phrase': 'is grown by planting', 'feature_type': 'encyclopedic'}
# {'phrase': 'has a green stalk', 'feature_type': 'visual perceptual'}
# {'phrase': 'is smooth on the outside', 'feature_type': 'other perceptual'}
# {'phrase': 'is used in stews', 'feature_type': 'functional'}
# {'phrase': 'is chopped', 'feature_type': 'functional'}
# {'phrase': 'is dark in color', 'feature_type': 'visual perceptual'}
# {'phrase': 'can be fried', 'feature_type': 'functional'}
# {'phrase': 'has hard and tough skin', 'feature_type': 'visual perceptual'}
# {'phrase': 'has a big seed', 'feature_type': 'visual perceptual'}
# {'phrase': 'is used to make guacamole', 'feature_type': 'functional'}
# {'phrase': 'contains oil and fat', 'feature_type': 'encyclopedic'}
# {'phrase': 'is not popular in England and United Kingdom', 'feature_type': 'encyclopedic'}
# {'phrase': 'is pear shaped', 'feature_type': 'visual perceptual'}
# {'phrase': 'goes well with chicken', 'feature_type': 'encyclopedic'}
# {'phrase': 'takes time to ripen', 'feature_type': 'functional'}
# {'phrase': 'is used as an ingredient in recipes', 'feature_type': 'taxonomic'}
# {'phrase': 'has an uneven surface', 'feature_type': 'visual perceptual'}
# {'phrase': 'is mushy', 'feature_type': 'visual perceptual'}
# {'phrase': 'has a smooth texture', 'feature_type': 'other perceptual'}
# {'phrase': 'can have a smooth texture', 'feature_type': 'other perceptual'}
# {'phrase': 'has a smooth skin', 'feature_type': 'other perceptual'}
# {'phrase': 'can be used to chop', 'feature_type': 'functional'}
# {'phrase': 'can cut and chop wood', 'feature_type': 'functional'}
# {'phrase': 'can be made of wood and metal', 'feature_type': 'visual perceptual'}
# {'phrase': 'is used to cut', 'feature_type': 'functional'}
# {'phrase': 'has metal blades', 'feature_type': 'visual perceptual'}
# {'phrase': 'is a tool', 'feature_type': 'taxonomic'}
# {'phrase': 'can cut down trees', 'feature_type': 'functional'}
# {'phrase': 'can have a wooden handle', 'feature_type': 'visual perceptual'}
# {'phrase': 'can be swung', 'feature_type': 'functional'}
# {'phrase': 'is used by woodcutters', 'feature_type': 'functional'}
# {'phrase': 'can split items', 'feature_type': 'functional'}
# {'phrase': 'is edged', 'feature_type': 'visual perceptual'}
# {'phrase': 'has two blades', 'feature_type': 'visual perceptual'}
# {'phrase': 'is chunky', 'feature_type': 'encyclopedic'}
# {'phrase': 'can be pink in color', 'feature_type': 'visual perceptual'}
# {'phrase': 'is pink in color', 'feature_type': 'visual perceptual'}
# {'phrase': "is made of pig's meat", 'feature_type': 'encyclopedic'}
# {'phrase': 'is eaten as meat', 'feature_type': 'functional'}
# {'phrase': 'is often eaten for breakfast', 'feature_type': 'functional'}
# {'phrase': 'can have a smoky flavor', 'feature_type': 'other perceptual'}
# {'phrase': 'is pork', 'feature_type': 'functional'}
# {'phrase': 'is streaky', 'feature_type': 'visual perceptual'}
# {'phrase': 'can be salty in taste', 'feature_type': 'other perceptual'}
# {'phrase': 'can be used in sandwiches', 'feature_type': 'functional'}
# {'phrase': 'can be eaten in strips', 'feature_type': 'visual perceptual'}
# {'phrase': 'can be grilled', 'feature_type': 'functional'}
# {'phrase': 'is preserved', 'feature_type': 'encyclopedic'}
# {'phrase': 'can be unhealthy', 'feature_type': 'encyclopedic'}
# {'phrase': 'is crispy when cooked', 'feature_type': 'other perceptual'}
# {'phrase': 'is unsmoked', 'feature_type': 'other perceptual'}
# {'phrase': 'is eaten with eggs', 'feature_type': 'functional'}
# {'phrase': 'has a rind', 'feature_type': 'visual perceptual'}
# {'phrase': 'is quick to cook', 'feature_type': 'functional'}
# {'phrase': 'can be cut into slices', 'feature_type': 'functional'}
# {'phrase': 'is used for shopping', 'feature_type': 'functional'}
# {'phrase': 'has a zip', 'feature_type': 'visual perceptual'}
# {'phrase': 'is fashionable', 'feature_type': 'encyclopedic'}
# {'phrase': 'can be used as a container', 'feature_type': 'taxonomic'}
# {'phrase': 'is reusable', 'feature_type': 'encyclopedic'}
# {'phrase': 'is portable', 'feature_type': 'functional'}
# {'phrase': 'can be worn on the shoulder', 'feature_type': 'functional'}
# {'phrase': 'can be made of paper', 'feature_type': 'visual perceptual'}
# {'phrase': 'can be used for storage', 'feature_type': 'functional'}
# {'phrase': 'is an accessory', 'feature_type': 'taxonomic'}
# {'phrase': 'can be disposable', 'feature_type': 'encyclopedic'}
# {'phrase': 'can hold books', 'feature_type': 'functional'}
# {'phrase': 'has an opening', 'feature_type': 'visual perceptual'}
# {'phrase': 'has a storage area', 'feature_type': 'encyclopedic'}
# {'phrase': 'can come in multiple shapes', 'feature_type': 'visual perceptual'}
# {'phrase': 'can be durable', 'feature_type': 'encyclopedic'}
# {'phrase': 'can be worn on the back', 'feature_type': 'functional'}
# {'phrase': 'can be made of canvas material', 'feature_type': 'visual perceptual'}
# {'phrase': 'is popular in Scotland', 'feature_type': 'encyclopedic'}
# {'phrase': 'has pipes', 'feature_type': 'visual perceptual'}
# {'phrase': 'contains a bag', 'feature_type': 'visual perceptual'}
# {'phrase': 'has a bag of air', 'feature_type': 'visual perceptual'}
# {'phrase': 'is traditional', 'feature_type': 'encyclopedic'}
# {'phrase': 'is made of tartan', 'feature_type': 'visual perceptual'}
# {'phrase': 'is blown to play', 'feature_type': 'functional'}
# {'phrase': 'can be blown', 'feature_type': 'functional'}
# {'phrase': 'can sound terrible', 'feature_type': 'other perceptual'}
# {'phrase': 'has a mouthpiece', 'feature_type': 'visual perceptual'}
# {'phrase': 'is a wind instrument', 'feature_type': 'taxonomic'}
# {'phrase': 'can make annoying sounds', 'feature_type': 'encyclopedic'}
# {'phrase': 'is played by people in kilts', 'feature_type': 'functional'}
# {'phrase': 'can be made of wood and fabric', 'feature_type': 'visual perceptual'}
# {'phrase': 'has a deep sound', 'feature_type': 'other perceptual'}
# {'phrase': 'requires lung power', 'feature_type': 'encyclopedic'}
# {'phrase': 'has a sharp sound', 'feature_type': 'other perceptual'}
# {'phrase': 'is involved in special occasions', 'feature_type': 'functional'}
# {'phrase': 'can be bouncy', 'feature_type': 'visual perceptual'}
# {'phrase': 'can bounce', 'feature_type': 'visual perceptual'}
# {'phrase': 'can be used in sports', 'feature_type': 'functional'}
# {'phrase': 'is spherical in shape', 'feature_type': 'visual perceptual'}
# {'phrase': 'is kicked', 'feature_type': 'functional'}
# {'phrase': 'is thrown', 'feature_type': 'functional'}
# {'phrase': 'can roll', 'feature_type': 'visual perceptual'}
# {'phrase': 'is used in playing football', 'feature_type': 'functional'}
# {'phrase': 'is inflated with air', 'feature_type': 'encyclopedic'}
# {'phrase': 'can be a source of entertainment', 'feature_type': 'encyclopedic'}
# {'phrase': 'can be caught', 'feature_type': 'encyclopedic'}
# {'phrase': 'is hunted', 'feature_type': 'encyclopedic'}
# {'phrase': 'can be inflated', 'feature_type': 'visual perceptual'}
# {'phrase': 'is played with', 'feature_type': 'functional'}
# {'phrase': 'can be used in tennis', 'feature_type': 'functional'}
# {'phrase': 'is popular with children', 'feature_type': 'functional'}
# {'phrase': 'can be used to play cricket', 'feature_type': 'functional'}
# {'phrase': 'can be used to play basketball', 'feature_type': 'functional'}
# {'phrase': 'can be used to play hockey', 'feature_type': 'functional'}
# {'phrase': 'can be hit', 'feature_type': 'functional'}
# {'phrase': 'is struck', 'feature_type': 'functional'}
# {'phrase': 'has one surface', 'feature_type': 'visual perceptual'}
# {'phrase': 'can be used on a beach', 'feature_type': 'encyclopedic'}
# {'phrase': 'can be used to play baseball', 'feature_type': 'functional'}
# {'phrase': 'can be used to play rugby', 'feature_type': 'functional'}
# {'phrase': 'can be used to play squash', 'feature_type': 'functional'}
# {'phrase': 'can be used to play table tennis', 'feature_type': 'functional'}
# {'phrase': 'can float', 'feature_type': 'functional'}
# {'phrase': 'can be filled with helium', 'feature_type': 'encyclopedic'}
# {'phrase': 'can burst', 'feature_type': 'other perceptual'}
# {'phrase': 'is popular at parties', 'feature_type': 'functional'}
# {'phrase': 'is attached to a string', 'feature_type': 'encyclopedic'}
# {'phrase': 'is connected by strings', 'feature_type': 'encyclopedic'}
# {'phrase': 'is flexible', 'feature_type': 'other perceptual'}
# {'phrase': 'is a stretched car', 'feature_type': 'other perceptual'}
# {'phrase': 'can be decorative', 'feature_type': 'functional'}
# {'phrase': 'is used in birthdays', 'feature_type': 'functional'}
# {'phrase': 'can be made into shapes', 'feature_type': 'functional'}
# {'phrase': 'can be tied into a knot', 'feature_type': 'visual perceptual'}
# {'phrase': 'has a hole', 'feature_type': 'visual perceptual'}
# {'phrase': 'can make a loud noise', 'feature_type': 'other perceptual'}
# {'phrase': 'can be deflated', 'feature_type': 'visual perceptual'}
# {'phrase': 'can make a squeaky noise', 'feature_type': 'other perceptual'}
# {'phrase': 'has a hole to blow in air', 'feature_type': 'encyclopedic'}
# {'phrase': 'is used in hot air balloons', 'feature_type': 'encyclopedic'}
# {'phrase': 'can be found in parties', 'feature_type': 'functional'}
# {'phrase': 'is fragile and delicate', 'feature_type': 'encyclopedic'}
# {'phrase': 'can float in air', 'feature_type': 'functional'}
# {'phrase': 'is curved in shape', 'feature_type': 'visual perceptual'}
# {'phrase': 'is popular with monkeys', 'feature_type': 'functional'}
# {'phrase': 'contains potassium', 'feature_type': 'encyclopedic'}
# {'phrase': 'has inedible skin', 'feature_type': 'encyclopedic'}
# {'phrase': 'is a source of energy', 'feature_type': 'functional'}
# {'phrase': 'grows in bunches', 'feature_type': 'visual perceptual'}
# {'phrase': 'bruises over time', 'feature_type': 'visual perceptual'}
# {'phrase': 'is useful for athletics', 'feature_type': 'functional'}
# {'phrase': 'has a phallic shape', 'feature_type': 'visual perceptual'}
# {'phrase': 'can be used to make flavored bread', 'feature_type': 'functional'}
# {'phrase': 'resembles a guitar', 'feature_type': 'taxonomic'}
# {'phrase': 'has a neck', 'feature_type': 'visual perceptual'}
# {'phrase': 'can be strummed', 'feature_type': 'functional'}
# {'phrase': 'is a string instrument', 'feature_type': 'taxonomic'}
# {'phrase': 'can be plucked', 'feature_type': 'functional'}
# {'phrase': 'is popular in country music', 'feature_type': 'functional'}
# {'phrase': 'can make a twangy sound', 'feature_type': 'other perceptual'}
# {'phrase': 'has four strings', 'feature_type': 'visual perceptual'}
# {'phrase': 'is popular in America', 'feature_type': 'encyclopedic'}
# {'phrase': 'has a high pitch', 'feature_type': 'other perceptual'}
# {'phrase': 'has a hollow body', 'feature_type': 'visual perceptual'}
# {'phrase': 'has a long neck', 'feature_type': 'visual perceptual'}
# {'phrase': 'is accompanied with singing', 'feature_type': 'functional'}
# {'phrase': 'can resonate', 'feature_type': 'visual perceptual'}
# {'phrase': 'has a fretboard', 'feature_type': 'visual perceptual'}
# {'phrase': 'can have metal strings', 'feature_type': 'visual perceptual'}
# {'phrase': 'is a type of boat', 'feature_type': 'taxonomic'}
# {'phrase': 'can be found on canals', 'feature_type': 'encyclopedic'}
# {'phrase': 'is found on water', 'feature_type': 'encyclopedic'}
# {'phrase': 'requires pulling', 'feature_type': 'functional'}
# {'phrase': 'can be painted', 'feature_type': 'visual perceptual'}
# {'phrase': 'was pulled by horses', 'feature_type': 'functional'}
# {'phrase': 'has a flat bottom', 'feature_type': 'visual perceptual'}
# {'phrase': 'can be used to live in', 'feature_type': 'taxonomic'}
# {'phrase': 'has a rudder', 'feature_type': 'visual perceptual'}
# {'phrase': 'can have rooms', 'feature_type': 'visual perceptual'}
# {'phrase': 'is used for recreation', 'feature_type': 'functional'}
# {'phrase': 'can be found on rivers', 'feature_type': 'encyclopedic'}
# {'phrase': 'can be moored', 'feature_type': 'encyclopedic'}
# {'phrase': 'does not have any passengers', 'feature_type': 'encyclopedic'}
# {'phrase': 'can look ugly', 'feature_type': 'visual perceptual'}
# {'phrase': 'can be made of waterproof material', 'feature_type': 'functional'}
# {'phrase': 'can store beer and ale', 'feature_type': 'functional'}
# {'phrase': 'is cylindrical in shape', 'feature_type': 'visual perceptual'}
# {'phrase': 'can hold or contain liquid', 'feature_type': 'functional'}
# {'phrase': 'can have a lid', 'feature_type': 'visual perceptual'}
# {'phrase': 'can store alcohol', 'feature_type': 'functional'}
# {'phrase': 'has metal bands', 'feature_type': 'visual perceptual'}
# {'phrase': 'can be found in boats or ships', 'feature_type': 'encyclopedic'}
# {'phrase': 'can store wine', 'feature_type': 'functional'}
# {'phrase': 'has a cork stopper', 'feature_type': 'visual perceptual'}
# {'phrase': 'can be found in cellars', 'feature_type': 'encyclopedic'}
# {'phrase': 'is wide in middle', 'feature_type': 'visual perceptual'}
# {'phrase': 'can have an attached tap', 'feature_type': 'visual perceptual'}
# {'phrase': 'is used to wash', 'feature_type': 'functional'}
# {'phrase': 'is found in bathrooms', 'feature_type': 'encyclopedic'}
# {'phrase': 'is a sink', 'feature_type': 'encyclopedic'}
# {'phrase': 'has a plug', 'feature_type': 'visual perceptual'}
# {'phrase': 'has a drain hole', 'feature_type': 'visual perceptual'}
# {'phrase': 'has a drain', 'feature_type': 'visual perceptual'}
# {'phrase': 'is used for washing', 'feature_type': 'functional'}
# {'phrase': 'is bowl shaped', 'feature_type': 'taxonomic'}
# {'phrase': 'is attached to pipes', 'feature_type': 'visual perceptual'}
# {'phrase': 'requires plumbing', 'feature_type': 'encyclopedic'}
# {'phrase': 'can have multiple taps', 'feature_type': 'visual perceptual'}
# {'phrase': 'can get cold', 'feature_type': 'other perceptual'}
# {'phrase': 'can be filled', 'feature_type': 'encyclopedic'}
# {'phrase': 'can be attached to a wall', 'feature_type': 'encyclopedic'}
# {'phrase': 'is used while brushing teeth', 'feature_type': 'functional'}
# {'phrase': 'can be found in bedrooms', 'feature_type': 'encyclopedic'}
# {'phrase': 'can be found inside buildings', 'feature_type': 'encyclopedic'}
# {'phrase': 'can be found near the toilet', 'feature_type': 'encyclopedic'}
# {'phrase': 'can be used for cleaning', 'feature_type': 'functional'}
# {'phrase': 'can be made of steel', 'feature_type': 'visual perceptual'}
# {'phrase': 'contain steel in its body', 'feature_type': 'visual perceptual'}
# {'phrase': 'can be made of wicker', 'feature_type': 'visual perceptual'}
# {'phrase': 'can be attached to bicycles', 'feature_type': 'visual perceptual'}
# {'phrase': 'can be woven', 'feature_type': 'visual perceptual'}
# {'phrase': 'can be made of straw', 'feature_type': 'visual perceptual'}
# {'phrase': 'can be found in shops', 'feature_type': 'encyclopedic'}
# {'phrase': 'can be found at picnics', 'feature_type': 'functional'}
# {'phrase': 'can contain flowers', 'feature_type': 'functional'}
# {'phrase': 'can be suspended', 'feature_type': 'functional'}
# {'phrase': 'is rigid', 'feature_type': 'visual perceptual'}
# {'phrase': 'is nocturnal', 'feature_type': 'encyclopedic'}
# {'phrase': 'is a mammal', 'feature_type': 'taxonomic'}
# {'phrase': 'eats insects', 'feature_type': 'functional'}
# {'phrase': 'can hang upside down', 'feature_type': 'visual perceptual'}
# {'phrase': 'has fur', 'feature_type': 'visual perceptual'}
# {'phrase': 'has fibrous skin', 'feature_type': 'visual perceptual'}
# {'phrase': 'uses echolocation', 'feature_type': 'functional'}
# {'phrase': 'is blind', 'feature_type': 'encyclopedic'}
# {'phrase': 'has ears', 'feature_type': 'visual perceptual'}
# {'phrase': 'eats fruit', 'feature_type': 'functional'}
# {'phrase': 'can be found in caves', 'feature_type': 'encyclopedic'}
# {'phrase': 'has big ears', 'feature_type': 'visual perceptual'}
# {'phrase': 'uses sonic waves to communicate', 'feature_type': 'encyclopedic'}
# {'phrase': 'can sleep', 'feature_type': 'functional'}
# {'phrase': 'has good hearing', 'feature_type': 'encyclopedic'}
# {'phrase': 'is associated with vampires', 'feature_type': 'taxonomic'}
# {'phrase': 'can carry diseases', 'feature_type': 'encyclopedic'}
# {'phrase': 'can be found in dark places', 'feature_type': 'encyclopedic'}
# {'phrase': 'eats rodents and mice', 'feature_type': 'functional'}
# {'phrase': 'can be found living in large groups', 'feature_type': 'encyclopedic'}
# {'phrase': 'can suck blood', 'feature_type': 'functional'}
# {'phrase': 'is perceived as cute', 'feature_type': 'encyclopedic'}
# {'phrase': 'is a flying rodent', 'feature_type': 'taxonomic'}
# {'phrase': 'is a rodent', 'feature_type': 'visual perceptual'}
# {'phrase': 'can have a hot temperature', 'feature_type': 'other perceptual'}
# {'phrase': 'can be made of enamel', 'feature_type': 'visual perceptual'}
# {'phrase': 'can contain bubbles', 'feature_type': 'visual perceptual'}
# {'phrase': 'has sides', 'feature_type': 'visual perceptual'}
# {'phrase': 'can overflow', 'feature_type': 'encyclopedic'}
# {'phrase': 'can have a rubber duck inside it', 'feature_type': 'encyclopedic'}
# {'phrase': 'can contain a shower', 'feature_type': 'visual perceptual'}
# {'phrase': 'can contain hot water', 'feature_type': 'encyclopedic'}
# {'phrase': 'is a tub', 'feature_type': 'taxonomic'}
# {'phrase': 'is used for taking a bath', 'feature_type': 'functional'}
# {'phrase': 'is an alternative to showers', 'feature_type': 'encyclopedic'}
# {'phrase': 'is a gun', 'feature_type': 'taxonomic'}
# {'phrase': 'can stab', 'feature_type': 'functional'}
# {'phrase': 'is attached to a gun', 'feature_type': 'functional'}
# {'phrase': 'has a knife', 'feature_type': 'visual perceptual'}
# {'phrase': 'is for hand to hand combat', 'feature_type': 'functional'}
# {'phrase': 'has attachment points', 'feature_type': 'visual perceptual'}
# {'phrase': 'is cruel', 'feature_type': 'encyclopedic'}
# {'phrase': 'has a sharp point', 'feature_type': 'visual perceptual'}
# {'phrase': 'is cooked by baking', 'feature_type': 'functional'}
# {'phrase': 'is a seed', 'feature_type': 'taxonomic'}
# {'phrase': 'has protein', 'feature_type': 'encyclopedic'}
# {'phrase': 'is a pulse', 'feature_type': 'taxonomic'}
# {'phrase': 'can be baked', 'feature_type': 'taxonomic'}
# {'phrase': 'can be used to make chilli', 'feature_type': 'functional'}
# {'phrase': 'is found in pods', 'feature_type': 'visual perceptual'}
# {'phrase': 'can have a kidney shape', 'feature_type': 'visual perceptual'}
# {'phrase': 'can be stored in cans or tins', 'feature_type': 'encyclopedic'}
# {'phrase': 'can be found in gardens', 'feature_type': 'encyclopedic'}
# {'phrase': 'can cause farting', 'feature_type': 'functional'}
# {'phrase': 'is a big seed', 'feature_type': 'encyclopedic'}
# {'phrase': 'can be sold fresh', 'feature_type': 'encyclopedic'}
# {'phrase': 'can be found in forests', 'feature_type': 'encyclopedic'}
# {'phrase': 'has babies that are called cubs', 'feature_type': 'encyclopedic'}
# {'phrase': 'has paws', 'feature_type': 'visual perceptual'}
# {'phrase': 'can growl', 'feature_type': 'other perceptual'}
# {'phrase': 'likes honey', 'feature_type': 'encyclopedic'}
# {'phrase': 'has a variety of species', 'feature_type': 'encyclopedic'}
# {'phrase': 'can be grizzly', 'feature_type': 'encyclopedic'}
# {'phrase': 'can be found in the north pole', 'feature_type': 'encyclopedic'}
# {'phrase': 'can climb', 'feature_type': 'functional'}
# {'phrase': 'has an insatiable appetite', 'feature_type': 'functional'}
# {'phrase': 'can hibernate', 'feature_type': 'encyclopedic'}
# {'phrase': 'can be found in cold climate', 'feature_type': 'encyclopedic'}
# {'phrase': 'can build natural dams', 'feature_type': 'functional'}
# {'phrase': 'can build', 'feature_type': 'functional'}
# {'phrase': 'can chew through wood', 'feature_type': 'functional'}
# {'phrase': 'has a flat tail', 'feature_type': 'visual perceptual'}
# {'phrase': 'can gnaw', 'feature_type': 'functional'}
# {'phrase': 'can chew', 'feature_type': 'functional'}
# {'phrase': 'has a big tail', 'feature_type': 'visual perceptual'}
# {'phrase': 'has big front teeth', 'feature_type': 'visual perceptual'}
# {'phrase': 'can be found in a dam', 'feature_type': 'encyclopedic'}
# {'phrase': 'has strong teeth', 'feature_type': 'visual perceptual'}
# {'phrase': 'is popular in Canada', 'feature_type': 'encyclopedic'}
# {'phrase': 'has small paws', 'feature_type': 'visual perceptual'}
# ...
# {'phrase': 'has a subject', 'feature_type': 'functional'}
# {'phrase': 'can contain diagrams', 'feature_type': 'visual perceptual'}
# {'phrase': 'can contain questions', 'feature_type': 'functional'}
# {'phrase': 'has a table of contents', 'feature_type': 'encyclopedic'}
# {'phrase': 'is factual', 'feature_type': 'functional'}
# {'phrase': 'is used for studying', 'feature_type': 'functional'}
# {'phrase': 'is used in universities', 'feature_type': 'functional'}
# {'phrase': 'is used in coursework', 'feature_type': 'functional'}
# {'phrase': 'is used in lectures', 'feature_type': 'functional'}
# {'phrase': 'is a symbol of power', 'feature_type': 'encyclopedic'}
# {'phrase': 'is plush', 'feature_type': 'visual perceptual'}
# {'phrase': 'is elevated', 'feature_type': 'encyclopedic'}
# {'phrase': 'is historical', 'feature_type': 'encyclopedic'}
# {'phrase': 'is a chair', 'feature_type': 'encyclopedic'}
# {'phrase': 'is for a ruler', 'feature_type': 'functional'}
# {'phrase': 'is used in coronations', 'feature_type': 'functional'}
# {'phrase': 'is a digit', 'feature_type': 'taxonomic'}
# {'phrase': 'is for showing approval', 'feature_type': 'functional'}
# {'phrase': 'is like a finger', 'feature_type': 'taxonomic'}
# {'phrase': 'has a cuticle', 'feature_type': 'visual perceptual'}
# {'phrase': 'is larger than fingers', 'feature_type': 'visual perceptual'}
# {'phrase': 'is not a finger', 'feature_type': 'taxonomic'}
# {'phrase': 'is orange and black in color', 'feature_type': 'visual perceptual'}
# {'phrase': 'can pounce', 'feature_type': 'functional'}
# {'phrase': 'has leathery skin', 'feature_type': 'visual perceptual'}
# {'phrase': 'has lumpy skin', 'feature_type': 'visual perceptual'}
# {'phrase': 'is used to heat bread', 'feature_type': 'functional'}
# {'phrase': 'is used for toasting', 'feature_type': 'functional'}
# {'phrase': 'has slots for bread', 'feature_type': 'visual perceptual'}
# {'phrase': 'has two or more slots', 'feature_type': 'visual perceptual'}
# {'phrase': 'can toast waffles', 'feature_type': 'functional'}
# {'phrase': 'is on the foot', 'feature_type': 'visual perceptual'}
# {'phrase': 'can be stubbed', 'feature_type': 'encyclopedic'}
# {'phrase': 'can have a ring on it', 'feature_type': 'encyclopedic'}
# {'phrase': 'is green when unripe', 'feature_type': 'encyclopedic'}
# {'phrase': 'is grown in a greenhouse', 'feature_type': 'encyclopedic'}
# {'phrase': 'has tastebuds', 'feature_type': 'encyclopedic'}
# {'phrase': 'can taste', 'feature_type': 'functional'}
# {'phrase': 'is required for speaking', 'feature_type': 'functional'}
# {'phrase': 'moves food around', 'feature_type': 'functional'}
# {'phrase': 'is used to taste food', 'feature_type': 'functional'}
# {'phrase': 'helps chewing', 'feature_type': 'functional'}
# {'phrase': 'has a line in the middle', 'feature_type': 'visual perceptual'}
# {'phrase': 'has a small tail', 'feature_type': 'visual perceptual'}
# {'phrase': 'is reclusive', 'feature_type': 'encyclopedic'}
# {'phrase': 'has large rear wheels', 'feature_type': 'visual perceptual'}
# {'phrase': 'is used in agriculture', 'feature_type': 'functional'}
# {'phrase': 'has small front wheels', 'feature_type': 'visual perceptual'}
# {'phrase': 'is slow on roads', 'feature_type': 'encyclopedic'}
# {'phrase': 'is used to pull ploughs', 'feature_type': 'functional'}
# {'phrase': 'runs on tracks', 'feature_type': 'functional'}
# {'phrase': 'pulls carriages', 'feature_type': 'visual perceptual'}
# {'phrase': 'can be powered by steam', 'feature_type': 'encyclopedic'}
# {'phrase': 'can serve food on board', 'feature_type': 'encyclopedic'}
# {'phrase': 'carries food and drinks', 'feature_type': 'functional'}
# {'phrase': 'is used in cafeterias', 'feature_type': 'functional'}
# {'phrase': 'has three wheels', 'feature_type': 'visual perceptual'}
# {'phrase': 'has one wheel at front and two at back', 'feature_type': 'visual perceptual'}
# {'phrase': 'is used in supermarkets', 'feature_type': 'functional'}
# {'phrase': 'can have a baby seat', 'feature_type': 'visual perceptual'}
# {'phrase': 'has a metal frame', 'feature_type': 'visual perceptual'}
# {'phrase': 'has three keys', 'feature_type': 'visual perceptual'}
# {'phrase': 'has a curved section', 'feature_type': 'visual perceptual'}
# {'phrase': 'is played in brass bands', 'feature_type': 'functional'}
# {'phrase': 'can be made of corduroy', 'feature_type': 'visual perceptual'}
# {'phrase': 'is caught by tickling', 'feature_type': 'encyclopedic'}
# {'phrase': 'is a small spade', 'feature_type': 'taxonomic'}
# {'phrase': 'can shovel', 'feature_type': 'visual perceptual'}
# {'phrase': 'is used for planting', 'feature_type': 'encyclopedic'}
# {'phrase': 'is used to pot plants', 'feature_type': 'functional'}
# {'phrase': 'is used on flowerbeds', 'feature_type': 'functional'}
# {'phrase': 'is like a lorry', 'feature_type': 'taxonomic'}
# {'phrase': 'has a cargo container', 'feature_type': 'visual perceptual'}
# {'phrase': 'has a wide end', 'feature_type': 'visual perceptual'}
# {'phrase': 'pulls boats', 'feature_type': 'functional'}
# {'phrase': 'tows boats', 'feature_type': 'functional'}
# {'phrase': 'guides larger boats', 'feature_type': 'functional'}
# {'phrase': 'is found in a harbor', 'feature_type': 'encyclopedic'}
# {'phrase': 'maneuvers other boats', 'feature_type': 'functional'}
# {'phrase': 'travels short distances', 'feature_type': 'encyclopedic'}
# {'phrase': 'is associated with Netherlands', 'feature_type': 'encyclopedic'}
# {'phrase': 'has colored petals', 'feature_type': 'visual perceptual'}
# {'phrase': 'is cup shaped', 'feature_type': 'visual perceptual'}
# {'phrase': 'is eaten as a steak', 'feature_type': 'encyclopedic'}
# {'phrase': 'is fished in nets', 'feature_type': 'encyclopedic'}
# {'phrase': 'is bred', 'feature_type': 'functional'}
# {'phrase': 'is eaten at thanksgiving', 'feature_type': 'encyclopedic'}
# {'phrase': 'has a saggy neck', 'feature_type': 'visual perceptual'}
# {'phrase': 'grows in winter', 'feature_type': 'encyclopedic'}
# {'phrase': 'is hard when raw', 'feature_type': 'encyclopedic'}
# {'phrase': 'is like a carrot', 'feature_type': 'taxonomic'}
# {'phrase': 'lays eggs on beach', 'feature_type': 'encyclopedic'}
# {'phrase': 'resembles a tortoise', 'feature_type': 'encyclopedic'}
# {'phrase': 'moves slowly on land', 'feature_type': 'encyclopedic'}
# {'phrase': 'is used for plucking', 'feature_type': 'functional'}
# {'phrase': 'is used to pull out hair', 'feature_type': 'functional'}
# {'phrase': 'is used to pluck eyebrows', 'feature_type': 'functional'}
# {'phrase': 'has two prongs', 'feature_type': 'visual perceptual'}
# {'phrase': 'is used to hold small objects', 'feature_type': 'functional'}
# {'phrase': 'has pointed ends', 'feature_type': 'visual perceptual'}
# {'phrase': 'is used to write', 'feature_type': 'functional'}
# {'phrase': 'has paper', 'feature_type': 'visual perceptual'}
# {'phrase': 'is used for writing letters', 'feature_type': 'functional'}
# {'phrase': 'can print', 'feature_type': 'functional'}
# {'phrase': 'makes a tapping sound', 'feature_type': 'other perceptual'}
# {'phrase': 'is clunky', 'feature_type': 'encyclopedic'}
# {'phrase': 'is used by writers', 'feature_type': 'functional'}
# {'phrase': 'has an ink ribbon', 'feature_type': 'visual perceptual'}
# {'phrase': 'has one wheel', 'feature_type': 'visual perceptual'}
# {'phrase': 'is difficult to balance on', 'feature_type': 'encyclopedic'}
# {'phrase': 'is used by clowns', 'feature_type': 'functional'}
# {'phrase': 'has no handlebars', 'feature_type': 'encyclopedic'}
# {'phrase': 'requires balancing', 'feature_type': 'encyclopedic'}
# {'phrase': 'is used by performers', 'feature_type': 'functional'}
# {'phrase': 'is worn on the face', 'feature_type': 'functional'}
# {'phrase': 'is used to conceal', 'feature_type': 'functional'}
# {'phrase': 'is religious', 'feature_type': 'encyclopedic'}
# {'phrase': 'is used in weddings', 'feature_type': 'functional'}
# {'phrase': 'is worn by Muslims', 'feature_type': 'functional'}
# {'phrase': 'is worn by nuns', 'feature_type': 'functional'}
# {'phrase': 'made of net', 'feature_type': 'visual perceptual'}
# {'phrase': 'is used as a shroud', 'feature_type': 'functional'}
# {'phrase': 'is played by a violinist', 'feature_type': 'encyclopedic'}
# {'phrase': 'is held under the chin', 'feature_type': 'encyclopedic'}
# {'phrase': 'is used in string ensembles', 'feature_type': 'functional'}
# {'phrase': 'contains money', 'feature_type': 'functional'}
# {'phrase': 'contains credit cards', 'feature_type': 'visual perceptual'}
# {'phrase': 'is pocket sized', 'feature_type': 'visual perceptual'}
# {'phrase': 'has bank notes', 'feature_type': 'functional'}
# {'phrase': 'contains identification', 'feature_type': 'encyclopedic'}
# {'phrase': 'contains coins', 'feature_type': 'encyclopedic'}
# {'phrase': 'contains receipts', 'feature_type': 'visual perceptual'}
# {'phrase': 'can be made of fake or real leather', 'feature_type': 'visual perceptual'}
# {'phrase': 'drags itself along', 'feature_type': 'functional'}
# {'phrase': 'has a moustache', 'feature_type': 'visual perceptual'}
# {'phrase': 'washes clothes', 'feature_type': 'functional'}
# {'phrase': 'uses soap', 'feature_type': 'encyclopedic'}
# {'phrase': 'has a compartment', 'feature_type': 'visual perceptual'}
# {'phrase': 'is connected to a water supply', 'feature_type': 'functional'}
# {'phrase': 'uses conditioner', 'feature_type': 'encyclopedic'}
# {'phrase': 'is used in laundromats', 'feature_type': 'encyclopedic'}
# {'phrase': 'spins clothes', 'feature_type': 'functional'}
# {'phrase': 'has a detergent compartment', 'feature_type': 'encyclopedic'}
# {'phrase': 'has a round door', 'feature_type': 'visual perceptual'}
# {'phrase': 'rinses water', 'feature_type': 'functional'}
# {'phrase': 'uses warm water', 'feature_type': 'encyclopedic'}
# {'phrase': 'washes fabrics', 'feature_type': 'functional'}
# {'phrase': 'is attracted to sweet things', 'feature_type': 'encyclopedic'}
# {'phrase': 'does not die when it stings', 'feature_type': 'encyclopedic'}
# {'phrase': 'can sting repeatedly', 'feature_type': 'other perceptual'}
# {'phrase': 'has a pink flesh', 'feature_type': 'visual perceptual'}
# {'phrase': 'is a melon', 'feature_type': 'taxonomic'}
# {'phrase': 'is diving equipment', 'feature_type': 'functional'}
# {'phrase': 'is used by surfers and divers', 'feature_type': 'functional'}
# {'phrase': 'is made of neoprene', 'feature_type': 'encyclopedic'}
# {'phrase': 'keeps the body warm in the water', 'feature_type': 'functional'}
# {'phrase': 'protects the body from the cold', 'feature_type': 'functional'}
# {'phrase': 'is hard to get off', 'feature_type': 'encyclopedic'}
# {'phrase': 'is used in water sports', 'feature_type': 'functional'}
# {'phrase': 'has a zip at the back', 'feature_type': 'visual perceptual'}
# {'phrase': 'has velcro', 'feature_type': 'visual perceptual'}
# {'phrase': 'is worn with flippers', 'feature_type': 'functional'}
# {'phrase': 'eats krill', 'feature_type': 'functional'}
# {'phrase': 'has baleen', 'feature_type': 'visual perceptual'}
# {'phrase': 'is the largest animal', 'feature_type': 'encyclopedic'}
# {'phrase': 'can get beached', 'feature_type': 'encyclopedic'}
# {'phrase': 'can hold its breath for long periods of time', 'feature_type': 'encyclopedic'}
# {'phrase': 'has a bucket', 'feature_type': 'visual perceptual'}
# {'phrase': 'is used to carry garden waste', 'feature_type': 'functional'}
# {'phrase': 'has a barrow', 'feature_type': 'visual perceptual'}
# {'phrase': 'has garden equipment', 'feature_type': 'functional'}
# {'phrase': 'is used by physically disabled people', 'feature_type': 'functional'}
# {'phrase': 'is used by people who cannot walk', 'feature_type': 'functional'}
# {'phrase': 'has footrests', 'feature_type': 'visual perceptual'}
# {'phrase': 'can be pushed by the person sitting in it', 'feature_type': 'functional'}
# {'phrase': 'is a chair with wheels', 'feature_type': 'encyclopedic'}
# {'phrase': 'is wheeled', 'feature_type': 'visual perceptual'}
# {'phrase': 'helps an injured person move', 'feature_type': 'functional'}
# {'phrase': 'can whip cream', 'feature_type': 'functional'}
# {'phrase': 'is used for whisking', 'feature_type': 'functional'}
# {'phrase': 'is used to mix eggs', 'feature_type': 'functional'}
# {'phrase': 'adds air to a mixture', 'feature_type': 'functional'}
# {'phrase': 'is used for whipping food', 'feature_type': 'functional'}
# {'phrase': 'is used for making cake', 'feature_type': 'functional'}
# {'phrase': 'has wire loops', 'feature_type': 'visual perceptual'}
# {'phrase': 'is made of curved wires', 'feature_type': 'visual perceptual'}
# {'phrase': 'is aged', 'feature_type': 'encyclopedic'}
# {'phrase': 'is made of fermented grain', 'feature_type': 'other perceptual'}
# {'phrase': 'is distilled', 'feature_type': 'encyclopedic'}
# {'phrase': 'is peaty', 'feature_type': 'other perceptual'}
# {'phrase': 'is smoky', 'feature_type': 'other perceptual'}
# {'phrase': 'has drooping branches', 'feature_type': 'visual perceptual'}
# {'phrase': 'has long branches', 'feature_type': 'visual perceptual'}
# {'phrase': 'produces catkin flowers', 'feature_type': 'visual perceptual'}
# {'phrase': 'is light colored', 'feature_type': 'visual perceptual'}
# {'phrase': 'is used to make aspirin', 'feature_type': 'functional'}
# {'phrase': 'has wind blowing through it', 'feature_type': 'encyclopedic'}
# {'phrase': 'is used to make cricket bats', 'feature_type': 'functional'}
# {'phrase': 'has soft wood', 'feature_type': 'encyclopedic'}
# {'phrase': 'is drunk with food', 'feature_type': 'encyclopedic'}
# {'phrase': 'is made at vineyards', 'feature_type': 'encyclopedic'}
# {'phrase': 'requires corkscrew to open', 'feature_type': 'functional'}
# {'phrase': 'has tannins', 'feature_type': 'encyclopedic'}
# {'phrase': 'is mulled', 'feature_type': 'encyclopedic'}
# {'phrase': 'makes a howling sound', 'feature_type': 'other perceptual'}
# {'phrase': 'howls at night', 'feature_type': 'other perceptual'}
# {'phrase': 'pecks trees', 'feature_type': 'functional'}
# {'phrase': 'makes a knocking sound', 'feature_type': 'other perceptual'}
# {'phrase': 'pecks wood for food', 'feature_type': 'functional'}
# {'phrase': 'is good for soil', 'feature_type': 'functional'}
# {'phrase': 'eats dirt', 'feature_type': 'functional'}
# {'phrase': 'can survive if cut in half', 'feature_type': 'encyclopedic'}
# {'phrase': 'has ropes', 'feature_type': 'visual perceptual'}
# {'phrase': 'is found in docks', 'feature_type': 'encyclopedic'}
# {'phrase': 'contains bacteria', 'feature_type': 'encyclopedic'}
# {'phrase': 'can contain fruit', 'feature_type': 'encyclopedic'}
# {'phrase': 'is biotic', 'feature_type': 'encyclopedic'}
# {'phrase': 'can be eaten with fruit', 'feature_type': 'encyclopedic'}
# {'phrase': 'is made of fermented milk', 'feature_type': 'encyclopedic'}
# {'phrase': 'is sold in a pot', 'feature_type': 'encyclopedic'}
# {'phrase': 'can be eaten with honey', 'feature_type': 'encyclopedic'}
# {'phrase': 'has friendly bacteria', 'feature_type': 'encyclopedic'}
# {'phrase': 'can be vanilla flavored', 'feature_type': 'encyclopedic'}
# {'phrase': 'goes up and down', 'feature_type': 'visual perceptual'}
# {'phrase': 'is attached to a finger', 'feature_type': 'visual perceptual'}
# {'phrase': 'has a finger loop', 'feature_type': 'visual perceptual'}
# {'phrase': 'can unravel', 'feature_type': 'visual perceptual'}
# {'phrase': 'has black stripes', 'feature_type': 'visual perceptual'}
# {'phrase': 'has white stripes', 'feature_type': 'visual perceptual'}
# {'phrase': 'has black and white stripes', 'feature_type': 'visual perceptual'}
# {'phrase': 'is preyed on by lions', 'feature_type': 'functional'}
# {'phrase': 'hides in grass', 'feature_type': 'encyclopedic'}
# {'phrase': 'can be used to make stew', 'feature_type': 'NA'}
# {'phrase': 'can be warm', 'feature_type': 'other perceptual'}
# {'phrase': 'can bleed', 'feature_type': 'encyclopedic'}
# {'phrase': 'has bones', 'feature_type': 'encyclopedic'}
# {'phrase': 'has forelimbs', 'feature_type': 'visual perceptual'}
# {'phrase': 'is aquatic', 'feature_type': 'encyclopedic'}
# {'phrase': 'is upright', 'feature_type': 'visual perceptual'}
# {'phrase': 'is worn in the kitchen', 'feature_type': 'functional'}
# {'phrase': 'uses electricity', 'feature_type': 'encyclopedic'}

# %%
doc = nlp('John is warm-blooded.')

# %%
[(token.text, token.pos_, token.tag_) for token in doc if token.pos_ in ['VERB', 'AUX']]
# Out:
# [('is', 'AUX', 'VBZ')]

# %%
for token in doc:
    print(token.text, token.pos_, token.tag_)
# Out:
# John PROPN NNP
# is AUX VBZ
# warm ADJ JJ
# - PUNCT HYPH
# blooded ADJ JJ
# . PUNCT .

# %%
'''
is -> is not
can -> cannot
has -> does not have

'''
